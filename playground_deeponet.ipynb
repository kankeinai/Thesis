# %% [markdown]
# # Notebook \#1 - Operator Learning and Optimal Control
#
# version: DeepONet
#
# Lets start by importing everything that we need for training and solving optimal control problems.

# %%
import torch
from utils.scripts import solve_optimization
from models.deeponet import DeepONetCartesianProd
from utils.settings import compute_loss_random_grid, gradient_automatic
from utils.data import MultiFunctionDatasetODE, save_dataset
from utils.scripts import load_data
from torch.optim.lr_scheduler import StepLR
import torch.optim as optim
from utils.training import training

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# We can define DeepONet architecture by using class `DeepONetCartesianProd`. It takes as input 2 lists: `branch_net` and `trunk_net`. They define number of neurons at each layer. `brunch_activations` and `trunk_activations` define what kind of activation functions will be used.

# %%
# Model Parameters
m = 200         # sensor size (branch input size)
n_hid = 200     # layer's hidden sizes
p = 200         # output size
dim_x = 1       # trunk (trunk input size)

# Specify the MLP architecture
branch_net = [m, n_hid,  n_hid, n_hid, n_hid, p]
branch_activations = ['tanh', 'tanh', 'tanh', 'tanh','none']
trunk_net = [dim_x, n_hid,  n_hid, n_hid, n_hid, p]
trunk_activations = ['tanh', 'tanh', 'tanh', 'tanh','none']
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

model
# Out:
# DeepONetCartesianProd(
#   (branch_net): DenseNetwork(
#     (network): Sequential(
#       (0): Linear(in_features=200, out_features=200, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=200, out_features=200, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=200, out_features=200, bias=True)
#       (5): Tanh()
#       (6): Linear(in_features=200, out_features=200, bias=True)
#       (7): Tanh()
#       (8): Linear(in_features=200, out_features=200, bias=True)
#       (9): Identity()
#     )
#   )
#   (trunk_net): DenseNetwork(
#     (network): Sequential(
#       (0): Linear(in_features=1, out_features=200, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=200, out_features=200, bias=True)
#       (3): Tanh()
#       (4): Linear(in_features=200, out_features=200, bias=True)
#       (5): Tanh()
#       (6): Linear(in_features=200, out_features=200, bias=True)
#       (7): Tanh()
#       (8): Linear(in_features=200, out_features=200, bias=True)
#       (9): Identity()
#     )
#   )
# )

# %% [markdown]
# Now, we have a model that we can either train to learn specific differential equation or load pre-trained weights. We can create a dataset using custom `MultiFunctionDatasetODE`. `fraction_supervised` defines what fraction of generated input functions will have a precomputed trajectory. Options for `selected_problem` are `linear`, `oscillatory`, `polynomial_tracking`, `nonlinear`, `singular_arc` like the ones used in the thesis. This set can be easily extended.

# %%
selected_problem = 'linear'
architecture = 'deeponet'

ds = MultiFunctionDatasetODE(
    m=200, 
    n_functions=10000,
    function_types=['sine', 'polynomial', 'constant', 'linear'],
    grf_lb= 0.05,
    grf_ub= 0.5,
    architecture = architecture,
    degree_range = (1, 5),
    slope_range = (-2, 2),
    intercept_range = (-2, 2),
    frequency_range = (0.1, 30),    # For 'sine'
    amplitude_range = (0.5, 2),  
    coeff_range = (-3, 3),
    end_time = 1,
    project = True,
    bound = [-1.5, -1.5],
    num_domain = 200,
    include_supervision = True,
    fraction_supervised = 1,
    problem = selected_problem,
)

# %% [markdown]
# It is also possible to save dataset and use it for future experiments:

# %%
save_dataset(ds,  "datasets/linear/", name = 'test')

# %% [markdown]
# `load_data()` function given path to saved train and test datasets create a `train_loader` and `test_loader` with default `batch_size = 64`

# %%
SEED = 42

train_loader, test_loader = load_data(
    architecture,
    'datasets/linear/train.pt',
    'datasets/linear/test.pt',
    SEED,
)

# %% [markdown]
# Before starting to train your model, you need to define `compute_loss`. For our case we can just use pre-written

# %%
compute_loss = compute_loss_random_grid['linear']
compute_loss
# Out:
# {'physics_loss': <function utils.settings.<lambda>(args)>,
#  'initial_loss': <function utils.settings.<lambda>(args)>}

# %% [markdown]
# which is esentially under the hood is a dictionary defining `physics_loss` and `initial_loss` as lambda functions that take as input `args`. `args` is a disctionary too that accepts any parameters, like `t`, `u`, `x`. Note that for DeepONet these losses should be defined on a random grid and for FNO and LNO on a fixed grid.
#
# For the gradient we have a function `gradient_automatic` that takes as input `x` and `t` and calculate a gradient via automatic differentiation:

# %%
gradient_automatic
# Out:
# <function utils.settings.gradient_automatic(x, t)>

# %% [markdown]
# Define anything needed for training

# %%
#Initialize Optimizer
lr = 0.0001
epochs = 2000
optimizer = optim.Adam(model.parameters(), lr=lr)

scheduler = StepLR(
    optimizer,
    step_size=100,   
    gamma=0.9,     
)

# %% [markdown]
# And just use our function `training`. Make sure to include correct `architecture="deeponet"`,`problem="linear"`, `w=[1, 1]` (for the losses), `save_plot = 20` (how often make analytics, predictions and losses plots), `save=100` (how often to save model and computation time array),

# %%
model, losses = training(model, optimizer, scheduler, train_loader, test_loader, compute_loss, gradient_automatic, num_epochs=epochs, problem=selected_problem, w=[1, 1])

# %% [markdown]
# Or you can just load pre-trained model

# %%
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

ckpt = torch.load("trained_models/linear/deeponet/unsupervised/epoch[1800]_model_time_[20250717_215634]_loss_[0.0006].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])
# Out:
# <All keys matched successfully>

# %% [markdown]
# # Control problem with Linear ODE

# %% [markdown]
# Now, we are ready to solve optimal control problem. We have control over the weights that are assigned to: physics loss, objective function, initial loss, smoothness and boundary loss (if there is any condition)

# %%
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

w = [100, 1, 1, 1, 0]

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'linear', initial_guess,
    lr=0.001,
    architecture="deeponet",  
    w=w,
    num_epochs=12000,
    m=m,
    device=device, logging = True
)
# Out:
# Epoch   50 | Loss: 7.350015 | rel_err_u: 3.8967, rel_err_x: 0.5252
# Epoch  100 | Loss: 5.106818 | rel_err_u: 3.8528, rel_err_x: 0.5242
# Epoch  150 | Loss: 3.604753 | rel_err_u: 3.8203, rel_err_x: 0.5243
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch  200 | Loss: 2.589784 | rel_err_u: 3.7956, rel_err_x: 0.5242
# Epoch  250 | Loss: 1.903567 | rel_err_u: 3.7757, rel_err_x: 0.5237
# Epoch  300 | Loss: 1.441365 | rel_err_u: 3.7588, rel_err_x: 0.5229
# Epoch  350 | Loss: 1.131671 | rel_err_u: 3.7436, rel_err_x: 0.5219
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch  400 | Loss: 0.925187 | rel_err_u: 3.7294, rel_err_x: 0.5207
# Epoch  450 | Loss: 0.788088 | rel_err_u: 3.7157, rel_err_x: 0.5194
# Epoch  500 | Loss: 0.697338 | rel_err_u: 3.7020, rel_err_x: 0.5179
# Epoch  550 | Loss: 0.637323 | rel_err_u: 3.6883, rel_err_x: 0.5164
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch  600 | Loss: 0.597494 | rel_err_u: 3.6744, rel_err_x: 0.5148
# Epoch  650 | Loss: 0.570769 | rel_err_u: 3.6602, rel_err_x: 0.5131
# Epoch  700 | Loss: 0.552441 | rel_err_u: 3.6456, rel_err_x: 0.5114
# Epoch  750 | Loss: 0.539433 | rel_err_u: 3.6306, rel_err_x: 0.5095
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch  800 | Loss: 0.529764 | rel_err_u: 3.6152, rel_err_x: 0.5076
# Epoch  850 | Loss: 0.522180 | rel_err_u: 3.5995, rel_err_x: 0.5057
# Epoch  900 | Loss: 0.515903 | rel_err_u: 3.5832, rel_err_x: 0.5036
# Epoch  950 | Loss: 0.510454 | rel_err_u: 3.5666, rel_err_x: 0.5015
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 1000 | Loss: 0.505537 | rel_err_u: 3.5495, rel_err_x: 0.4994
# Epoch 1050 | Loss: 0.500973 | rel_err_u: 3.5320, rel_err_x: 0.4971
# Epoch 1100 | Loss: 0.496649 | rel_err_u: 3.5141, rel_err_x: 0.4948
# Epoch 1150 | Loss: 0.492494 | rel_err_u: 3.4958, rel_err_x: 0.4925
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 1200 | Loss: 0.488460 | rel_err_u: 3.4771, rel_err_x: 0.4900
# Epoch 1250 | Loss: 0.484515 | rel_err_u: 3.4580, rel_err_x: 0.4875
# Epoch 1300 | Loss: 0.480635 | rel_err_u: 3.4384, rel_err_x: 0.4849
# Epoch 1350 | Loss: 0.476803 | rel_err_u: 3.4185, rel_err_x: 0.4823
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 1400 | Loss: 0.473005 | rel_err_u: 3.3982, rel_err_x: 0.4796
# Epoch 1450 | Loss: 0.469232 | rel_err_u: 3.3775, rel_err_x: 0.4768
# Epoch 1500 | Loss: 0.465474 | rel_err_u: 3.3564, rel_err_x: 0.4740
# Epoch 1550 | Loss: 0.461727 | rel_err_u: 3.3349, rel_err_x: 0.4711
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 1600 | Loss: 0.457985 | rel_err_u: 3.3131, rel_err_x: 0.4681
# Epoch 1650 | Loss: 0.454244 | rel_err_u: 3.2909, rel_err_x: 0.4651
# Epoch 1700 | Loss: 0.450502 | rel_err_u: 3.2684, rel_err_x: 0.4620
# Epoch 1750 | Loss: 0.446757 | rel_err_u: 3.2455, rel_err_x: 0.4589
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 1800 | Loss: 0.443008 | rel_err_u: 3.2222, rel_err_x: 0.4557
# Epoch 1850 | Loss: 0.439254 | rel_err_u: 3.1986, rel_err_x: 0.4524
# Epoch 1900 | Loss: 0.435495 | rel_err_u: 3.1747, rel_err_x: 0.4491
# Epoch 1950 | Loss: 0.431731 | rel_err_u: 3.1505, rel_err_x: 0.4457
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 2000 | Loss: 0.427961 | rel_err_u: 3.1260, rel_err_x: 0.4423
# Epoch 2050 | Loss: 0.424188 | rel_err_u: 3.1011, rel_err_x: 0.4388
# Epoch 2100 | Loss: 0.420411 | rel_err_u: 3.0760, rel_err_x: 0.4353
# Epoch 2150 | Loss: 0.416631 | rel_err_u: 3.0505, rel_err_x: 0.4317
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 2200 | Loss: 0.412849 | rel_err_u: 3.0248, rel_err_x: 0.4281
# Epoch 2250 | Loss: 0.409067 | rel_err_u: 2.9987, rel_err_x: 0.4244
# Epoch 2300 | Loss: 0.405285 | rel_err_u: 2.9724, rel_err_x: 0.4207
# Epoch 2350 | Loss: 0.401504 | rel_err_u: 2.9458, rel_err_x: 0.4169
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 2400 | Loss: 0.397727 | rel_err_u: 2.9190, rel_err_x: 0.4130
# Epoch 2450 | Loss: 0.393954 | rel_err_u: 2.8918, rel_err_x: 0.4092
# Epoch 2500 | Loss: 0.390186 | rel_err_u: 2.8645, rel_err_x: 0.4052
# Epoch 2550 | Loss: 0.386425 | rel_err_u: 2.8368, rel_err_x: 0.4013
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 2600 | Loss: 0.382672 | rel_err_u: 2.8090, rel_err_x: 0.3972
# Epoch 2650 | Loss: 0.378928 | rel_err_u: 2.7809, rel_err_x: 0.3932
# Epoch 2700 | Loss: 0.375196 | rel_err_u: 2.7525, rel_err_x: 0.3891
# Epoch 2750 | Loss: 0.371476 | rel_err_u: 2.7239, rel_err_x: 0.3849
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 2800 | Loss: 0.367769 | rel_err_u: 2.6952, rel_err_x: 0.3807
# Epoch 2850 | Loss: 0.364078 | rel_err_u: 2.6662, rel_err_x: 0.3765
# Epoch 2900 | Loss: 0.360403 | rel_err_u: 2.6369, rel_err_x: 0.3722
# Epoch 2950 | Loss: 0.356746 | rel_err_u: 2.6075, rel_err_x: 0.3679
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 3000 | Loss: 0.353109 | rel_err_u: 2.5779, rel_err_x: 0.3635
# Epoch 3050 | Loss: 0.349492 | rel_err_u: 2.5481, rel_err_x: 0.3591
# Epoch 3100 | Loss: 0.345897 | rel_err_u: 2.5182, rel_err_x: 0.3547
# Epoch 3150 | Loss: 0.342326 | rel_err_u: 2.4880, rel_err_x: 0.3502
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 3200 | Loss: 0.338781 | rel_err_u: 2.4578, rel_err_x: 0.3457
# Epoch 3250 | Loss: 0.335261 | rel_err_u: 2.4273, rel_err_x: 0.3412
# Epoch 3300 | Loss: 0.331770 | rel_err_u: 2.3967, rel_err_x: 0.3366
# Epoch 3350 | Loss: 0.328308 | rel_err_u: 2.3660, rel_err_x: 0.3320
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 3400 | Loss: 0.324876 | rel_err_u: 2.3351, rel_err_x: 0.3274
# Epoch 3450 | Loss: 0.321477 | rel_err_u: 2.3041, rel_err_x: 0.3227
# Epoch 3500 | Loss: 0.318111 | rel_err_u: 2.2730, rel_err_x: 0.3181
# Epoch 3550 | Loss: 0.314780 | rel_err_u: 2.2419, rel_err_x: 0.3134
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 3600 | Loss: 0.311485 | rel_err_u: 2.2106, rel_err_x: 0.3086
# Epoch 3650 | Loss: 0.308228 | rel_err_u: 2.1793, rel_err_x: 0.3039
# Epoch 3700 | Loss: 0.305011 | rel_err_u: 2.1478, rel_err_x: 0.2991
# Epoch 3750 | Loss: 0.301833 | rel_err_u: 2.1164, rel_err_x: 0.2943
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 3800 | Loss: 0.298699 | rel_err_u: 2.0849, rel_err_x: 0.2895
# Epoch 3850 | Loss: 0.295607 | rel_err_u: 2.0534, rel_err_x: 0.2847
# Epoch 3900 | Loss: 0.292561 | rel_err_u: 2.0219, rel_err_x: 0.2799
# Epoch 3950 | Loss: 0.289561 | rel_err_u: 1.9904, rel_err_x: 0.2750
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 4000 | Loss: 0.286610 | rel_err_u: 1.9590, rel_err_x: 0.2702
# Epoch 4050 | Loss: 0.283708 | rel_err_u: 1.9275, rel_err_x: 0.2653
# Epoch 4100 | Loss: 0.280857 | rel_err_u: 1.8962, rel_err_x: 0.2605
# Epoch 4150 | Loss: 0.278058 | rel_err_u: 1.8649, rel_err_x: 0.2557
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 4200 | Loss: 0.275314 | rel_err_u: 1.8337, rel_err_x: 0.2508
# Epoch 4250 | Loss: 0.272624 | rel_err_u: 1.8027, rel_err_x: 0.2460
# Epoch 4300 | Loss: 0.269990 | rel_err_u: 1.7718, rel_err_x: 0.2412
# Epoch 4350 | Loss: 0.267412 | rel_err_u: 1.7410, rel_err_x: 0.2365
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 4400 | Loss: 0.264892 | rel_err_u: 1.7104, rel_err_x: 0.2317
# Epoch 4450 | Loss: 0.262430 | rel_err_u: 1.6799, rel_err_x: 0.2270
# Epoch 4500 | Loss: 0.260026 | rel_err_u: 1.6497, rel_err_x: 0.2223
# Epoch 4550 | Loss: 0.257680 | rel_err_u: 1.6196, rel_err_x: 0.2176
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 4600 | Loss: 0.255392 | rel_err_u: 1.5898, rel_err_x: 0.2130
# Epoch 4650 | Loss: 0.253161 | rel_err_u: 1.5601, rel_err_x: 0.2084
# Epoch 4700 | Loss: 0.250986 | rel_err_u: 1.5307, rel_err_x: 0.2038
# Epoch 4750 | Loss: 0.248866 | rel_err_u: 1.5014, rel_err_x: 0.1993
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 4800 | Loss: 0.246801 | rel_err_u: 1.4724, rel_err_x: 0.1948
# Epoch 4850 | Loss: 0.244788 | rel_err_u: 1.4435, rel_err_x: 0.1904
# Epoch 4900 | Loss: 0.242826 | rel_err_u: 1.4149, rel_err_x: 0.1860
# Epoch 4950 | Loss: 0.240914 | rel_err_u: 1.3864, rel_err_x: 0.1816
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 5000 | Loss: 0.239050 | rel_err_u: 1.3581, rel_err_x: 0.1773
# Epoch 5050 | Loss: 0.237234 | rel_err_u: 1.3300, rel_err_x: 0.1730
# Epoch 5100 | Loss: 0.235462 | rel_err_u: 1.3021, rel_err_x: 0.1688
# Epoch 5150 | Loss: 0.233735 | rel_err_u: 1.2744, rel_err_x: 0.1646
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 5200 | Loss: 0.232051 | rel_err_u: 1.2468, rel_err_x: 0.1604
# Epoch 5250 | Loss: 0.230410 | rel_err_u: 1.2193, rel_err_x: 0.1562
# Epoch 5300 | Loss: 0.228809 | rel_err_u: 1.1920, rel_err_x: 0.1521
# Epoch 5350 | Loss: 0.227249 | rel_err_u: 1.1649, rel_err_x: 0.1481
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 5400 | Loss: 0.225730 | rel_err_u: 1.1379, rel_err_x: 0.1440
# Epoch 5450 | Loss: 0.224250 | rel_err_u: 1.1111, rel_err_x: 0.1400
# Epoch 5500 | Loss: 0.222810 | rel_err_u: 1.0845, rel_err_x: 0.1360
# Epoch 5550 | Loss: 0.221409 | rel_err_u: 1.0580, rel_err_x: 0.1321
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 5600 | Loss: 0.220049 | rel_err_u: 1.0318, rel_err_x: 0.1282
# Epoch 5650 | Loss: 0.218727 | rel_err_u: 1.0057, rel_err_x: 0.1243
# Epoch 5700 | Loss: 0.217446 | rel_err_u: 0.9798, rel_err_x: 0.1205
# Epoch 5750 | Loss: 0.216205 | rel_err_u: 0.9542, rel_err_x: 0.1167
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 5800 | Loss: 0.215004 | rel_err_u: 0.9288, rel_err_x: 0.1130
# Epoch 5850 | Loss: 0.213843 | rel_err_u: 0.9037, rel_err_x: 0.1093
# Epoch 5900 | Loss: 0.212723 | rel_err_u: 0.8788, rel_err_x: 0.1056
# Epoch 5950 | Loss: 0.211643 | rel_err_u: 0.8542, rel_err_x: 0.1020
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 6000 | Loss: 0.210604 | rel_err_u: 0.8299, rel_err_x: 0.0985
# Epoch 6050 | Loss: 0.209606 | rel_err_u: 0.8060, rel_err_x: 0.0950
# Epoch 6100 | Loss: 0.208649 | rel_err_u: 0.7824, rel_err_x: 0.0916
# Epoch 6150 | Loss: 0.207731 | rel_err_u: 0.7591, rel_err_x: 0.0882
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 6200 | Loss: 0.206853 | rel_err_u: 0.7362, rel_err_x: 0.0849
# Epoch 6250 | Loss: 0.206015 | rel_err_u: 0.7136, rel_err_x: 0.0817
# Epoch 6300 | Loss: 0.205215 | rel_err_u: 0.6915, rel_err_x: 0.0785
# Epoch 6350 | Loss: 0.204454 | rel_err_u: 0.6697, rel_err_x: 0.0754
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 6400 | Loss: 0.203729 | rel_err_u: 0.6484, rel_err_x: 0.0724
# Epoch 6450 | Loss: 0.203041 | rel_err_u: 0.6275, rel_err_x: 0.0695
# Epoch 6500 | Loss: 0.202388 | rel_err_u: 0.6070, rel_err_x: 0.0666
# Epoch 6550 | Loss: 0.201770 | rel_err_u: 0.5869, rel_err_x: 0.0639
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 6600 | Loss: 0.201184 | rel_err_u: 0.5672, rel_err_x: 0.0612
# Epoch 6650 | Loss: 0.200631 | rel_err_u: 0.5479, rel_err_x: 0.0586
# Epoch 6700 | Loss: 0.200108 | rel_err_u: 0.5291, rel_err_x: 0.0560
# Epoch 6750 | Loss: 0.199614 | rel_err_u: 0.5107, rel_err_x: 0.0536
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 6800 | Loss: 0.199148 | rel_err_u: 0.4926, rel_err_x: 0.0512
# Epoch 6850 | Loss: 0.198709 | rel_err_u: 0.4750, rel_err_x: 0.0490
# Epoch 6900 | Loss: 0.198295 | rel_err_u: 0.4578, rel_err_x: 0.0467
# Epoch 6950 | Loss: 0.197906 | rel_err_u: 0.4410, rel_err_x: 0.0446
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 7000 | Loss: 0.197540 | rel_err_u: 0.4246, rel_err_x: 0.0426
# Epoch 7050 | Loss: 0.197196 | rel_err_u: 0.4085, rel_err_x: 0.0406
# Epoch 7100 | Loss: 0.196872 | rel_err_u: 0.3929, rel_err_x: 0.0387
# Epoch 7150 | Loss: 0.196568 | rel_err_u: 0.3776, rel_err_x: 0.0368
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 7200 | Loss: 0.196283 | rel_err_u: 0.3626, rel_err_x: 0.0350
# Epoch 7250 | Loss: 0.196016 | rel_err_u: 0.3481, rel_err_x: 0.0333
# Epoch 7300 | Loss: 0.195765 | rel_err_u: 0.3339, rel_err_x: 0.0317
# Epoch 7350 | Loss: 0.195531 | rel_err_u: 0.3200, rel_err_x: 0.0301
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 7400 | Loss: 0.195312 | rel_err_u: 0.3065, rel_err_x: 0.0285
# Epoch 7450 | Loss: 0.195107 | rel_err_u: 0.2933, rel_err_x: 0.0271
# Epoch 7500 | Loss: 0.194916 | rel_err_u: 0.2805, rel_err_x: 0.0257
# Epoch 7550 | Loss: 0.194739 | rel_err_u: 0.2680, rel_err_x: 0.0243
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 7600 | Loss: 0.194573 | rel_err_u: 0.2558, rel_err_x: 0.0230
# Epoch 7650 | Loss: 0.194419 | rel_err_u: 0.2440, rel_err_x: 0.0217
# Epoch 7700 | Loss: 0.194277 | rel_err_u: 0.2325, rel_err_x: 0.0205
# Epoch 7750 | Loss: 0.194145 | rel_err_u: 0.2214, rel_err_x: 0.0193
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 7800 | Loss: 0.194023 | rel_err_u: 0.2105, rel_err_x: 0.0182
# Epoch 7850 | Loss: 0.193910 | rel_err_u: 0.2001, rel_err_x: 0.0171
# Epoch 7900 | Loss: 0.193807 | rel_err_u: 0.1899, rel_err_x: 0.0161
# Epoch 7950 | Loss: 0.193711 | rel_err_u: 0.1801, rel_err_x: 0.0151
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 8000 | Loss: 0.193624 | rel_err_u: 0.1706, rel_err_x: 0.0141
# Epoch 8050 | Loss: 0.193544 | rel_err_u: 0.1615, rel_err_x: 0.0132
# Epoch 8100 | Loss: 0.193472 | rel_err_u: 0.1527, rel_err_x: 0.0124
# Epoch 8150 | Loss: 0.193405 | rel_err_u: 0.1442, rel_err_x: 0.0116
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 8200 | Loss: 0.193345 | rel_err_u: 0.1360, rel_err_x: 0.0108
# Epoch 8250 | Loss: 0.193290 | rel_err_u: 0.1282, rel_err_x: 0.0100
# Epoch 8300 | Loss: 0.193241 | rel_err_u: 0.1207, rel_err_x: 0.0093
# Epoch 8350 | Loss: 0.193197 | rel_err_u: 0.1135, rel_err_x: 0.0086
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 8400 | Loss: 0.193157 | rel_err_u: 0.1066, rel_err_x: 0.0080
# Epoch 8450 | Loss: 0.193121 | rel_err_u: 0.1000, rel_err_x: 0.0074
# Epoch 8500 | Loss: 0.193089 | rel_err_u: 0.0937, rel_err_x: 0.0068
# Epoch 8550 | Loss: 0.193060 | rel_err_u: 0.0878, rel_err_x: 0.0063
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 8600 | Loss: 0.193035 | rel_err_u: 0.0821, rel_err_x: 0.0058
# Epoch 8650 | Loss: 0.193012 | rel_err_u: 0.0768, rel_err_x: 0.0053
# Epoch 8700 | Loss: 0.192993 | rel_err_u: 0.0717, rel_err_x: 0.0048
# Epoch 8750 | Loss: 0.192975 | rel_err_u: 0.0670, rel_err_x: 0.0044
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 8800 | Loss: 0.192960 | rel_err_u: 0.0625, rel_err_x: 0.0040
# Epoch 8850 | Loss: 0.192946 | rel_err_u: 0.0582, rel_err_x: 0.0037
# Epoch 8900 | Loss: 0.192935 | rel_err_u: 0.0543, rel_err_x: 0.0033
# Epoch 8950 | Loss: 0.192925 | rel_err_u: 0.0506, rel_err_x: 0.0030
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 9000 | Loss: 0.192916 | rel_err_u: 0.0472, rel_err_x: 0.0027
# Epoch 9050 | Loss: 0.192908 | rel_err_u: 0.0440, rel_err_x: 0.0024
# Epoch 9100 | Loss: 0.192902 | rel_err_u: 0.0411, rel_err_x: 0.0022
# Epoch 9150 | Loss: 0.192896 | rel_err_u: 0.0385, rel_err_x: 0.0019
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 9200 | Loss: 0.192891 | rel_err_u: 0.0360, rel_err_x: 0.0017
# Epoch 9250 | Loss: 0.192887 | rel_err_u: 0.0338, rel_err_x: 0.0015
# Epoch 9300 | Loss: 0.192884 | rel_err_u: 0.0318, rel_err_x: 0.0013
# Epoch 9350 | Loss: 0.192881 | rel_err_u: 0.0300, rel_err_x: 0.0012
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 9400 | Loss: 0.192879 | rel_err_u: 0.0284, rel_err_x: 0.0010
# Epoch 9450 | Loss: 0.192877 | rel_err_u: 0.0270, rel_err_x: 0.0009
# Epoch 9500 | Loss: 0.192875 | rel_err_u: 0.0258, rel_err_x: 0.0007
# Epoch 9550 | Loss: 0.192874 | rel_err_u: 0.0247, rel_err_x: 0.0006
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 9600 | Loss: 0.192873 | rel_err_u: 0.0238, rel_err_x: 0.0005
# Epoch 9650 | Loss: 0.192872 | rel_err_u: 0.0230, rel_err_x: 0.0005
# Epoch 9700 | Loss: 0.192871 | rel_err_u: 0.0223, rel_err_x: 0.0004
# Epoch 9750 | Loss: 0.192870 | rel_err_u: 0.0217, rel_err_x: 0.0004
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 9800 | Loss: 0.192870 | rel_err_u: 0.0213, rel_err_x: 0.0003
# Epoch 9850 | Loss: 0.192870 | rel_err_u: 0.0209, rel_err_x: 0.0003
# Epoch 9900 | Loss: 0.192869 | rel_err_u: 0.0206, rel_err_x: 0.0003
# Epoch 9950 | Loss: 0.192869 | rel_err_u: 0.0203, rel_err_x: 0.0003
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 10000 | Loss: 0.192869 | rel_err_u: 0.0201, rel_err_x: 0.0003
# Epoch 10050 | Loss: 0.192869 | rel_err_u: 0.0199, rel_err_x: 0.0003
# Epoch 10100 | Loss: 0.192869 | rel_err_u: 0.0198, rel_err_x: 0.0003
# Epoch 10150 | Loss: 0.192869 | rel_err_u: 0.0196, rel_err_x: 0.0004
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 10200 | Loss: 0.192868 | rel_err_u: 0.0195, rel_err_x: 0.0004
# Epoch 10250 | Loss: 0.192868 | rel_err_u: 0.0195, rel_err_x: 0.0004
# Epoch 10300 | Loss: 0.192868 | rel_err_u: 0.0194, rel_err_x: 0.0004
# Epoch 10350 | Loss: 0.192868 | rel_err_u: 0.0194, rel_err_x: 0.0004
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 10400 | Loss: 0.192868 | rel_err_u: 0.0193, rel_err_x: 0.0004
# Epoch 10450 | Loss: 0.192868 | rel_err_u: 0.0193, rel_err_x: 0.0004
# Epoch 10500 | Loss: 0.192868 | rel_err_u: 0.0193, rel_err_x: 0.0005
# Epoch 10550 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 10600 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10650 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10700 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10750 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 10800 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10850 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10900 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 10950 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 11000 | Loss: 0.192868 | rel_err_u: 0.0192, rel_err_x: 0.0005
# Epoch 11050 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11100 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11150 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 11200 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11250 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11300 | Loss: 0.192869 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11350 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 11400 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11450 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11500 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11550 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 11600 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11650 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11700 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11750 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 11800 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11850 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11900 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Epoch 11950 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005
# Plot saved to found_trajectories/linear/deeponet/plot.png
# Epoch 12000 | Loss: 0.192868 | rel_err_u: 0.0191, rel_err_x: 0.0005

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.19274890422821045

# %% [markdown]
# <image src="found_trajectories/linear/deeponet/plot.png" width = "600">

# %% [markdown]
# Let's repeat the same process for all other problems with DeepONet

# %% [markdown]
# # Control problem with Oscillatory Forcing

# %%
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

ckpt = torch.load("trained_models/oscillatory/deeponet/unsupervised/epoch[1500]_model_time_[20250717_222232]_loss_[0.0065].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

initial_guess = torch.zeros((1, m), dtype=torch.float32, device=device, requires_grad=True)

w = [100, 1, 1, 0, 100]

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'oscillatory', initial_guess,
    lr=0.001,
    architecture="deeponet",  
    w=w,
    num_epochs=12000,
    m=m,
    device=device, logging = True
)
# Out:
# Epoch   50 | Loss: 96.521370 | rel_err_u: 10.6354, rel_err_x: 0.0509
# Epoch  100 | Loss: 93.286140 | rel_err_u: 19.8667, rel_err_x: 0.1034
# Epoch  150 | Loss: 90.956848 | rel_err_u: 27.8460, rel_err_x: 0.1533
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch  200 | Loss: 89.237671 | rel_err_u: 34.8885, rel_err_x: 0.1994
# Epoch  250 | Loss: 87.914474 | rel_err_u: 41.3137, rel_err_x: 0.2408
# Epoch  300 | Loss: 86.835518 | rel_err_u: 47.3954, rel_err_x: 0.2769
# Epoch  350 | Loss: 85.885376 | rel_err_u: 53.3890, rel_err_x: 0.3063
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch  400 | Loss: 84.964920 | rel_err_u: 59.5218, rel_err_x: 0.3280
# Epoch  450 | Loss: 83.984947 | rel_err_u: 65.9549, rel_err_x: 0.3438
# Epoch  500 | Loss: 82.912613 | rel_err_u: 72.6332, rel_err_x: 0.3616
# Epoch  550 | Loss: 81.815392 | rel_err_u: 79.2246, rel_err_x: 0.3874
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch  600 | Loss: 80.779320 | rel_err_u: 85.4767, rel_err_x: 0.4154
# Epoch  650 | Loss: 79.839745 | rel_err_u: 91.3275, rel_err_x: 0.4385
# Epoch  700 | Loss: 78.988930 | rel_err_u: 96.7894, rel_err_x: 0.4554
# Epoch  750 | Loss: 78.204445 | rel_err_u: 101.9047, rel_err_x: 0.4677
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch  800 | Loss: 77.464279 | rel_err_u: 106.7243, rel_err_x: 0.4766
# Epoch  850 | Loss: 76.752441 | rel_err_u: 111.2943, rel_err_x: 0.4825
# Epoch  900 | Loss: 76.063034 | rel_err_u: 115.6461, rel_err_x: 0.4855
# Epoch  950 | Loss: 75.400200 | rel_err_u: 119.7951, rel_err_x: 0.4854
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 1000 | Loss: 74.772598 | rel_err_u: 123.7505, rel_err_x: 0.4824
# Epoch 1050 | Loss: 74.185677 | rel_err_u: 127.5311, rel_err_x: 0.4768
# Epoch 1100 | Loss: 73.637161 | rel_err_u: 131.1727, rel_err_x: 0.4695
# Epoch 1150 | Loss: 73.117180 | rel_err_u: 134.7270, rel_err_x: 0.4614
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 1200 | Loss: 72.607979 | rel_err_u: 138.2619, rel_err_x: 0.4533
# Epoch 1250 | Loss: 72.076881 | rel_err_u: 141.8723, rel_err_x: 0.4465
# Epoch 1300 | Loss: 71.459892 | rel_err_u: 145.6927, rel_err_x: 0.4433
# Epoch 1350 | Loss: 70.695312 | rel_err_u: 149.7973, rel_err_x: 0.4466
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 1400 | Loss: 69.894005 | rel_err_u: 153.9012, rel_err_x: 0.4538
# Epoch 1450 | Loss: 69.223808 | rel_err_u: 157.6139, rel_err_x: 0.4593
# Epoch 1500 | Loss: 68.689201 | rel_err_u: 160.9481, rel_err_x: 0.4639
# Epoch 1550 | Loss: 68.245796 | rel_err_u: 164.0529, rel_err_x: 0.4683
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 1600 | Loss: 67.862198 | rel_err_u: 167.0196, rel_err_x: 0.4724
# Epoch 1650 | Loss: 67.519554 | rel_err_u: 169.8972, rel_err_x: 0.4763
# Epoch 1700 | Loss: 67.206322 | rel_err_u: 172.7142, rel_err_x: 0.4798
# Epoch 1750 | Loss: 66.915543 | rel_err_u: 175.4878, rel_err_x: 0.4832
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 1800 | Loss: 66.643105 | rel_err_u: 178.2272, rel_err_x: 0.4864
# Epoch 1850 | Loss: 66.386688 | rel_err_u: 180.9355, rel_err_x: 0.4896
# Epoch 1900 | Loss: 66.144958 | rel_err_u: 183.6125, rel_err_x: 0.4928
# Epoch 1950 | Loss: 65.916885 | rel_err_u: 186.2563, rel_err_x: 0.4960
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 2000 | Loss: 65.701393 | rel_err_u: 188.8655, rel_err_x: 0.4993
# Epoch 2050 | Loss: 65.497284 | rel_err_u: 191.4402, rel_err_x: 0.5025
# Epoch 2100 | Loss: 65.303261 | rel_err_u: 193.9820, rel_err_x: 0.5058
# Epoch 2150 | Loss: 65.118027 | rel_err_u: 196.4935, rel_err_x: 0.5090
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 2200 | Loss: 64.940269 | rel_err_u: 198.9784, rel_err_x: 0.5121
# Epoch 2250 | Loss: 64.768661 | rel_err_u: 201.4410, rel_err_x: 0.5150
# Epoch 2300 | Loss: 64.601875 | rel_err_u: 203.8862, rel_err_x: 0.5177
# Epoch 2350 | Loss: 64.438560 | rel_err_u: 206.3194, rel_err_x: 0.5201
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 2400 | Loss: 64.277359 | rel_err_u: 208.7463, rel_err_x: 0.5223
# Epoch 2450 | Loss: 64.117149 | rel_err_u: 211.1729, rel_err_x: 0.5242
# Epoch 2500 | Loss: 63.957333 | rel_err_u: 213.6041, rel_err_x: 0.5260
# Epoch 2550 | Loss: 63.798351 | rel_err_u: 216.0432, rel_err_x: 0.5276
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 2600 | Loss: 63.641804 | rel_err_u: 218.4905, rel_err_x: 0.5292
# Epoch 2650 | Loss: 63.489876 | rel_err_u: 220.9434, rel_err_x: 0.5308
# Epoch 2700 | Loss: 63.344543 | rel_err_u: 223.3978, rel_err_x: 0.5327
# Epoch 2750 | Loss: 63.206882 | rel_err_u: 225.8495, rel_err_x: 0.5346
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 2800 | Loss: 63.077061 | rel_err_u: 228.2947, rel_err_x: 0.5367
# Epoch 2850 | Loss: 62.954559 | rel_err_u: 230.7309, rel_err_x: 0.5388
# Epoch 2900 | Loss: 62.838600 | rel_err_u: 233.1567, rel_err_x: 0.5411
# Epoch 2950 | Loss: 62.728310 | rel_err_u: 235.5715, rel_err_x: 0.5433
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 3000 | Loss: 62.622898 | rel_err_u: 237.9758, rel_err_x: 0.5457
# Epoch 3050 | Loss: 62.521568 | rel_err_u: 240.3707, rel_err_x: 0.5481
# Epoch 3100 | Loss: 62.423695 | rel_err_u: 242.7579, rel_err_x: 0.5508
# Epoch 3150 | Loss: 62.328663 | rel_err_u: 245.1397, rel_err_x: 0.5536
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 3200 | Loss: 62.235981 | rel_err_u: 247.5183, rel_err_x: 0.5566
# Epoch 3250 | Loss: 62.145252 | rel_err_u: 249.8962, rel_err_x: 0.5599
# Epoch 3300 | Loss: 62.056107 | rel_err_u: 252.2758, rel_err_x: 0.5634
# Epoch 3350 | Loss: 61.968273 | rel_err_u: 254.6593, rel_err_x: 0.5673
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 3400 | Loss: 61.881535 | rel_err_u: 257.0487, rel_err_x: 0.5716
# Epoch 3450 | Loss: 61.795750 | rel_err_u: 259.4455, rel_err_x: 0.5762
# Epoch 3500 | Loss: 61.710861 | rel_err_u: 261.8508, rel_err_x: 0.5811
# Epoch 3550 | Loss: 61.626926 | rel_err_u: 264.2652, rel_err_x: 0.5864
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 3600 | Loss: 61.544071 | rel_err_u: 266.6889, rel_err_x: 0.5921
# Epoch 3650 | Loss: 61.462517 | rel_err_u: 269.1215, rel_err_x: 0.5980
# Epoch 3700 | Loss: 61.382549 | rel_err_u: 271.5621, rel_err_x: 0.6041
# Epoch 3750 | Loss: 61.304413 | rel_err_u: 274.0101, rel_err_x: 0.6104
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 3800 | Loss: 61.228352 | rel_err_u: 276.4643, rel_err_x: 0.6167
# Epoch 3850 | Loss: 61.154472 | rel_err_u: 278.9241, rel_err_x: 0.6230
# Epoch 3900 | Loss: 61.082737 | rel_err_u: 281.3891, rel_err_x: 0.6292
# Epoch 3950 | Loss: 61.013008 | rel_err_u: 283.8591, rel_err_x: 0.6353
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 4000 | Loss: 60.944969 | rel_err_u: 286.3347, rel_err_x: 0.6413
# Epoch 4050 | Loss: 60.878185 | rel_err_u: 288.8164, rel_err_x: 0.6471
# Epoch 4100 | Loss: 60.812195 | rel_err_u: 291.3051, rel_err_x: 0.6526
# Epoch 4150 | Loss: 60.746456 | rel_err_u: 293.8012, rel_err_x: 0.6579
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 4200 | Loss: 60.680645 | rel_err_u: 296.3047, rel_err_x: 0.6629
# Epoch 4250 | Loss: 60.614765 | rel_err_u: 298.8142, rel_err_x: 0.6678
# Epoch 4300 | Loss: 60.549183 | rel_err_u: 301.3276, rel_err_x: 0.6726
# Epoch 4350 | Loss: 60.484467 | rel_err_u: 303.8441, rel_err_x: 0.6774
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 4400 | Loss: 60.421055 | rel_err_u: 306.3647, rel_err_x: 0.6825
# Epoch 4450 | Loss: 60.358940 | rel_err_u: 308.8922, rel_err_x: 0.6880
# Epoch 4500 | Loss: 60.297901 | rel_err_u: 311.4294, rel_err_x: 0.6939
# Epoch 4550 | Loss: 60.237419 | rel_err_u: 313.9784, rel_err_x: 0.7003
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 4600 | Loss: 60.176991 | rel_err_u: 316.5388, rel_err_x: 0.7072
# Epoch 4650 | Loss: 60.116264 | rel_err_u: 319.1058, rel_err_x: 0.7145
# Epoch 4700 | Loss: 60.055573 | rel_err_u: 321.6671, rel_err_x: 0.7222
# Epoch 4750 | Loss: 59.996078 | rel_err_u: 324.2032, rel_err_x: 0.7303
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 4800 | Loss: 59.939194 | rel_err_u: 326.6936, rel_err_x: 0.7389
# Epoch 4850 | Loss: 59.885704 | rel_err_u: 329.1262, rel_err_x: 0.7481
# Epoch 4900 | Loss: 59.835552 | rel_err_u: 331.5005, rel_err_x: 0.7579
# Epoch 4950 | Loss: 59.788071 | rel_err_u: 333.8246, rel_err_x: 0.7683
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 5000 | Loss: 59.742569 | rel_err_u: 336.1092, rel_err_x: 0.7792
# Epoch 5050 | Loss: 59.698441 | rel_err_u: 338.3650, rel_err_x: 0.7905
# Epoch 5100 | Loss: 59.655151 | rel_err_u: 340.6014, rel_err_x: 0.8020
# Epoch 5150 | Loss: 59.612335 | rel_err_u: 342.8265, rel_err_x: 0.8139
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 5200 | Loss: 59.569572 | rel_err_u: 345.0478, rel_err_x: 0.8259
# Epoch 5250 | Loss: 59.526505 | rel_err_u: 347.2720, rel_err_x: 0.8383
# Epoch 5300 | Loss: 59.482738 | rel_err_u: 349.5058, rel_err_x: 0.8509
# Epoch 5350 | Loss: 59.437870 | rel_err_u: 351.7560, rel_err_x: 0.8637
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 5400 | Loss: 59.391464 | rel_err_u: 354.0292, rel_err_x: 0.8768
# Epoch 5450 | Loss: 59.343147 | rel_err_u: 356.3321, rel_err_x: 0.8901
# Epoch 5500 | Loss: 59.292568 | rel_err_u: 358.6712, rel_err_x: 0.9037
# Epoch 5550 | Loss: 59.239487 | rel_err_u: 361.0525, rel_err_x: 0.9175
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 5600 | Loss: 59.183777 | rel_err_u: 363.4813, rel_err_x: 0.9316
# Epoch 5650 | Loss: 59.125385 | rel_err_u: 365.9621, rel_err_x: 0.9458
# Epoch 5700 | Loss: 59.064301 | rel_err_u: 368.4966, rel_err_x: 0.9601
# Epoch 5750 | Loss: 59.000748 | rel_err_u: 371.0796, rel_err_x: 0.9744
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 5800 | Loss: 58.935448 | rel_err_u: 373.6897, rel_err_x: 0.9886
# Epoch 5850 | Loss: 58.870228 | rel_err_u: 376.2814, rel_err_x: 1.0026
# Epoch 5900 | Loss: 58.807777 | rel_err_u: 378.7882, rel_err_x: 1.0160
# Epoch 5950 | Loss: 58.750469 | rel_err_u: 381.1471, rel_err_x: 1.0287
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 6000 | Loss: 58.699467 | rel_err_u: 383.3226, rel_err_x: 1.0407
# Epoch 6050 | Loss: 58.654900 | rel_err_u: 385.3090, rel_err_x: 1.0518
# Epoch 6100 | Loss: 58.616192 | rel_err_u: 387.1196, rel_err_x: 1.0621
# Epoch 6150 | Loss: 58.582340 | rel_err_u: 388.7753, rel_err_x: 1.0717
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 6200 | Loss: 58.552391 | rel_err_u: 390.2986, rel_err_x: 1.0805
# Epoch 6250 | Loss: 58.525463 | rel_err_u: 391.7090, rel_err_x: 1.0888
# Epoch 6300 | Loss: 58.500908 | rel_err_u: 393.0226, rel_err_x: 1.0964
# Epoch 6350 | Loss: 58.478249 | rel_err_u: 394.2522, rel_err_x: 1.1036
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 6400 | Loss: 58.457092 | rel_err_u: 395.4081, rel_err_x: 1.1104
# Epoch 6450 | Loss: 58.437176 | rel_err_u: 396.4986, rel_err_x: 1.1167
# Epoch 6500 | Loss: 58.418343 | rel_err_u: 397.5309, rel_err_x: 1.1227
# Epoch 6550 | Loss: 58.400486 | rel_err_u: 398.5109, rel_err_x: 1.1283
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 6600 | Loss: 58.383621 | rel_err_u: 399.4444, rel_err_x: 1.1336
# Epoch 6650 | Loss: 58.367786 | rel_err_u: 400.3365, rel_err_x: 1.1386
# Epoch 6700 | Loss: 58.353035 | rel_err_u: 401.1920, rel_err_x: 1.1434
# Epoch 6750 | Loss: 58.339409 | rel_err_u: 402.0155, rel_err_x: 1.1481
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 6800 | Loss: 58.326916 | rel_err_u: 402.8105, rel_err_x: 1.1525
# Epoch 6850 | Loss: 58.315510 | rel_err_u: 403.5803, rel_err_x: 1.1568
# Epoch 6900 | Loss: 58.305111 | rel_err_u: 404.3275, rel_err_x: 1.1610
# Epoch 6950 | Loss: 58.295616 | rel_err_u: 405.0539, rel_err_x: 1.1651
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 7000 | Loss: 58.286919 | rel_err_u: 405.7616, rel_err_x: 1.1692
# Epoch 7050 | Loss: 58.278893 | rel_err_u: 406.4522, rel_err_x: 1.1732
# Epoch 7100 | Loss: 58.271454 | rel_err_u: 407.1279, rel_err_x: 1.1771
# Epoch 7150 | Loss: 58.264496 | rel_err_u: 407.7908, rel_err_x: 1.1809
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 7200 | Loss: 58.257946 | rel_err_u: 408.4436, rel_err_x: 1.1848
# Epoch 7250 | Loss: 58.251736 | rel_err_u: 409.0888, rel_err_x: 1.1886
# Epoch 7300 | Loss: 58.245800 | rel_err_u: 409.7295, rel_err_x: 1.1924
# Epoch 7350 | Loss: 58.240067 | rel_err_u: 410.3685, rel_err_x: 1.1963
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 7400 | Loss: 58.234516 | rel_err_u: 411.0088, rel_err_x: 1.2001
# Epoch 7450 | Loss: 58.229069 | rel_err_u: 411.6532, rel_err_x: 1.2040
# Epoch 7500 | Loss: 58.223728 | rel_err_u: 412.3044, rel_err_x: 1.2080
# Epoch 7550 | Loss: 58.218433 | rel_err_u: 412.9651, rel_err_x: 1.2120
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 7600 | Loss: 58.213192 | rel_err_u: 413.6375, rel_err_x: 1.2161
# Epoch 7650 | Loss: 58.207962 | rel_err_u: 414.3235, rel_err_x: 1.2202
# Epoch 7700 | Loss: 58.202744 | rel_err_u: 415.0247, rel_err_x: 1.2245
# Epoch 7750 | Loss: 58.197548 | rel_err_u: 415.7422, rel_err_x: 1.2289
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 7800 | Loss: 58.192348 | rel_err_u: 416.4764, rel_err_x: 1.2334
# Epoch 7850 | Loss: 58.187183 | rel_err_u: 417.2274, rel_err_x: 1.2380
# Epoch 7900 | Loss: 58.182053 | rel_err_u: 417.9941, rel_err_x: 1.2427
# Epoch 7950 | Loss: 58.176979 | rel_err_u: 418.7756, rel_err_x: 1.2475
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 8000 | Loss: 58.171997 | rel_err_u: 419.5700, rel_err_x: 1.2524
# Epoch 8050 | Loss: 58.167095 | rel_err_u: 420.3747, rel_err_x: 1.2573
# Epoch 8100 | Loss: 58.162281 | rel_err_u: 421.1876, rel_err_x: 1.2624
# Epoch 8150 | Loss: 58.157562 | rel_err_u: 422.0056, rel_err_x: 1.2675
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 8200 | Loss: 58.152931 | rel_err_u: 422.8272, rel_err_x: 1.2726
# Epoch 8250 | Loss: 58.148354 | rel_err_u: 423.6500, rel_err_x: 1.2777
# Epoch 8300 | Loss: 58.143810 | rel_err_u: 424.4726, rel_err_x: 1.2829
# Epoch 8350 | Loss: 58.139252 | rel_err_u: 425.2938, rel_err_x: 1.2880
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 8400 | Loss: 58.134655 | rel_err_u: 426.1132, rel_err_x: 1.2931
# Epoch 8450 | Loss: 58.130024 | rel_err_u: 426.9300, rel_err_x: 1.2982
# Epoch 8500 | Loss: 58.125362 | rel_err_u: 427.7436, rel_err_x: 1.3031
# Epoch 8550 | Loss: 58.120743 | rel_err_u: 428.5534, rel_err_x: 1.3080
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 8600 | Loss: 58.116184 | rel_err_u: 429.3582, rel_err_x: 1.3127
# Epoch 8650 | Loss: 58.111740 | rel_err_u: 430.1572, rel_err_x: 1.3173
# Epoch 8700 | Loss: 58.107422 | rel_err_u: 430.9489, rel_err_x: 1.3218
# Epoch 8750 | Loss: 58.103233 | rel_err_u: 431.7318, rel_err_x: 1.3261
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 8800 | Loss: 58.099163 | rel_err_u: 432.5038, rel_err_x: 1.3304
# Epoch 8850 | Loss: 58.095207 | rel_err_u: 433.2617, rel_err_x: 1.3345
# Epoch 8900 | Loss: 58.091381 | rel_err_u: 434.0022, rel_err_x: 1.3385
# Epoch 8950 | Loss: 58.087685 | rel_err_u: 434.7203, rel_err_x: 1.3424
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 9000 | Loss: 58.084110 | rel_err_u: 435.4110, rel_err_x: 1.3462
# Epoch 9050 | Loss: 58.080624 | rel_err_u: 436.0692, rel_err_x: 1.3499
# Epoch 9100 | Loss: 58.077171 | rel_err_u: 436.6899, rel_err_x: 1.3534
# Epoch 9150 | Loss: 58.073673 | rel_err_u: 437.2697, rel_err_x: 1.3567
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 9200 | Loss: 58.069950 | rel_err_u: 437.8064, rel_err_x: 1.3598
# Epoch 9250 | Loss: 58.065708 | rel_err_u: 438.3011, rel_err_x: 1.3627
# Epoch 9300 | Loss: 58.060467 | rel_err_u: 438.7592, rel_err_x: 1.3653
# Epoch 9350 | Loss: 58.053600 | rel_err_u: 439.1970, rel_err_x: 1.3678
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 9400 | Loss: 58.044872 | rel_err_u: 439.6477, rel_err_x: 1.3703
# Epoch 9450 | Loss: 58.035206 | rel_err_u: 440.1683, rel_err_x: 1.3731
# Epoch 9500 | Loss: 58.025349 | rel_err_u: 440.8631, rel_err_x: 1.3773
# Epoch 9550 | Loss: 58.011505 | rel_err_u: 442.0036, rel_err_x: 1.3850
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 9600 | Loss: 57.973083 | rel_err_u: 444.2572, rel_err_x: 1.4000
# Epoch 9650 | Loss: 57.915836 | rel_err_u: 447.0205, rel_err_x: 1.4175
# Epoch 9700 | Loss: 57.884605 | rel_err_u: 448.4070, rel_err_x: 1.4271
# Epoch 9750 | Loss: 57.866459 | rel_err_u: 449.0831, rel_err_x: 1.4322
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 9800 | Loss: 57.854500 | rel_err_u: 449.4138, rel_err_x: 1.4348
# Epoch 9850 | Loss: 57.846123 | rel_err_u: 449.5942, rel_err_x: 1.4362
# Epoch 9900 | Loss: 57.840015 | rel_err_u: 449.7184, rel_err_x: 1.4369
# Epoch 9950 | Loss: 57.835438 | rel_err_u: 449.8285, rel_err_x: 1.4373
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 10000 | Loss: 57.831921 | rel_err_u: 449.9423, rel_err_x: 1.4376
# Epoch 10050 | Loss: 57.829178 | rel_err_u: 450.0664, rel_err_x: 1.4377
# Epoch 10100 | Loss: 57.826962 | rel_err_u: 450.2022, rel_err_x: 1.4379
# Epoch 10150 | Loss: 57.825172 | rel_err_u: 450.3490, rel_err_x: 1.4380
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 10200 | Loss: 57.823685 | rel_err_u: 450.5052, rel_err_x: 1.4382
# Epoch 10250 | Loss: 57.822456 | rel_err_u: 450.6693, rel_err_x: 1.4385
# Epoch 10300 | Loss: 57.821400 | rel_err_u: 450.8396, rel_err_x: 1.4387
# Epoch 10350 | Loss: 57.820515 | rel_err_u: 451.0150, rel_err_x: 1.4390
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 10400 | Loss: 57.819756 | rel_err_u: 451.1945, rel_err_x: 1.4394
# Epoch 10450 | Loss: 57.819069 | rel_err_u: 451.3771, rel_err_x: 1.4398
# Epoch 10500 | Loss: 57.818443 | rel_err_u: 451.5624, rel_err_x: 1.4403
# Epoch 10550 | Loss: 57.817871 | rel_err_u: 451.7495, rel_err_x: 1.4408
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 10600 | Loss: 57.817337 | rel_err_u: 451.9373, rel_err_x: 1.4413
# Epoch 10650 | Loss: 57.816837 | rel_err_u: 452.1246, rel_err_x: 1.4419
# Epoch 10700 | Loss: 57.816357 | rel_err_u: 452.3095, rel_err_x: 1.4425
# Epoch 10750 | Loss: 57.815929 | rel_err_u: 452.4903, rel_err_x: 1.4430
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 10800 | Loss: 57.815536 | rel_err_u: 452.6648, rel_err_x: 1.4436
# Epoch 10850 | Loss: 57.815174 | rel_err_u: 452.8311, rel_err_x: 1.4441
# Epoch 10900 | Loss: 57.814869 | rel_err_u: 452.9877, rel_err_x: 1.4446
# Epoch 10950 | Loss: 57.814613 | rel_err_u: 453.1338, rel_err_x: 1.4451
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 11000 | Loss: 57.814392 | rel_err_u: 453.2685, rel_err_x: 1.4455
# Epoch 11050 | Loss: 57.814224 | rel_err_u: 453.3916, rel_err_x: 1.4458
# Epoch 11100 | Loss: 57.814079 | rel_err_u: 453.5033, rel_err_x: 1.4462
# Epoch 11150 | Loss: 57.813969 | rel_err_u: 453.6039, rel_err_x: 1.4465
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 11200 | Loss: 57.813885 | rel_err_u: 453.6938, rel_err_x: 1.4467
# Epoch 11250 | Loss: 57.813812 | rel_err_u: 453.7738, rel_err_x: 1.4469
# Epoch 11300 | Loss: 57.813755 | rel_err_u: 453.8446, rel_err_x: 1.4471
# Epoch 11350 | Loss: 57.813713 | rel_err_u: 453.9070, rel_err_x: 1.4473
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 11400 | Loss: 57.813686 | rel_err_u: 453.9621, rel_err_x: 1.4474
# Epoch 11450 | Loss: 57.813663 | rel_err_u: 454.0103, rel_err_x: 1.4476
# Epoch 11500 | Loss: 57.813637 | rel_err_u: 454.0526, rel_err_x: 1.4477
# Epoch 11550 | Loss: 57.813614 | rel_err_u: 454.0896, rel_err_x: 1.4478
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 11600 | Loss: 57.813614 | rel_err_u: 454.1222, rel_err_x: 1.4479
# Epoch 11650 | Loss: 57.813599 | rel_err_u: 454.1508, rel_err_x: 1.4480
# Epoch 11700 | Loss: 57.813591 | rel_err_u: 454.1759, rel_err_x: 1.4481
# Epoch 11750 | Loss: 57.813591 | rel_err_u: 454.1981, rel_err_x: 1.4481
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 11800 | Loss: 57.813580 | rel_err_u: 454.2176, rel_err_x: 1.4482
# Epoch 11850 | Loss: 57.813568 | rel_err_u: 454.2348, rel_err_x: 1.4482
# Epoch 11900 | Loss: 57.813576 | rel_err_u: 454.2500, rel_err_x: 1.4483
# Epoch 11950 | Loss: 57.813568 | rel_err_u: 454.2634, rel_err_x: 1.4483
# Plot saved to found_trajectories/oscillatory/deeponet/plot.png
# Epoch 12000 | Loss: 57.813572 | rel_err_u: 454.2754, rel_err_x: 1.4484

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 2.029810667037964

# %% [markdown]
# <image src="found_trajectories/oscillatory/deeponet/plot.png" width="600">

# %% [markdown]
# # Control problem with Polynomial Tracking

# %%
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

ckpt = torch.load("trained_models/polynomial_tracking/deeponet/unsupervised/epoch[1300]_model_time_[20250717_222408]_loss_[0.0149].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

w = [200, 1, 1, 2, 0]

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'polynomial_tracking', initial_guess,
    lr=0.001,
    architecture="deeponet",  
    w=w,
    num_epochs=10000,
    m=m,
    device=device, logging = True
)
# Out:
# Epoch   50 | Loss: 12.104949 | rel_err_u: 2.0987, rel_err_x: 1.2192
# Epoch  100 | Loss: 7.915780 | rel_err_u: 2.0225, rel_err_x: 1.2422
# Epoch  150 | Loss: 5.255310 | rel_err_u: 1.9594, rel_err_x: 1.2643
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch  200 | Loss: 3.539303 | rel_err_u: 1.9099, rel_err_x: 1.2784
# Epoch  250 | Loss: 2.427424 | rel_err_u: 1.8712, rel_err_x: 1.2856
# Epoch  300 | Loss: 1.704902 | rel_err_u: 1.8405, rel_err_x: 1.2883
# Epoch  350 | Loss: 1.234455 | rel_err_u: 1.8157, rel_err_x: 1.2880
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch  400 | Loss: 0.928016 | rel_err_u: 1.7952, rel_err_x: 1.2858
# Epoch  450 | Loss: 0.728640 | rel_err_u: 1.7777, rel_err_x: 1.2824
# Epoch  500 | Loss: 0.599147 | rel_err_u: 1.7623, rel_err_x: 1.2780
# Epoch  550 | Loss: 0.515069 | rel_err_u: 1.7482, rel_err_x: 1.2728
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch  600 | Loss: 0.460259 | rel_err_u: 1.7351, rel_err_x: 1.2671
# Epoch  650 | Loss: 0.424090 | rel_err_u: 1.7224, rel_err_x: 1.2610
# Epoch  700 | Loss: 0.399635 | rel_err_u: 1.7100, rel_err_x: 1.2544
# Epoch  750 | Loss: 0.382446 | rel_err_u: 1.6977, rel_err_x: 1.2475
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch  800 | Loss: 0.369723 | rel_err_u: 1.6855, rel_err_x: 1.2403
# Epoch  850 | Loss: 0.359737 | rel_err_u: 1.6732, rel_err_x: 1.2328
# Epoch  900 | Loss: 0.351447 | rel_err_u: 1.6609, rel_err_x: 1.2250
# Epoch  950 | Loss: 0.344233 | rel_err_u: 1.6486, rel_err_x: 1.2171
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 1000 | Loss: 0.337734 | rel_err_u: 1.6362, rel_err_x: 1.2089
# Epoch 1050 | Loss: 0.331739 | rel_err_u: 1.6237, rel_err_x: 1.2006
# Epoch 1100 | Loss: 0.326124 | rel_err_u: 1.6112, rel_err_x: 1.1921
# Epoch 1150 | Loss: 0.320815 | rel_err_u: 1.5986, rel_err_x: 1.1835
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 1200 | Loss: 0.315763 | rel_err_u: 1.5860, rel_err_x: 1.1748
# Epoch 1250 | Loss: 0.310937 | rel_err_u: 1.5734, rel_err_x: 1.1659
# Epoch 1300 | Loss: 0.306315 | rel_err_u: 1.5607, rel_err_x: 1.1569
# Epoch 1350 | Loss: 0.301878 | rel_err_u: 1.5479, rel_err_x: 1.1479
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 1400 | Loss: 0.297613 | rel_err_u: 1.5352, rel_err_x: 1.1387
# Epoch 1450 | Loss: 0.293507 | rel_err_u: 1.5224, rel_err_x: 1.1294
# Epoch 1500 | Loss: 0.289552 | rel_err_u: 1.5095, rel_err_x: 1.1201
# Epoch 1550 | Loss: 0.285737 | rel_err_u: 1.4967, rel_err_x: 1.1106
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 1600 | Loss: 0.282054 | rel_err_u: 1.4837, rel_err_x: 1.1011
# Epoch 1650 | Loss: 0.278497 | rel_err_u: 1.4708, rel_err_x: 1.0915
# Epoch 1700 | Loss: 0.275059 | rel_err_u: 1.4578, rel_err_x: 1.0818
# Epoch 1750 | Loss: 0.271733 | rel_err_u: 1.4447, rel_err_x: 1.0720
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 1800 | Loss: 0.268513 | rel_err_u: 1.4316, rel_err_x: 1.0622
# Epoch 1850 | Loss: 0.265393 | rel_err_u: 1.4185, rel_err_x: 1.0523
# Epoch 1900 | Loss: 0.262370 | rel_err_u: 1.4053, rel_err_x: 1.0423
# Epoch 1950 | Loss: 0.259436 | rel_err_u: 1.3921, rel_err_x: 1.0323
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 2000 | Loss: 0.256589 | rel_err_u: 1.3788, rel_err_x: 1.0221
# Epoch 2050 | Loss: 0.253822 | rel_err_u: 1.3654, rel_err_x: 1.0120
# Epoch 2100 | Loss: 0.251132 | rel_err_u: 1.3520, rel_err_x: 1.0017
# Epoch 2150 | Loss: 0.248515 | rel_err_u: 1.3386, rel_err_x: 0.9914
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 2200 | Loss: 0.245966 | rel_err_u: 1.3251, rel_err_x: 0.9810
# Epoch 2250 | Loss: 0.243483 | rel_err_u: 1.3115, rel_err_x: 0.9706
# Epoch 2300 | Loss: 0.241062 | rel_err_u: 1.2978, rel_err_x: 0.9601
# Epoch 2350 | Loss: 0.238699 | rel_err_u: 1.2841, rel_err_x: 0.9496
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 2400 | Loss: 0.236392 | rel_err_u: 1.2704, rel_err_x: 0.9390
# Epoch 2450 | Loss: 0.234138 | rel_err_u: 1.2566, rel_err_x: 0.9283
# Epoch 2500 | Loss: 0.231933 | rel_err_u: 1.2427, rel_err_x: 0.9176
# Epoch 2550 | Loss: 0.229777 | rel_err_u: 1.2287, rel_err_x: 0.9068
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 2600 | Loss: 0.227667 | rel_err_u: 1.2148, rel_err_x: 0.8960
# Epoch 2650 | Loss: 0.225600 | rel_err_u: 1.2007, rel_err_x: 0.8851
# Epoch 2700 | Loss: 0.223575 | rel_err_u: 1.1866, rel_err_x: 0.8742
# Epoch 2750 | Loss: 0.221590 | rel_err_u: 1.1724, rel_err_x: 0.8633
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 2800 | Loss: 0.219644 | rel_err_u: 1.1582, rel_err_x: 0.8522
# Epoch 2850 | Loss: 0.217735 | rel_err_u: 1.1440, rel_err_x: 0.8412
# Epoch 2900 | Loss: 0.215861 | rel_err_u: 1.1297, rel_err_x: 0.8301
# Epoch 2950 | Loss: 0.214023 | rel_err_u: 1.1153, rel_err_x: 0.8190
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 3000 | Loss: 0.212218 | rel_err_u: 1.1010, rel_err_x: 0.8078
# Epoch 3050 | Loss: 0.210446 | rel_err_u: 1.0866, rel_err_x: 0.7966
# Epoch 3100 | Loss: 0.208707 | rel_err_u: 1.0721, rel_err_x: 0.7854
# Epoch 3150 | Loss: 0.206998 | rel_err_u: 1.0576, rel_err_x: 0.7742
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 3200 | Loss: 0.205320 | rel_err_u: 1.0431, rel_err_x: 0.7629
# Epoch 3250 | Loss: 0.203673 | rel_err_u: 1.0286, rel_err_x: 0.7516
# Epoch 3300 | Loss: 0.202055 | rel_err_u: 1.0141, rel_err_x: 0.7403
# Epoch 3350 | Loss: 0.200466 | rel_err_u: 0.9995, rel_err_x: 0.7290
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 3400 | Loss: 0.198906 | rel_err_u: 0.9850, rel_err_x: 0.7176
# Epoch 3450 | Loss: 0.197375 | rel_err_u: 0.9704, rel_err_x: 0.7063
# Epoch 3500 | Loss: 0.195872 | rel_err_u: 0.9558, rel_err_x: 0.6949
# Epoch 3550 | Loss: 0.194397 | rel_err_u: 0.9413, rel_err_x: 0.6836
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 3600 | Loss: 0.192950 | rel_err_u: 0.9267, rel_err_x: 0.6722
# Epoch 3650 | Loss: 0.191531 | rel_err_u: 0.9122, rel_err_x: 0.6609
# Epoch 3700 | Loss: 0.190139 | rel_err_u: 0.8976, rel_err_x: 0.6496
# Epoch 3750 | Loss: 0.188775 | rel_err_u: 0.8832, rel_err_x: 0.6382
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 3800 | Loss: 0.187439 | rel_err_u: 0.8687, rel_err_x: 0.6269
# Epoch 3850 | Loss: 0.186130 | rel_err_u: 0.8542, rel_err_x: 0.6157
# Epoch 3900 | Loss: 0.184849 | rel_err_u: 0.8398, rel_err_x: 0.6044
# Epoch 3950 | Loss: 0.183595 | rel_err_u: 0.8255, rel_err_x: 0.5932
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 4000 | Loss: 0.182368 | rel_err_u: 0.8112, rel_err_x: 0.5820
# Epoch 4050 | Loss: 0.181169 | rel_err_u: 0.7969, rel_err_x: 0.5708
# Epoch 4100 | Loss: 0.179996 | rel_err_u: 0.7827, rel_err_x: 0.5597
# Epoch 4150 | Loss: 0.178851 | rel_err_u: 0.7686, rel_err_x: 0.5487
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 4200 | Loss: 0.177734 | rel_err_u: 0.7545, rel_err_x: 0.5377
# Epoch 4250 | Loss: 0.176643 | rel_err_u: 0.7405, rel_err_x: 0.5267
# Epoch 4300 | Loss: 0.175579 | rel_err_u: 0.7265, rel_err_x: 0.5158
# Epoch 4350 | Loss: 0.174543 | rel_err_u: 0.7127, rel_err_x: 0.5050
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 4400 | Loss: 0.173533 | rel_err_u: 0.6989, rel_err_x: 0.4942
# Epoch 4450 | Loss: 0.172549 | rel_err_u: 0.6852, rel_err_x: 0.4835
# Epoch 4500 | Loss: 0.171593 | rel_err_u: 0.6717, rel_err_x: 0.4728
# Epoch 4550 | Loss: 0.170662 | rel_err_u: 0.6582, rel_err_x: 0.4623
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 4600 | Loss: 0.169758 | rel_err_u: 0.6448, rel_err_x: 0.4518
# Epoch 4650 | Loss: 0.168880 | rel_err_u: 0.6315, rel_err_x: 0.4414
# Epoch 4700 | Loss: 0.168027 | rel_err_u: 0.6183, rel_err_x: 0.4311
# Epoch 4750 | Loss: 0.167200 | rel_err_u: 0.6053, rel_err_x: 0.4209
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 4800 | Loss: 0.166398 | rel_err_u: 0.5923, rel_err_x: 0.4108
# Epoch 4850 | Loss: 0.165621 | rel_err_u: 0.5795, rel_err_x: 0.4008
# Epoch 4900 | Loss: 0.164869 | rel_err_u: 0.5668, rel_err_x: 0.3909
# Epoch 4950 | Loss: 0.164141 | rel_err_u: 0.5542, rel_err_x: 0.3811
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 5000 | Loss: 0.163437 | rel_err_u: 0.5417, rel_err_x: 0.3713
# Epoch 5050 | Loss: 0.162756 | rel_err_u: 0.5294, rel_err_x: 0.3617
# Epoch 5100 | Loss: 0.162099 | rel_err_u: 0.5172, rel_err_x: 0.3523
# Epoch 5150 | Loss: 0.161464 | rel_err_u: 0.5052, rel_err_x: 0.3429
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 5200 | Loss: 0.160851 | rel_err_u: 0.4932, rel_err_x: 0.3336
# Epoch 5250 | Loss: 0.160261 | rel_err_u: 0.4815, rel_err_x: 0.3245
# Epoch 5300 | Loss: 0.159692 | rel_err_u: 0.4698, rel_err_x: 0.3155
# Epoch 5350 | Loss: 0.159144 | rel_err_u: 0.4584, rel_err_x: 0.3066
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 5400 | Loss: 0.158617 | rel_err_u: 0.4470, rel_err_x: 0.2978
# Epoch 5450 | Loss: 0.158110 | rel_err_u: 0.4358, rel_err_x: 0.2892
# Epoch 5500 | Loss: 0.157622 | rel_err_u: 0.4248, rel_err_x: 0.2807
# Epoch 5550 | Loss: 0.157154 | rel_err_u: 0.4139, rel_err_x: 0.2723
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 5600 | Loss: 0.156704 | rel_err_u: 0.4031, rel_err_x: 0.2641
# Epoch 5650 | Loss: 0.156273 | rel_err_u: 0.3925, rel_err_x: 0.2560
# Epoch 5700 | Loss: 0.155859 | rel_err_u: 0.3821, rel_err_x: 0.2480
# Epoch 5750 | Loss: 0.155463 | rel_err_u: 0.3718, rel_err_x: 0.2402
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 5800 | Loss: 0.155083 | rel_err_u: 0.3617, rel_err_x: 0.2325
# Epoch 5850 | Loss: 0.154720 | rel_err_u: 0.3517, rel_err_x: 0.2250
# Epoch 5900 | Loss: 0.154373 | rel_err_u: 0.3419, rel_err_x: 0.2176
# Epoch 5950 | Loss: 0.154041 | rel_err_u: 0.3323, rel_err_x: 0.2103
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 6000 | Loss: 0.153724 | rel_err_u: 0.3228, rel_err_x: 0.2032
# Epoch 6050 | Loss: 0.153421 | rel_err_u: 0.3134, rel_err_x: 0.1962
# Epoch 6100 | Loss: 0.153132 | rel_err_u: 0.3043, rel_err_x: 0.1894
# Epoch 6150 | Loss: 0.152857 | rel_err_u: 0.2952, rel_err_x: 0.1827
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 6200 | Loss: 0.152595 | rel_err_u: 0.2864, rel_err_x: 0.1762
# Epoch 6250 | Loss: 0.152346 | rel_err_u: 0.2777, rel_err_x: 0.1698
# Epoch 6300 | Loss: 0.152109 | rel_err_u: 0.2691, rel_err_x: 0.1636
# Epoch 6350 | Loss: 0.151884 | rel_err_u: 0.2608, rel_err_x: 0.1575
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 6400 | Loss: 0.151670 | rel_err_u: 0.2525, rel_err_x: 0.1515
# Epoch 6450 | Loss: 0.151467 | rel_err_u: 0.2445, rel_err_x: 0.1457
# Epoch 6500 | Loss: 0.151275 | rel_err_u: 0.2366, rel_err_x: 0.1401
# Epoch 6550 | Loss: 0.151093 | rel_err_u: 0.2289, rel_err_x: 0.1346
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 6600 | Loss: 0.150921 | rel_err_u: 0.2213, rel_err_x: 0.1292
# Epoch 6650 | Loss: 0.150758 | rel_err_u: 0.2139, rel_err_x: 0.1240
# Epoch 6700 | Loss: 0.150604 | rel_err_u: 0.2067, rel_err_x: 0.1189
# Epoch 6750 | Loss: 0.150459 | rel_err_u: 0.1996, rel_err_x: 0.1140
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 6800 | Loss: 0.150322 | rel_err_u: 0.1927, rel_err_x: 0.1092
# Epoch 6850 | Loss: 0.150194 | rel_err_u: 0.1859, rel_err_x: 0.1045
# Epoch 6900 | Loss: 0.150073 | rel_err_u: 0.1793, rel_err_x: 0.1000
# Epoch 6950 | Loss: 0.149959 | rel_err_u: 0.1729, rel_err_x: 0.0957
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 7000 | Loss: 0.149853 | rel_err_u: 0.1667, rel_err_x: 0.0914
# Epoch 7050 | Loss: 0.149753 | rel_err_u: 0.1606, rel_err_x: 0.0873
# Epoch 7100 | Loss: 0.149659 | rel_err_u: 0.1547, rel_err_x: 0.0834
# Epoch 7150 | Loss: 0.149572 | rel_err_u: 0.1490, rel_err_x: 0.0796
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 7200 | Loss: 0.149491 | rel_err_u: 0.1434, rel_err_x: 0.0759
# Epoch 7250 | Loss: 0.149415 | rel_err_u: 0.1380, rel_err_x: 0.0723
# Epoch 7300 | Loss: 0.149344 | rel_err_u: 0.1328, rel_err_x: 0.0689
# Epoch 7350 | Loss: 0.149278 | rel_err_u: 0.1278, rel_err_x: 0.0656
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 7400 | Loss: 0.149217 | rel_err_u: 0.1229, rel_err_x: 0.0624
# Epoch 7450 | Loss: 0.149161 | rel_err_u: 0.1182, rel_err_x: 0.0594
# Epoch 7500 | Loss: 0.149109 | rel_err_u: 0.1137, rel_err_x: 0.0564
# Epoch 7550 | Loss: 0.149060 | rel_err_u: 0.1093, rel_err_x: 0.0536
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 7600 | Loss: 0.149016 | rel_err_u: 0.1052, rel_err_x: 0.0509
# Epoch 7650 | Loss: 0.148975 | rel_err_u: 0.1012, rel_err_x: 0.0483
# Epoch 7700 | Loss: 0.148937 | rel_err_u: 0.0974, rel_err_x: 0.0459
# Epoch 7750 | Loss: 0.148903 | rel_err_u: 0.0938, rel_err_x: 0.0435
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 7800 | Loss: 0.148871 | rel_err_u: 0.0903, rel_err_x: 0.0413
# Epoch 7850 | Loss: 0.148843 | rel_err_u: 0.0870, rel_err_x: 0.0391
# Epoch 7900 | Loss: 0.148816 | rel_err_u: 0.0840, rel_err_x: 0.0371
# Epoch 7950 | Loss: 0.148792 | rel_err_u: 0.0810, rel_err_x: 0.0352
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 8000 | Loss: 0.148771 | rel_err_u: 0.0783, rel_err_x: 0.0334
# Epoch 8050 | Loss: 0.148751 | rel_err_u: 0.0757, rel_err_x: 0.0316
# Epoch 8100 | Loss: 0.148733 | rel_err_u: 0.0733, rel_err_x: 0.0300
# Epoch 8150 | Loss: 0.148717 | rel_err_u: 0.0710, rel_err_x: 0.0284
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 8200 | Loss: 0.148703 | rel_err_u: 0.0690, rel_err_x: 0.0270
# Epoch 8250 | Loss: 0.148690 | rel_err_u: 0.0670, rel_err_x: 0.0256
# Epoch 8300 | Loss: 0.148678 | rel_err_u: 0.0653, rel_err_x: 0.0243
# Epoch 8350 | Loss: 0.148668 | rel_err_u: 0.0636, rel_err_x: 0.0231
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 8400 | Loss: 0.148659 | rel_err_u: 0.0621, rel_err_x: 0.0219
# Epoch 8450 | Loss: 0.148651 | rel_err_u: 0.0608, rel_err_x: 0.0209
# Epoch 8500 | Loss: 0.148643 | rel_err_u: 0.0596, rel_err_x: 0.0199
# Epoch 8550 | Loss: 0.148637 | rel_err_u: 0.0584, rel_err_x: 0.0190
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 8600 | Loss: 0.148631 | rel_err_u: 0.0574, rel_err_x: 0.0181
# Epoch 8650 | Loss: 0.148626 | rel_err_u: 0.0566, rel_err_x: 0.0173
# Epoch 8700 | Loss: 0.148622 | rel_err_u: 0.0558, rel_err_x: 0.0166
# Epoch 8750 | Loss: 0.148618 | rel_err_u: 0.0551, rel_err_x: 0.0159
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 8800 | Loss: 0.148615 | rel_err_u: 0.0544, rel_err_x: 0.0153
# Epoch 8850 | Loss: 0.148612 | rel_err_u: 0.0539, rel_err_x: 0.0147
# Epoch 8900 | Loss: 0.148609 | rel_err_u: 0.0534, rel_err_x: 0.0142
# Epoch 8950 | Loss: 0.148607 | rel_err_u: 0.0530, rel_err_x: 0.0137
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 9000 | Loss: 0.148605 | rel_err_u: 0.0526, rel_err_x: 0.0133
# Epoch 9050 | Loss: 0.148604 | rel_err_u: 0.0523, rel_err_x: 0.0129
# Epoch 9100 | Loss: 0.148603 | rel_err_u: 0.0520, rel_err_x: 0.0125
# Epoch 9150 | Loss: 0.148601 | rel_err_u: 0.0518, rel_err_x: 0.0122
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 9200 | Loss: 0.148600 | rel_err_u: 0.0516, rel_err_x: 0.0119
# Epoch 9250 | Loss: 0.148600 | rel_err_u: 0.0514, rel_err_x: 0.0116
# Epoch 9300 | Loss: 0.148599 | rel_err_u: 0.0513, rel_err_x: 0.0114
# Epoch 9350 | Loss: 0.148598 | rel_err_u: 0.0512, rel_err_x: 0.0112
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 9400 | Loss: 0.148598 | rel_err_u: 0.0511, rel_err_x: 0.0110
# Epoch 9450 | Loss: 0.148597 | rel_err_u: 0.0510, rel_err_x: 0.0108
# Epoch 9500 | Loss: 0.148597 | rel_err_u: 0.0509, rel_err_x: 0.0107
# Epoch 9550 | Loss: 0.148597 | rel_err_u: 0.0508, rel_err_x: 0.0106
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 9600 | Loss: 0.148597 | rel_err_u: 0.0508, rel_err_x: 0.0104
# Epoch 9650 | Loss: 0.148596 | rel_err_u: 0.0507, rel_err_x: 0.0103
# Epoch 9700 | Loss: 0.148596 | rel_err_u: 0.0507, rel_err_x: 0.0102
# Epoch 9750 | Loss: 0.148596 | rel_err_u: 0.0507, rel_err_x: 0.0101
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 9800 | Loss: 0.148596 | rel_err_u: 0.0507, rel_err_x: 0.0101
# Epoch 9850 | Loss: 0.148596 | rel_err_u: 0.0506, rel_err_x: 0.0100
# Epoch 9900 | Loss: 0.148596 | rel_err_u: 0.0506, rel_err_x: 0.0100
# Epoch 9950 | Loss: 0.148596 | rel_err_u: 0.0506, rel_err_x: 0.0099
# Plot saved to found_trajectories/polynomial_tracking/deeponet/plot.png
# Epoch 10000 | Loss: 0.148596 | rel_err_u: 0.0506, rel_err_x: 0.0099

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.14795131981372833

# %% [markdown]
# <img src="found_trajectories/polynomial_tracking/deeponet/plot.png" width="600">

# %% [markdown]
# # Control problem with Nonlinear ODE

# %%
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

ckpt = torch.load("trained_models/nonlinear/deeponet/unsupervised/epoch[1500]_model_time_[20250717_215941]_loss_[0.0099].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

w = [150, 1, 1, 1, 0]

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'nonlinear', initial_guess,
    lr=0.001,
    architecture="deeponet",  
    w=w,
    num_epochs=20000,
    m=m,
    bounds = [-1.5, 1.5],
    device=device, logging = True
)
# Out:
# Epoch   50 | Loss: 145.218002 | rel_err_u: 1.7862, rel_err_x: 0.3321
# Epoch  100 | Loss: 85.869713 | rel_err_u: 1.7334, rel_err_x: 0.2606
# Epoch  150 | Loss: 54.967941 | rel_err_u: 1.6883, rel_err_x: 0.2268
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch  200 | Loss: 37.376125 | rel_err_u: 1.6517, rel_err_x: 0.2113
# Epoch  250 | Loss: 26.777822 | rel_err_u: 1.6234, rel_err_x: 0.2074
# Epoch  300 | Loss: 19.940796 | rel_err_u: 1.6016, rel_err_x: 0.2096
# Epoch  350 | Loss: 15.378124 | rel_err_u: 1.5836, rel_err_x: 0.2125
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch  400 | Loss: 12.277107 | rel_err_u: 1.5676, rel_err_x: 0.2134
# Epoch  450 | Loss: 10.075662 | rel_err_u: 1.5528, rel_err_x: 0.2130
# Epoch  500 | Loss: 8.443405 | rel_err_u: 1.5392, rel_err_x: 0.2121
# Epoch  550 | Loss: 7.191081 | rel_err_u: 1.5267, rel_err_x: 0.2112
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch  600 | Loss: 6.203009 | rel_err_u: 1.5150, rel_err_x: 0.2102
# Epoch  650 | Loss: 5.405264 | rel_err_u: 1.5041, rel_err_x: 0.2092
# Epoch  700 | Loss: 4.749116 | rel_err_u: 1.4939, rel_err_x: 0.2081
# Epoch  750 | Loss: 4.201420 | rel_err_u: 1.4843, rel_err_x: 0.2070
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch  800 | Loss: 3.738849 | rel_err_u: 1.4753, rel_err_x: 0.2059
# Epoch  850 | Loss: 3.344444 | rel_err_u: 1.4668, rel_err_x: 0.2047
# Epoch  900 | Loss: 3.005501 | rel_err_u: 1.4590, rel_err_x: 0.2036
# Epoch  950 | Loss: 2.712281 | rel_err_u: 1.4516, rel_err_x: 0.2025
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 1000 | Loss: 2.457189 | rel_err_u: 1.4447, rel_err_x: 0.2014
# Epoch 1050 | Loss: 2.234189 | rel_err_u: 1.4382, rel_err_x: 0.2003
# Epoch 1100 | Loss: 2.038438 | rel_err_u: 1.4321, rel_err_x: 0.1992
# Epoch 1150 | Loss: 1.865976 | rel_err_u: 1.4264, rel_err_x: 0.1982
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 1200 | Loss: 1.713548 | rel_err_u: 1.4210, rel_err_x: 0.1972
# Epoch 1250 | Loss: 1.578407 | rel_err_u: 1.4159, rel_err_x: 0.1962
# Epoch 1300 | Loss: 1.458234 | rel_err_u: 1.4111, rel_err_x: 0.1952
# Epoch 1350 | Loss: 1.351042 | rel_err_u: 1.4065, rel_err_x: 0.1942
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 1400 | Loss: 1.255110 | rel_err_u: 1.4021, rel_err_x: 0.1933
# Epoch 1450 | Loss: 1.168956 | rel_err_u: 1.3978, rel_err_x: 0.1923
# Epoch 1500 | Loss: 1.091292 | rel_err_u: 1.3937, rel_err_x: 0.1913
# Epoch 1550 | Loss: 1.021013 | rel_err_u: 1.3898, rel_err_x: 0.1904
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 1600 | Loss: 0.957166 | rel_err_u: 1.3859, rel_err_x: 0.1895
# Epoch 1650 | Loss: 0.898940 | rel_err_u: 1.3822, rel_err_x: 0.1885
# Epoch 1700 | Loss: 0.845632 | rel_err_u: 1.3785, rel_err_x: 0.1876
# Epoch 1750 | Loss: 0.796656 | rel_err_u: 1.3750, rel_err_x: 0.1866
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 1800 | Loss: 0.751510 | rel_err_u: 1.3715, rel_err_x: 0.1857
# Epoch 1850 | Loss: 0.709764 | rel_err_u: 1.3681, rel_err_x: 0.1848
# Epoch 1900 | Loss: 0.671062 | rel_err_u: 1.3647, rel_err_x: 0.1839
# Epoch 1950 | Loss: 0.635103 | rel_err_u: 1.3615, rel_err_x: 0.1830
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 2000 | Loss: 0.601626 | rel_err_u: 1.3583, rel_err_x: 0.1821
# Epoch 2050 | Loss: 0.570421 | rel_err_u: 1.3551, rel_err_x: 0.1812
# Epoch 2100 | Loss: 0.541298 | rel_err_u: 1.3520, rel_err_x: 0.1804
# Epoch 2150 | Loss: 0.514109 | rel_err_u: 1.3490, rel_err_x: 0.1795
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 2200 | Loss: 0.488716 | rel_err_u: 1.3460, rel_err_x: 0.1787
# Epoch 2250 | Loss: 0.465001 | rel_err_u: 1.3430, rel_err_x: 0.1779
# Epoch 2300 | Loss: 0.442849 | rel_err_u: 1.3401, rel_err_x: 0.1771
# Epoch 2350 | Loss: 0.422158 | rel_err_u: 1.3372, rel_err_x: 0.1763
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 2400 | Loss: 0.402829 | rel_err_u: 1.3344, rel_err_x: 0.1755
# Epoch 2450 | Loss: 0.384765 | rel_err_u: 1.3316, rel_err_x: 0.1748
# Epoch 2500 | Loss: 0.367869 | rel_err_u: 1.3288, rel_err_x: 0.1740
# Epoch 2550 | Loss: 0.352048 | rel_err_u: 1.3261, rel_err_x: 0.1733
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 2600 | Loss: 0.337215 | rel_err_u: 1.3233, rel_err_x: 0.1726
# Epoch 2650 | Loss: 0.323286 | rel_err_u: 1.3206, rel_err_x: 0.1719
# Epoch 2700 | Loss: 0.310188 | rel_err_u: 1.3180, rel_err_x: 0.1712
# Epoch 2750 | Loss: 0.297849 | rel_err_u: 1.3153, rel_err_x: 0.1705
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 2800 | Loss: 0.286206 | rel_err_u: 1.3126, rel_err_x: 0.1698
# Epoch 2850 | Loss: 0.275205 | rel_err_u: 1.3100, rel_err_x: 0.1692
# Epoch 2900 | Loss: 0.264796 | rel_err_u: 1.3074, rel_err_x: 0.1685
# Epoch 2950 | Loss: 0.254933 | rel_err_u: 1.3048, rel_err_x: 0.1679
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 3000 | Loss: 0.245573 | rel_err_u: 1.3021, rel_err_x: 0.1673
# Epoch 3050 | Loss: 0.236684 | rel_err_u: 1.2996, rel_err_x: 0.1667
# Epoch 3100 | Loss: 0.228234 | rel_err_u: 1.2970, rel_err_x: 0.1661
# Epoch 3150 | Loss: 0.220191 | rel_err_u: 1.2944, rel_err_x: 0.1655
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 3200 | Loss: 0.212532 | rel_err_u: 1.2918, rel_err_x: 0.1649
# Epoch 3250 | Loss: 0.205233 | rel_err_u: 1.2892, rel_err_x: 0.1643
# Epoch 3300 | Loss: 0.198272 | rel_err_u: 1.2866, rel_err_x: 0.1637
# Epoch 3350 | Loss: 0.191629 | rel_err_u: 1.2841, rel_err_x: 0.1631
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 3400 | Loss: 0.185285 | rel_err_u: 1.2815, rel_err_x: 0.1625
# Epoch 3450 | Loss: 0.179225 | rel_err_u: 1.2789, rel_err_x: 0.1620
# Epoch 3500 | Loss: 0.173431 | rel_err_u: 1.2763, rel_err_x: 0.1614
# Epoch 3550 | Loss: 0.167890 | rel_err_u: 1.2737, rel_err_x: 0.1608
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 3600 | Loss: 0.162586 | rel_err_u: 1.2710, rel_err_x: 0.1603
# Epoch 3650 | Loss: 0.157507 | rel_err_u: 1.2684, rel_err_x: 0.1597
# Epoch 3700 | Loss: 0.152639 | rel_err_u: 1.2657, rel_err_x: 0.1591
# Epoch 3750 | Loss: 0.147971 | rel_err_u: 1.2631, rel_err_x: 0.1586
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 3800 | Loss: 0.143490 | rel_err_u: 1.2604, rel_err_x: 0.1580
# Epoch 3850 | Loss: 0.139188 | rel_err_u: 1.2577, rel_err_x: 0.1575
# Epoch 3900 | Loss: 0.135051 | rel_err_u: 1.2549, rel_err_x: 0.1569
# Epoch 3950 | Loss: 0.131069 | rel_err_u: 1.2522, rel_err_x: 0.1563
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 4000 | Loss: 0.127236 | rel_err_u: 1.2494, rel_err_x: 0.1558
# Epoch 4050 | Loss: 0.123539 | rel_err_u: 1.2466, rel_err_x: 0.1552
# Epoch 4100 | Loss: 0.119971 | rel_err_u: 1.2437, rel_err_x: 0.1546
# Epoch 4150 | Loss: 0.116525 | rel_err_u: 1.2409, rel_err_x: 0.1541
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 4200 | Loss: 0.113190 | rel_err_u: 1.2380, rel_err_x: 0.1535
# Epoch 4250 | Loss: 0.109963 | rel_err_u: 1.2350, rel_err_x: 0.1529
# Epoch 4300 | Loss: 0.106835 | rel_err_u: 1.2321, rel_err_x: 0.1523
# Epoch 4350 | Loss: 0.103800 | rel_err_u: 1.2291, rel_err_x: 0.1517
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 4400 | Loss: 0.100853 | rel_err_u: 1.2260, rel_err_x: 0.1512
# Epoch 4450 | Loss: 0.097988 | rel_err_u: 1.2230, rel_err_x: 0.1506
# Epoch 4500 | Loss: 0.095200 | rel_err_u: 1.2199, rel_err_x: 0.1500
# Epoch 4550 | Loss: 0.092484 | rel_err_u: 1.2167, rel_err_x: 0.1493
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 4600 | Loss: 0.089837 | rel_err_u: 1.2135, rel_err_x: 0.1487
# Epoch 4650 | Loss: 0.087253 | rel_err_u: 1.2103, rel_err_x: 0.1481
# Epoch 4700 | Loss: 0.084732 | rel_err_u: 1.2071, rel_err_x: 0.1475
# Epoch 4750 | Loss: 0.082266 | rel_err_u: 1.2037, rel_err_x: 0.1468
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 4800 | Loss: 0.079855 | rel_err_u: 1.2004, rel_err_x: 0.1462
# Epoch 4850 | Loss: 0.077495 | rel_err_u: 1.1970, rel_err_x: 0.1455
# Epoch 4900 | Loss: 0.075184 | rel_err_u: 1.1936, rel_err_x: 0.1449
# Epoch 4950 | Loss: 0.072918 | rel_err_u: 1.1901, rel_err_x: 0.1442
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 5000 | Loss: 0.070696 | rel_err_u: 1.1866, rel_err_x: 0.1435
# Epoch 5050 | Loss: 0.068515 | rel_err_u: 1.1830, rel_err_x: 0.1428
# Epoch 5100 | Loss: 0.066374 | rel_err_u: 1.1794, rel_err_x: 0.1421
# Epoch 5150 | Loss: 0.064270 | rel_err_u: 1.1757, rel_err_x: 0.1414
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 5200 | Loss: 0.062201 | rel_err_u: 1.1720, rel_err_x: 0.1407
# Epoch 5250 | Loss: 0.060167 | rel_err_u: 1.1682, rel_err_x: 0.1400
# Epoch 5300 | Loss: 0.058164 | rel_err_u: 1.1644, rel_err_x: 0.1392
# Epoch 5350 | Loss: 0.056192 | rel_err_u: 1.1605, rel_err_x: 0.1385
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 5400 | Loss: 0.054249 | rel_err_u: 1.1566, rel_err_x: 0.1377
# Epoch 5450 | Loss: 0.052334 | rel_err_u: 1.1526, rel_err_x: 0.1370
# Epoch 5500 | Loss: 0.050444 | rel_err_u: 1.1486, rel_err_x: 0.1362
# Epoch 5550 | Loss: 0.048579 | rel_err_u: 1.1445, rel_err_x: 0.1354
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 5600 | Loss: 0.046737 | rel_err_u: 1.1404, rel_err_x: 0.1346
# Epoch 5650 | Loss: 0.044917 | rel_err_u: 1.1362, rel_err_x: 0.1338
# Epoch 5700 | Loss: 0.043118 | rel_err_u: 1.1319, rel_err_x: 0.1330
# Epoch 5750 | Loss: 0.041338 | rel_err_u: 1.1276, rel_err_x: 0.1322
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 5800 | Loss: 0.039576 | rel_err_u: 1.1232, rel_err_x: 0.1313
# Epoch 5850 | Loss: 0.037830 | rel_err_u: 1.1188, rel_err_x: 0.1305
# Epoch 5900 | Loss: 0.036100 | rel_err_u: 1.1143, rel_err_x: 0.1296
# Epoch 5950 | Loss: 0.034385 | rel_err_u: 1.1098, rel_err_x: 0.1288
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 6000 | Loss: 0.032683 | rel_err_u: 1.1052, rel_err_x: 0.1279
# Epoch 6050 | Loss: 0.030993 | rel_err_u: 1.1005, rel_err_x: 0.1270
# Epoch 6100 | Loss: 0.029315 | rel_err_u: 1.0958, rel_err_x: 0.1261
# Epoch 6150 | Loss: 0.027647 | rel_err_u: 1.0910, rel_err_x: 0.1252
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 6200 | Loss: 0.025988 | rel_err_u: 1.0861, rel_err_x: 0.1243
# Epoch 6250 | Loss: 0.024338 | rel_err_u: 1.0812, rel_err_x: 0.1233
# Epoch 6300 | Loss: 0.022697 | rel_err_u: 1.0762, rel_err_x: 0.1224
# Epoch 6350 | Loss: 0.021062 | rel_err_u: 1.0712, rel_err_x: 0.1214
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 6400 | Loss: 0.019434 | rel_err_u: 1.0660, rel_err_x: 0.1205
# Epoch 6450 | Loss: 0.017813 | rel_err_u: 1.0609, rel_err_x: 0.1195
# Epoch 6500 | Loss: 0.016197 | rel_err_u: 1.0556, rel_err_x: 0.1185
# Epoch 6550 | Loss: 0.014586 | rel_err_u: 1.0503, rel_err_x: 0.1175
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 6600 | Loss: 0.012980 | rel_err_u: 1.0449, rel_err_x: 0.1165
# Epoch 6650 | Loss: 0.011379 | rel_err_u: 1.0394, rel_err_x: 0.1155
# Epoch 6700 | Loss: 0.009782 | rel_err_u: 1.0339, rel_err_x: 0.1144
# Epoch 6750 | Loss: 0.008190 | rel_err_u: 1.0282, rel_err_x: 0.1134
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 6800 | Loss: 0.006601 | rel_err_u: 1.0226, rel_err_x: 0.1123
# Epoch 6850 | Loss: 0.005016 | rel_err_u: 1.0168, rel_err_x: 0.1113
# Epoch 6900 | Loss: 0.003435 | rel_err_u: 1.0110, rel_err_x: 0.1102
# Epoch 6950 | Loss: 0.001857 | rel_err_u: 1.0051, rel_err_x: 0.1091
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 7000 | Loss: 0.000284 | rel_err_u: 0.9991, rel_err_x: 0.1080
# Epoch 7050 | Loss: -0.001286 | rel_err_u: 0.9931, rel_err_x: 0.1069
# Epoch 7100 | Loss: -0.002852 | rel_err_u: 0.9870, rel_err_x: 0.1058
# Epoch 7150 | Loss: -0.004415 | rel_err_u: 0.9808, rel_err_x: 0.1047
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 7200 | Loss: -0.005973 | rel_err_u: 0.9746, rel_err_x: 0.1036
# Epoch 7250 | Loss: -0.007527 | rel_err_u: 0.9682, rel_err_x: 0.1024
# Epoch 7300 | Loss: -0.009077 | rel_err_u: 0.9618, rel_err_x: 0.1013
# Epoch 7350 | Loss: -0.010622 | rel_err_u: 0.9554, rel_err_x: 0.1001
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 7400 | Loss: -0.012163 | rel_err_u: 0.9488, rel_err_x: 0.0990
# Epoch 7450 | Loss: -0.013699 | rel_err_u: 0.9422, rel_err_x: 0.0978
# Epoch 7500 | Loss: -0.015230 | rel_err_u: 0.9356, rel_err_x: 0.0966
# Epoch 7550 | Loss: -0.016756 | rel_err_u: 0.9288, rel_err_x: 0.0954
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 7600 | Loss: -0.018276 | rel_err_u: 0.9220, rel_err_x: 0.0942
# Epoch 7650 | Loss: -0.019790 | rel_err_u: 0.9151, rel_err_x: 0.0930
# Epoch 7700 | Loss: -0.021299 | rel_err_u: 0.9082, rel_err_x: 0.0918
# Epoch 7750 | Loss: -0.022802 | rel_err_u: 0.9012, rel_err_x: 0.0906
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 7800 | Loss: -0.024298 | rel_err_u: 0.8941, rel_err_x: 0.0894
# Epoch 7850 | Loss: -0.025787 | rel_err_u: 0.8869, rel_err_x: 0.0882
# Epoch 7900 | Loss: -0.027271 | rel_err_u: 0.8797, rel_err_x: 0.0869
# Epoch 7950 | Loss: -0.028747 | rel_err_u: 0.8724, rel_err_x: 0.0857
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 8000 | Loss: -0.030216 | rel_err_u: 0.8651, rel_err_x: 0.0844
# Epoch 8050 | Loss: -0.031677 | rel_err_u: 0.8577, rel_err_x: 0.0832
# Epoch 8100 | Loss: -0.033131 | rel_err_u: 0.8502, rel_err_x: 0.0819
# Epoch 8150 | Loss: -0.034578 | rel_err_u: 0.8426, rel_err_x: 0.0807
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 8200 | Loss: -0.036016 | rel_err_u: 0.8350, rel_err_x: 0.0794
# Epoch 8250 | Loss: -0.037447 | rel_err_u: 0.8273, rel_err_x: 0.0782
# Epoch 8300 | Loss: -0.038869 | rel_err_u: 0.8196, rel_err_x: 0.0769
# Epoch 8350 | Loss: -0.040284 | rel_err_u: 0.8118, rel_err_x: 0.0756
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 8400 | Loss: -0.041689 | rel_err_u: 0.8040, rel_err_x: 0.0743
# Epoch 8450 | Loss: -0.043087 | rel_err_u: 0.7960, rel_err_x: 0.0730
# Epoch 8500 | Loss: -0.044476 | rel_err_u: 0.7881, rel_err_x: 0.0717
# Epoch 8550 | Loss: -0.045856 | rel_err_u: 0.7800, rel_err_x: 0.0705
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 8600 | Loss: -0.047227 | rel_err_u: 0.7719, rel_err_x: 0.0692
# Epoch 8650 | Loss: -0.048590 | rel_err_u: 0.7638, rel_err_x: 0.0678
# Epoch 8700 | Loss: -0.049944 | rel_err_u: 0.7555, rel_err_x: 0.0665
# Epoch 8750 | Loss: -0.051289 | rel_err_u: 0.7473, rel_err_x: 0.0652
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 8800 | Loss: -0.052625 | rel_err_u: 0.7389, rel_err_x: 0.0639
# Epoch 8850 | Loss: -0.053952 | rel_err_u: 0.7306, rel_err_x: 0.0626
# Epoch 8900 | Loss: -0.055271 | rel_err_u: 0.7221, rel_err_x: 0.0613
# Epoch 8950 | Loss: -0.056580 | rel_err_u: 0.7136, rel_err_x: 0.0599
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 9000 | Loss: -0.057880 | rel_err_u: 0.7051, rel_err_x: 0.0586
# Epoch 9050 | Loss: -0.059171 | rel_err_u: 0.6965, rel_err_x: 0.0572
# Epoch 9100 | Loss: -0.060454 | rel_err_u: 0.6878, rel_err_x: 0.0559
# Epoch 9150 | Loss: -0.061727 | rel_err_u: 0.6791, rel_err_x: 0.0546
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 9200 | Loss: -0.062990 | rel_err_u: 0.6704, rel_err_x: 0.0532
# Epoch 9250 | Loss: -0.064244 | rel_err_u: 0.6616, rel_err_x: 0.0518
# Epoch 9300 | Loss: -0.065487 | rel_err_u: 0.6527, rel_err_x: 0.0505
# Epoch 9350 | Loss: -0.066721 | rel_err_u: 0.6439, rel_err_x: 0.0491
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 9400 | Loss: -0.067943 | rel_err_u: 0.6349, rel_err_x: 0.0478
# Epoch 9450 | Loss: -0.069155 | rel_err_u: 0.6260, rel_err_x: 0.0464
# Epoch 9500 | Loss: -0.070355 | rel_err_u: 0.6170, rel_err_x: 0.0451
# Epoch 9550 | Loss: -0.071543 | rel_err_u: 0.6079, rel_err_x: 0.0437
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 9600 | Loss: -0.072718 | rel_err_u: 0.5988, rel_err_x: 0.0423
# Epoch 9650 | Loss: -0.073881 | rel_err_u: 0.5898, rel_err_x: 0.0410
# Epoch 9700 | Loss: -0.075028 | rel_err_u: 0.5806, rel_err_x: 0.0396
# Epoch 9750 | Loss: -0.076159 | rel_err_u: 0.5715, rel_err_x: 0.0383
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 9800 | Loss: -0.077271 | rel_err_u: 0.5624, rel_err_x: 0.0370
# Epoch 9850 | Loss: -0.078361 | rel_err_u: 0.5533, rel_err_x: 0.0356
# Epoch 9900 | Loss: -0.079426 | rel_err_u: 0.5442, rel_err_x: 0.0343
# Epoch 9950 | Loss: -0.080462 | rel_err_u: 0.5351, rel_err_x: 0.0330
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 10000 | Loss: -0.081467 | rel_err_u: 0.5262, rel_err_x: 0.0318
# Epoch 10050 | Loss: -0.082439 | rel_err_u: 0.5172, rel_err_x: 0.0305
# Epoch 10100 | Loss: -0.083378 | rel_err_u: 0.5084, rel_err_x: 0.0293
# Epoch 10150 | Loss: -0.084283 | rel_err_u: 0.4996, rel_err_x: 0.0281
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 10200 | Loss: -0.085157 | rel_err_u: 0.4909, rel_err_x: 0.0270
# Epoch 10250 | Loss: -0.085999 | rel_err_u: 0.4823, rel_err_x: 0.0259
# Epoch 10300 | Loss: -0.086814 | rel_err_u: 0.4738, rel_err_x: 0.0248
# Epoch 10350 | Loss: -0.087601 | rel_err_u: 0.4654, rel_err_x: 0.0237
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 10400 | Loss: -0.088361 | rel_err_u: 0.4571, rel_err_x: 0.0227
# Epoch 10450 | Loss: -0.089099 | rel_err_u: 0.4489, rel_err_x: 0.0216
# Epoch 10500 | Loss: -0.089810 | rel_err_u: 0.4408, rel_err_x: 0.0207
# Epoch 10550 | Loss: -0.090505 | rel_err_u: 0.4328, rel_err_x: 0.0197
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 10600 | Loss: -0.091176 | rel_err_u: 0.4250, rel_err_x: 0.0188
# Epoch 10650 | Loss: -0.091824 | rel_err_u: 0.4172, rel_err_x: 0.0179
# Epoch 10700 | Loss: -0.092448 | rel_err_u: 0.4097, rel_err_x: 0.0170
# Epoch 10750 | Loss: -0.093047 | rel_err_u: 0.4022, rel_err_x: 0.0162
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 10800 | Loss: -0.093614 | rel_err_u: 0.3949, rel_err_x: 0.0154
# Epoch 10850 | Loss: -0.094161 | rel_err_u: 0.3877, rel_err_x: 0.0147
# Epoch 10900 | Loss: -0.094673 | rel_err_u: 0.3807, rel_err_x: 0.0140
# Epoch 10950 | Loss: -0.095156 | rel_err_u: 0.3738, rel_err_x: 0.0133
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 11000 | Loss: -0.095611 | rel_err_u: 0.3670, rel_err_x: 0.0127
# Epoch 11050 | Loss: -0.096041 | rel_err_u: 0.3604, rel_err_x: 0.0121
# Epoch 11100 | Loss: -0.096442 | rel_err_u: 0.3539, rel_err_x: 0.0115
# Epoch 11150 | Loss: -0.096831 | rel_err_u: 0.3475, rel_err_x: 0.0110
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 11200 | Loss: -0.097198 | rel_err_u: 0.3412, rel_err_x: 0.0105
# Epoch 11250 | Loss: -0.097537 | rel_err_u: 0.3350, rel_err_x: 0.0100
# Epoch 11300 | Loss: -0.097881 | rel_err_u: 0.3290, rel_err_x: 0.0096
# Epoch 11350 | Loss: -0.098202 | rel_err_u: 0.3230, rel_err_x: 0.0091
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 11400 | Loss: -0.098508 | rel_err_u: 0.3172, rel_err_x: 0.0087
# Epoch 11450 | Loss: -0.098799 | rel_err_u: 0.3116, rel_err_x: 0.0083
# Epoch 11500 | Loss: -0.099080 | rel_err_u: 0.3060, rel_err_x: 0.0080
# Epoch 11550 | Loss: -0.099348 | rel_err_u: 0.3005, rel_err_x: 0.0076
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 11600 | Loss: -0.099599 | rel_err_u: 0.2952, rel_err_x: 0.0073
# Epoch 11650 | Loss: -0.099846 | rel_err_u: 0.2900, rel_err_x: 0.0070
# Epoch 11700 | Loss: -0.100077 | rel_err_u: 0.2849, rel_err_x: 0.0067
# Epoch 11750 | Loss: -0.100296 | rel_err_u: 0.2799, rel_err_x: 0.0064
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 11800 | Loss: -0.100503 | rel_err_u: 0.2751, rel_err_x: 0.0061
# Epoch 11850 | Loss: -0.100700 | rel_err_u: 0.2703, rel_err_x: 0.0059
# Epoch 11900 | Loss: -0.100813 | rel_err_u: 0.2657, rel_err_x: 0.0057
# Epoch 11950 | Loss: -0.101064 | rel_err_u: 0.2612, rel_err_x: 0.0054
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 12000 | Loss: -0.101234 | rel_err_u: 0.2568, rel_err_x: 0.0052
# Epoch 12050 | Loss: -0.101393 | rel_err_u: 0.2525, rel_err_x: 0.0051
# Epoch 12100 | Loss: -0.101541 | rel_err_u: 0.2484, rel_err_x: 0.0049
# Epoch 12150 | Loss: -0.101688 | rel_err_u: 0.2444, rel_err_x: 0.0047
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 12200 | Loss: -0.101824 | rel_err_u: 0.2404, rel_err_x: 0.0046
# Epoch 12250 | Loss: -0.101938 | rel_err_u: 0.2366, rel_err_x: 0.0044
# Epoch 12300 | Loss: -0.102074 | rel_err_u: 0.2329, rel_err_x: 0.0043
# Epoch 12350 | Loss: -0.102190 | rel_err_u: 0.2293, rel_err_x: 0.0042
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 12400 | Loss: -0.102287 | rel_err_u: 0.2259, rel_err_x: 0.0041
# Epoch 12450 | Loss: -0.102401 | rel_err_u: 0.2225, rel_err_x: 0.0040
# Epoch 12500 | Loss: -0.102499 | rel_err_u: 0.2192, rel_err_x: 0.0039
# Epoch 12550 | Loss: -0.102451 | rel_err_u: 0.2160, rel_err_x: 0.0039
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 12600 | Loss: -0.102675 | rel_err_u: 0.2130, rel_err_x: 0.0038
# Epoch 12650 | Loss: -0.102760 | rel_err_u: 0.2101, rel_err_x: 0.0037
# Epoch 12700 | Loss: -0.102839 | rel_err_u: 0.2072, rel_err_x: 0.0036
# Epoch 12750 | Loss: -0.102914 | rel_err_u: 0.2044, rel_err_x: 0.0036
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 12800 | Loss: -0.102983 | rel_err_u: 0.2017, rel_err_x: 0.0035
# Epoch 12850 | Loss: -0.103046 | rel_err_u: 0.1991, rel_err_x: 0.0035
# Epoch 12900 | Loss: -0.103118 | rel_err_u: 0.1966, rel_err_x: 0.0035
# Epoch 12950 | Loss: -0.103180 | rel_err_u: 0.1941, rel_err_x: 0.0035
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 13000 | Loss: -0.103235 | rel_err_u: 0.1917, rel_err_x: 0.0034
# Epoch 13050 | Loss: -0.103294 | rel_err_u: 0.1894, rel_err_x: 0.0034
# Epoch 13100 | Loss: -0.103341 | rel_err_u: 0.1871, rel_err_x: 0.0034
# Epoch 13150 | Loss: -0.103397 | rel_err_u: 0.1850, rel_err_x: 0.0034
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 13200 | Loss: -0.103444 | rel_err_u: 0.1829, rel_err_x: 0.0034
# Epoch 13250 | Loss: -0.103488 | rel_err_u: 0.1809, rel_err_x: 0.0034
# Epoch 13300 | Loss: -0.103520 | rel_err_u: 0.1789, rel_err_x: 0.0034
# Epoch 13350 | Loss: -0.103573 | rel_err_u: 0.1770, rel_err_x: 0.0034
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 13400 | Loss: -0.103611 | rel_err_u: 0.1752, rel_err_x: 0.0034
# Epoch 13450 | Loss: -0.103646 | rel_err_u: 0.1734, rel_err_x: 0.0034
# Epoch 13500 | Loss: -0.103685 | rel_err_u: 0.1717, rel_err_x: 0.0034
# Epoch 13550 | Loss: -0.103719 | rel_err_u: 0.1700, rel_err_x: 0.0034
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 13600 | Loss: -0.103734 | rel_err_u: 0.1684, rel_err_x: 0.0034
# Epoch 13650 | Loss: -0.103781 | rel_err_u: 0.1669, rel_err_x: 0.0034
# Epoch 13700 | Loss: -0.103810 | rel_err_u: 0.1654, rel_err_x: 0.0034
# Epoch 13750 | Loss: -0.103493 | rel_err_u: 0.1639, rel_err_x: 0.0034
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 13800 | Loss: -0.103862 | rel_err_u: 0.1625, rel_err_x: 0.0034
# Epoch 13850 | Loss: -0.103886 | rel_err_u: 0.1612, rel_err_x: 0.0034
# Epoch 13900 | Loss: -0.103909 | rel_err_u: 0.1598, rel_err_x: 0.0034
# Epoch 13950 | Loss: -0.103917 | rel_err_u: 0.1585, rel_err_x: 0.0034
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 14000 | Loss: -0.103952 | rel_err_u: 0.1573, rel_err_x: 0.0034
# Epoch 14050 | Loss: -0.103972 | rel_err_u: 0.1561, rel_err_x: 0.0034
# Epoch 14100 | Loss: -0.103987 | rel_err_u: 0.1549, rel_err_x: 0.0033
# Epoch 14150 | Loss: -0.104012 | rel_err_u: 0.1538, rel_err_x: 0.0033
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 14200 | Loss: -0.104033 | rel_err_u: 0.1527, rel_err_x: 0.0033
# Epoch 14250 | Loss: -0.103989 | rel_err_u: 0.1516, rel_err_x: 0.0033
# Epoch 14300 | Loss: -0.104071 | rel_err_u: 0.1507, rel_err_x: 0.0033
# Epoch 14350 | Loss: -0.104093 | rel_err_u: 0.1498, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 14400 | Loss: -0.104103 | rel_err_u: 0.1489, rel_err_x: 0.0032
# Epoch 14450 | Loss: -0.104119 | rel_err_u: 0.1480, rel_err_x: 0.0032
# Epoch 14500 | Loss: -0.104142 | rel_err_u: 0.1472, rel_err_x: 0.0032
# Epoch 14550 | Loss: -0.104157 | rel_err_u: 0.1465, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 14600 | Loss: -0.104131 | rel_err_u: 0.1457, rel_err_x: 0.0032
# Epoch 14650 | Loss: -0.104184 | rel_err_u: 0.1450, rel_err_x: 0.0032
# Epoch 14700 | Loss: -0.104197 | rel_err_u: 0.1444, rel_err_x: 0.0032
# Epoch 14750 | Loss: -0.104211 | rel_err_u: 0.1437, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 14800 | Loss: -0.104206 | rel_err_u: 0.1431, rel_err_x: 0.0032
# Epoch 14850 | Loss: -0.104235 | rel_err_u: 0.1426, rel_err_x: 0.0032
# Epoch 14900 | Loss: -0.104248 | rel_err_u: 0.1421, rel_err_x: 0.0032
# Epoch 14950 | Loss: -0.103967 | rel_err_u: 0.1416, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 15000 | Loss: -0.104271 | rel_err_u: 0.1411, rel_err_x: 0.0032
# Epoch 15050 | Loss: -0.104283 | rel_err_u: 0.1407, rel_err_x: 0.0032
# Epoch 15100 | Loss: -0.104244 | rel_err_u: 0.1404, rel_err_x: 0.0032
# Epoch 15150 | Loss: -0.104304 | rel_err_u: 0.1400, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 15200 | Loss: -0.104315 | rel_err_u: 0.1397, rel_err_x: 0.0032
# Epoch 15250 | Loss: -0.104147 | rel_err_u: 0.1394, rel_err_x: 0.0032
# Epoch 15300 | Loss: -0.104333 | rel_err_u: 0.1392, rel_err_x: 0.0032
# Epoch 15350 | Loss: -0.104343 | rel_err_u: 0.1390, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 15400 | Loss: -0.104341 | rel_err_u: 0.1388, rel_err_x: 0.0032
# Epoch 15450 | Loss: -0.104358 | rel_err_u: 0.1387, rel_err_x: 0.0032
# Epoch 15500 | Loss: -0.104365 | rel_err_u: 0.1385, rel_err_x: 0.0032
# Epoch 15550 | Loss: -0.104371 | rel_err_u: 0.1384, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 15600 | Loss: -0.104377 | rel_err_u: 0.1383, rel_err_x: 0.0033
# Epoch 15650 | Loss: -0.104326 | rel_err_u: 0.1382, rel_err_x: 0.0032
# Epoch 15700 | Loss: -0.104386 | rel_err_u: 0.1381, rel_err_x: 0.0032
# Epoch 15750 | Loss: -0.104303 | rel_err_u: 0.1381, rel_err_x: 0.0033
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 15800 | Loss: -0.104392 | rel_err_u: 0.1380, rel_err_x: 0.0032
# Epoch 15850 | Loss: -0.104395 | rel_err_u: 0.1379, rel_err_x: 0.0032
# Epoch 15900 | Loss: -0.104394 | rel_err_u: 0.1379, rel_err_x: 0.0032
# Epoch 15950 | Loss: -0.104399 | rel_err_u: 0.1378, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 16000 | Loss: -0.104401 | rel_err_u: 0.1377, rel_err_x: 0.0032
# Epoch 16050 | Loss: -0.104288 | rel_err_u: 0.1377, rel_err_x: 0.0032
# Epoch 16100 | Loss: -0.104404 | rel_err_u: 0.1376, rel_err_x: 0.0032
# Epoch 16150 | Loss: -0.104405 | rel_err_u: 0.1376, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 16200 | Loss: -0.104405 | rel_err_u: 0.1375, rel_err_x: 0.0032
# Epoch 16250 | Loss: -0.104398 | rel_err_u: 0.1375, rel_err_x: 0.0032
# Epoch 16300 | Loss: -0.104405 | rel_err_u: 0.1374, rel_err_x: 0.0032
# Epoch 16350 | Loss: -0.104408 | rel_err_u: 0.1374, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 16400 | Loss: -0.104406 | rel_err_u: 0.1373, rel_err_x: 0.0032
# Epoch 16450 | Loss: -0.104409 | rel_err_u: 0.1373, rel_err_x: 0.0032
# Epoch 16500 | Loss: -0.104402 | rel_err_u: 0.1372, rel_err_x: 0.0032
# Epoch 16550 | Loss: -0.104409 | rel_err_u: 0.1372, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 16600 | Loss: -0.104410 | rel_err_u: 0.1371, rel_err_x: 0.0032
# Epoch 16650 | Loss: -0.104320 | rel_err_u: 0.1371, rel_err_x: 0.0032
# Epoch 16700 | Loss: -0.104410 | rel_err_u: 0.1371, rel_err_x: 0.0032
# Epoch 16750 | Loss: -0.104411 | rel_err_u: 0.1370, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 16800 | Loss: -0.104411 | rel_err_u: 0.1370, rel_err_x: 0.0032
# Epoch 16850 | Loss: -0.104373 | rel_err_u: 0.1369, rel_err_x: 0.0032
# Epoch 16900 | Loss: -0.104411 | rel_err_u: 0.1369, rel_err_x: 0.0032
# Epoch 16950 | Loss: -0.104412 | rel_err_u: 0.1369, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 17000 | Loss: -0.104412 | rel_err_u: 0.1368, rel_err_x: 0.0032
# Epoch 17050 | Loss: -0.104392 | rel_err_u: 0.1368, rel_err_x: 0.0032
# Epoch 17100 | Loss: -0.104412 | rel_err_u: 0.1368, rel_err_x: 0.0032
# Epoch 17150 | Loss: -0.104413 | rel_err_u: 0.1368, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 17200 | Loss: -0.104395 | rel_err_u: 0.1367, rel_err_x: 0.0032
# Epoch 17250 | Loss: -0.104409 | rel_err_u: 0.1367, rel_err_x: 0.0032
# Epoch 17300 | Loss: -0.104413 | rel_err_u: 0.1367, rel_err_x: 0.0032
# Epoch 17350 | Loss: -0.104413 | rel_err_u: 0.1367, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 17400 | Loss: -0.104411 | rel_err_u: 0.1366, rel_err_x: 0.0032
# Epoch 17450 | Loss: -0.104412 | rel_err_u: 0.1366, rel_err_x: 0.0032
# Epoch 17500 | Loss: -0.104413 | rel_err_u: 0.1366, rel_err_x: 0.0032
# Epoch 17550 | Loss: -0.104163 | rel_err_u: 0.1366, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 17600 | Loss: -0.104412 | rel_err_u: 0.1366, rel_err_x: 0.0031
# Epoch 17650 | Loss: -0.104413 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Epoch 17700 | Loss: -0.104373 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Epoch 17750 | Loss: -0.104413 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 17800 | Loss: -0.104414 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Epoch 17850 | Loss: -0.104409 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Epoch 17900 | Loss: -0.104414 | rel_err_u: 0.1365, rel_err_x: 0.0031
# Epoch 17950 | Loss: -0.104407 | rel_err_u: 0.1364, rel_err_x: 0.0032
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 18000 | Loss: -0.104414 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18050 | Loss: -0.104414 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18100 | Loss: -0.104412 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18150 | Loss: -0.104414 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 18200 | Loss: -0.104351 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18250 | Loss: -0.104412 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18300 | Loss: -0.104383 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Epoch 18350 | Loss: -0.104413 | rel_err_u: 0.1364, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 18400 | Loss: -0.104336 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18450 | Loss: -0.104414 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18500 | Loss: -0.104387 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18550 | Loss: -0.104410 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 18600 | Loss: -0.104414 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18650 | Loss: -0.104377 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18700 | Loss: -0.104413 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18750 | Loss: -0.104414 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 18800 | Loss: -0.104140 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18850 | Loss: -0.104413 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18900 | Loss: -0.104414 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 18950 | Loss: -0.104414 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 19000 | Loss: -0.104309 | rel_err_u: 0.1363, rel_err_x: 0.0031
# Epoch 19050 | Loss: -0.104414 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19100 | Loss: -0.104415 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19150 | Loss: -0.104400 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 19200 | Loss: -0.104414 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19250 | Loss: -0.104415 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19300 | Loss: -0.104411 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19350 | Loss: -0.104414 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 19400 | Loss: -0.104360 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19450 | Loss: -0.104413 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19500 | Loss: -0.104415 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19550 | Loss: -0.104397 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 19600 | Loss: -0.104414 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19650 | Loss: -0.104389 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19700 | Loss: -0.104286 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19750 | Loss: -0.104415 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 19800 | Loss: -0.104330 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19850 | Loss: -0.104414 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19900 | Loss: -0.104394 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Epoch 19950 | Loss: -0.104406 | rel_err_u: 0.1362, rel_err_x: 0.0031
# Plot saved to found_trajectories/nonlinear/deeponet/plot.png
# Epoch 20000 | Loss: -0.104415 | rel_err_u: 0.1362, rel_err_x: 0.0031

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: -0.10695081204175949

# %% [markdown]
# <image src="found_trajectories/nonlinear/deeponet/plot.png" width = 600>

# %% [markdown]
# # Control problem with Singular Arc

# %%
model = DeepONetCartesianProd(branch_net, trunk_net, branch_activations, trunk_activations)
model.to(device)

ckpt = torch.load("trained_models/singular_arc/deeponet/unsupervised/epoch[1500]_model_time_[20250717_220059]_loss_[0.0059].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True) - 3 

w = [10, 1, 1, 1, 10]

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'singular_arc', initial_guess,
    lr=0.001,
    architecture="deeponet",  
    w=w,
    num_epochs=10000,
    m=m,
    bounds = [-3.5, 0],
    device=device, logging = True
)
# Out:
# Epoch   50 | Loss: 10.701880 | rel_err_u: 1.0008, rel_err_x: 1.2033
# Epoch  100 | Loss: 10.295107 | rel_err_u: 0.9726, rel_err_x: 1.1552
# Epoch  150 | Loss: 9.911869 | rel_err_u: 0.9446, rel_err_x: 1.1068
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch  200 | Loss: 9.550135 | rel_err_u: 0.9170, rel_err_x: 1.0587
# Epoch  250 | Loss: 9.208881 | rel_err_u: 0.8898, rel_err_x: 1.0111
# Epoch  300 | Loss: 8.887429 | rel_err_u: 0.8631, rel_err_x: 0.9643
# Epoch  350 | Loss: 8.585202 | rel_err_u: 0.8370, rel_err_x: 0.9184
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch  400 | Loss: 8.301638 | rel_err_u: 0.8115, rel_err_x: 0.8736
# Epoch  450 | Loss: 8.036135 | rel_err_u: 0.7866, rel_err_x: 0.8302
# Epoch  500 | Loss: 7.788013 | rel_err_u: 0.7623, rel_err_x: 0.7882
# Epoch  550 | Loss: 7.556484 | rel_err_u: 0.7384, rel_err_x: 0.7478
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch  600 | Loss: 7.340657 | rel_err_u: 0.7151, rel_err_x: 0.7092
# Epoch  650 | Loss: 7.139546 | rel_err_u: 0.6922, rel_err_x: 0.6725
# Epoch  700 | Loss: 6.952101 | rel_err_u: 0.6698, rel_err_x: 0.6376
# Epoch  750 | Loss: 6.777232 | rel_err_u: 0.6477, rel_err_x: 0.6048
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch  800 | Loss: 6.613853 | rel_err_u: 0.6260, rel_err_x: 0.5739
# Epoch  850 | Loss: 6.460902 | rel_err_u: 0.6046, rel_err_x: 0.5449
# Epoch  900 | Loss: 6.317382 | rel_err_u: 0.5836, rel_err_x: 0.5177
# Epoch  950 | Loss: 6.182376 | rel_err_u: 0.5628, rel_err_x: 0.4923
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 1000 | Loss: 6.055061 | rel_err_u: 0.5424, rel_err_x: 0.4686
# Epoch 1050 | Loss: 5.934719 | rel_err_u: 0.5222, rel_err_x: 0.4464
# Epoch 1100 | Loss: 5.820730 | rel_err_u: 0.5024, rel_err_x: 0.4256
# Epoch 1150 | Loss: 5.712570 | rel_err_u: 0.4828, rel_err_x: 0.4062
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 1200 | Loss: 5.609797 | rel_err_u: 0.4636, rel_err_x: 0.3879
# Epoch 1250 | Loss: 5.512041 | rel_err_u: 0.4447, rel_err_x: 0.3707
# Epoch 1300 | Loss: 5.418994 | rel_err_u: 0.4261, rel_err_x: 0.3546
# Epoch 1350 | Loss: 5.330393 | rel_err_u: 0.4079, rel_err_x: 0.3393
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 1400 | Loss: 5.246014 | rel_err_u: 0.3901, rel_err_x: 0.3250
# Epoch 1450 | Loss: 5.165662 | rel_err_u: 0.3726, rel_err_x: 0.3114
# Epoch 1500 | Loss: 5.089166 | rel_err_u: 0.3556, rel_err_x: 0.2985
# Epoch 1550 | Loss: 5.016370 | rel_err_u: 0.3390, rel_err_x: 0.2864
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 1600 | Loss: 4.947132 | rel_err_u: 0.3229, rel_err_x: 0.2749
# Epoch 1650 | Loss: 4.881320 | rel_err_u: 0.3072, rel_err_x: 0.2640
# Epoch 1700 | Loss: 4.818810 | rel_err_u: 0.2921, rel_err_x: 0.2537
# Epoch 1750 | Loss: 4.759481 | rel_err_u: 0.2775, rel_err_x: 0.2440
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 1800 | Loss: 4.703223 | rel_err_u: 0.2635, rel_err_x: 0.2348
# Epoch 1850 | Loss: 4.649921 | rel_err_u: 0.2501, rel_err_x: 0.2261
# Epoch 1900 | Loss: 4.599472 | rel_err_u: 0.2373, rel_err_x: 0.2180
# Epoch 1950 | Loss: 4.551768 | rel_err_u: 0.2252, rel_err_x: 0.2104
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 2000 | Loss: 4.506707 | rel_err_u: 0.2139, rel_err_x: 0.2033
# Epoch 2050 | Loss: 4.464188 | rel_err_u: 0.2033, rel_err_x: 0.1967
# Epoch 2100 | Loss: 4.424111 | rel_err_u: 0.1935, rel_err_x: 0.1905
# Epoch 2150 | Loss: 4.386378 | rel_err_u: 0.1847, rel_err_x: 0.1849
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 2200 | Loss: 4.350891 | rel_err_u: 0.1767, rel_err_x: 0.1797
# Epoch 2250 | Loss: 4.317554 | rel_err_u: 0.1697, rel_err_x: 0.1750
# Epoch 2300 | Loss: 4.286271 | rel_err_u: 0.1638, rel_err_x: 0.1707
# Epoch 2350 | Loss: 4.256946 | rel_err_u: 0.1588, rel_err_x: 0.1668
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 2400 | Loss: 4.229573 | rel_err_u: 0.1547, rel_err_x: 0.1631
# Epoch 2450 | Loss: 4.203969 | rel_err_u: 0.1516, rel_err_x: 0.1599
# Epoch 2500 | Loss: 4.180033 | rel_err_u: 0.1496, rel_err_x: 0.1572
# Epoch 2550 | Loss: 4.157674 | rel_err_u: 0.1485, rel_err_x: 0.1549
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 2600 | Loss: 4.136806 | rel_err_u: 0.1483, rel_err_x: 0.1530
# Epoch 2650 | Loss: 4.117380 | rel_err_u: 0.1489, rel_err_x: 0.1514
# Epoch 2700 | Loss: 4.099345 | rel_err_u: 0.1502, rel_err_x: 0.1500
# Epoch 2750 | Loss: 4.082557 | rel_err_u: 0.1521, rel_err_x: 0.1489
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 2800 | Loss: 4.066928 | rel_err_u: 0.1546, rel_err_x: 0.1482
# Epoch 2850 | Loss: 4.052381 | rel_err_u: 0.1576, rel_err_x: 0.1478
# Epoch 2900 | Loss: 4.038839 | rel_err_u: 0.1611, rel_err_x: 0.1477
# Epoch 2950 | Loss: 4.026230 | rel_err_u: 0.1650, rel_err_x: 0.1479
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 3000 | Loss: 4.014482 | rel_err_u: 0.1691, rel_err_x: 0.1484
# Epoch 3050 | Loss: 4.003526 | rel_err_u: 0.1735, rel_err_x: 0.1491
# Epoch 3100 | Loss: 3.993295 | rel_err_u: 0.1781, rel_err_x: 0.1500
# Epoch 3150 | Loss: 3.983722 | rel_err_u: 0.1829, rel_err_x: 0.1511
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 3200 | Loss: 3.974751 | rel_err_u: 0.1877, rel_err_x: 0.1523
# Epoch 3250 | Loss: 3.966324 | rel_err_u: 0.1926, rel_err_x: 0.1536
# Epoch 3300 | Loss: 3.958370 | rel_err_u: 0.1977, rel_err_x: 0.1551
# Epoch 3350 | Loss: 3.950837 | rel_err_u: 0.2027, rel_err_x: 0.1569
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 3400 | Loss: 3.943693 | rel_err_u: 0.2079, rel_err_x: 0.1588
# Epoch 3450 | Loss: 3.936942 | rel_err_u: 0.2131, rel_err_x: 0.1609
# Epoch 3500 | Loss: 3.930637 | rel_err_u: 0.2183, rel_err_x: 0.1631
# Epoch 3550 | Loss: 3.924862 | rel_err_u: 0.2234, rel_err_x: 0.1654
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 3600 | Loss: 3.919686 | rel_err_u: 0.2283, rel_err_x: 0.1678
# Epoch 3650 | Loss: 3.915128 | rel_err_u: 0.2329, rel_err_x: 0.1701
# Epoch 3700 | Loss: 3.911186 | rel_err_u: 0.2372, rel_err_x: 0.1723
# Epoch 3750 | Loss: 3.907761 | rel_err_u: 0.2413, rel_err_x: 0.1744
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 3800 | Loss: 3.904788 | rel_err_u: 0.2451, rel_err_x: 0.1764
# Epoch 3850 | Loss: 3.902212 | rel_err_u: 0.2487, rel_err_x: 0.1782
# Epoch 3900 | Loss: 3.899982 | rel_err_u: 0.2520, rel_err_x: 0.1800
# Epoch 3950 | Loss: 3.898056 | rel_err_u: 0.2551, rel_err_x: 0.1816
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 4000 | Loss: 3.896394 | rel_err_u: 0.2580, rel_err_x: 0.1831
# Epoch 4050 | Loss: 3.894963 | rel_err_u: 0.2607, rel_err_x: 0.1845
# Epoch 4100 | Loss: 3.893737 | rel_err_u: 0.2631, rel_err_x: 0.1857
# Epoch 4150 | Loss: 3.892684 | rel_err_u: 0.2654, rel_err_x: 0.1869
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 4200 | Loss: 3.891781 | rel_err_u: 0.2676, rel_err_x: 0.1880
# Epoch 4250 | Loss: 3.891012 | rel_err_u: 0.2695, rel_err_x: 0.1889
# Epoch 4300 | Loss: 3.890357 | rel_err_u: 0.2713, rel_err_x: 0.1898
# Epoch 4350 | Loss: 3.889800 | rel_err_u: 0.2729, rel_err_x: 0.1906
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 4400 | Loss: 3.889327 | rel_err_u: 0.2745, rel_err_x: 0.1913
# Epoch 4450 | Loss: 3.888927 | rel_err_u: 0.2758, rel_err_x: 0.1920
# Epoch 4500 | Loss: 3.888588 | rel_err_u: 0.2771, rel_err_x: 0.1926
# Epoch 4550 | Loss: 3.888303 | rel_err_u: 0.2783, rel_err_x: 0.1932
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 4600 | Loss: 3.888064 | rel_err_u: 0.2794, rel_err_x: 0.1937
# Epoch 4650 | Loss: 3.887868 | rel_err_u: 0.2803, rel_err_x: 0.1942
# Epoch 4700 | Loss: 3.887713 | rel_err_u: 0.2811, rel_err_x: 0.1946
# Epoch 4750 | Loss: 3.887586 | rel_err_u: 0.2818, rel_err_x: 0.1949
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 4800 | Loss: 3.887483 | rel_err_u: 0.2825, rel_err_x: 0.1953
# Epoch 4850 | Loss: 3.887399 | rel_err_u: 0.2831, rel_err_x: 0.1956
# Epoch 4900 | Loss: 3.887330 | rel_err_u: 0.2836, rel_err_x: 0.1958
# Epoch 4950 | Loss: 3.887273 | rel_err_u: 0.2841, rel_err_x: 0.1961
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 5000 | Loss: 3.887228 | rel_err_u: 0.2845, rel_err_x: 0.1963
# Epoch 5050 | Loss: 3.887192 | rel_err_u: 0.2849, rel_err_x: 0.1965
# Epoch 5100 | Loss: 3.887162 | rel_err_u: 0.2852, rel_err_x: 0.1967
# Epoch 5150 | Loss: 3.887138 | rel_err_u: 0.2855, rel_err_x: 0.1968
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 5200 | Loss: 3.887119 | rel_err_u: 0.2858, rel_err_x: 0.1969
# Epoch 5250 | Loss: 3.887104 | rel_err_u: 0.2860, rel_err_x: 0.1971
# Epoch 5300 | Loss: 3.887094 | rel_err_u: 0.2862, rel_err_x: 0.1971
# Epoch 5350 | Loss: 3.887085 | rel_err_u: 0.2863, rel_err_x: 0.1972
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 5400 | Loss: 3.887078 | rel_err_u: 0.2864, rel_err_x: 0.1973
# Epoch 5450 | Loss: 3.887074 | rel_err_u: 0.2866, rel_err_x: 0.1974
# Epoch 5500 | Loss: 3.887069 | rel_err_u: 0.2867, rel_err_x: 0.1974
# Epoch 5550 | Loss: 3.887066 | rel_err_u: 0.2868, rel_err_x: 0.1975
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 5600 | Loss: 3.887064 | rel_err_u: 0.2868, rel_err_x: 0.1975
# Epoch 5650 | Loss: 3.887062 | rel_err_u: 0.2869, rel_err_x: 0.1976
# Epoch 5700 | Loss: 3.887060 | rel_err_u: 0.2870, rel_err_x: 0.1976
# Epoch 5750 | Loss: 3.887059 | rel_err_u: 0.2870, rel_err_x: 0.1976
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 5800 | Loss: 3.887058 | rel_err_u: 0.2871, rel_err_x: 0.1976
# Epoch 5850 | Loss: 3.887057 | rel_err_u: 0.2871, rel_err_x: 0.1977
# Epoch 5900 | Loss: 3.887056 | rel_err_u: 0.2871, rel_err_x: 0.1977
# Epoch 5950 | Loss: 3.887056 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 6000 | Loss: 3.887056 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Epoch 6050 | Loss: 3.887055 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Epoch 6100 | Loss: 3.887056 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Epoch 6150 | Loss: 3.887055 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 6200 | Loss: 3.887055 | rel_err_u: 0.2872, rel_err_x: 0.1977
# Epoch 6250 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6300 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6350 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 6400 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6450 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6500 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6550 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 6600 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6650 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6700 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6750 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 6800 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6850 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6900 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 6950 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 7000 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7050 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7100 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7150 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 7200 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7250 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7300 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7350 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 7400 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7450 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7500 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7550 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 7600 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7650 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7700 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7750 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 7800 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7850 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7900 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 7950 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 8000 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8050 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8100 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8150 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 8200 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8250 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8300 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8350 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 8400 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8450 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8500 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8550 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 8600 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8650 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8700 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8750 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 8800 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8850 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8900 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 8950 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 9000 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9050 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9100 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9150 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 9200 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9250 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9300 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9350 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 9400 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9450 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9500 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9550 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 9600 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9650 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9700 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9750 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 9800 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9850 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9900 | Loss: 3.887054 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Epoch 9950 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978
# Plot saved to found_trajectories/singular_arc/deeponet/plot.png
# Epoch 10000 | Loss: 3.887055 | rel_err_u: 0.2873, rel_err_x: 0.1978

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 2.1729605197906494

# %% [markdown]
# <image src="found_trajectories/singular_arc/deeponet/plot.png" width = 600>

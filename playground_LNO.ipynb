# %% [markdown]
# # Notebook \#3 - Laplace Neural Operator

# %% [markdown]
# In this jupyter notebook, we are going to cover how Laplace Neural Operator can be used to solve a control problem that has differential equation as one of the constraint. The structure of the notebooks is as follows:
# - Preinstall and import all needed libraries
# - Generate a training dataset
# - Train operator
# - Solve optimization problem
# - Compare with analytical solution

# %%
#Make sure that you have installed all dependencies
#pip install -r requirements.txt
from torch.utils.data import DataLoader
import numpy as np

# utils folder contains all the functions to load the data, train the model and plot the results
# models folder contains the model architectures
from utils.data import MultiFunctionDatasetODE, custom_collate_ODE_fn_fno 
from models.lno import *
from utils.scripts import *

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Generate Dataset

# %% [markdown]
# Suppose we have a parametric differential equation. This can be any arbitrary ode/pde, but for the sake of simplicity, let it be:
# $$\frac{dx}{dt} - x(t) + u(t) = 0$$
# where $u(t)$ is some arbitrary function or "parameter". And $x(t)$ is such function that ode is solved correctly.
#
# We would like to train a model that can learn a mapping $u(t)\rightarrow x(t)$
#
# At first we need to generate a dataset. This can be done using `MultiFunctionDatasetODE` function. It would generate 1000000 functions of different function families (`'grf', 'linear', 'sine', 'polynomial', 'constant'`).
#
# The time range would be $[0,1]$. For the Laplace Neural Operator, time should be discretized. In our case we set `m=200`, implying "200 sensors" or measurments.
#
# We split this into batches of size `1024`

# %%
n_functions = 1000000
end_time = 1.0
batch_size = 1024
m = 200

dataset = MultiFunctionDatasetODE(
    m=m,
    n_functions=n_functions,
    function_types=['grf', 'linear', 'sine', 'polynomial','constant'],
    end_time = end_time,
    num_domain = 200,
    num_initial = 20,
    grf_lb = 0.02,
    grf_ub = 0.5
)

dataloader = DataLoader(dataset, batch_size=batch_size, collate_fn=custom_collate_ODE_fn_fno, shuffle=True)

# %% [markdown]
# # Laplace Neural Operator

# %% [markdown]
# You can find source code of the FNO in the `models/fno.py` file.

# %% [markdown]
# ## Theory

# %% [markdown]
# ## Lagrangian Neural Operator (LNO): Key Ideas
#
# - **Follow the flow**
#   Track the solution along characteristic trajectories $\xi(t)$ instead of fixed-grid points.
#
# - **Rational dynamics**
#   Learn a small set of complex poles $p_k$ and residues $r_k$ so that
#   $$
#     x_{\rm trans}(t)
#     = \mathcal{F}^{-1}\!\Bigl[\frac{r_k}{i\omega - p_k}\,\hat{x}(\omega)\Bigr],
#   $$
#   $$
#     x_{\rm ss}(t)
#     = \sum_k\Bigl(-\frac{r_k}{i\,p_k}\Bigr)\,e^{p_k t}.
#   $$
#
# - **Local refinement**
#   A lightweight $1\times1$ convolution (or MLP) corrects fine-scale and nonlinear features.
#
# - **Why it works**
#   Combines interpretable global filters (few exponentials) with flexible local corrections, yielding compact, accurate operator approximations.

# %% [markdown]
# ## Train model

# %% [markdown]
# The workflow is simple. To create a model, you need to call `LNO1d()`. It has only input parameters `modes` and `width`.

# %%
modes = 16
width = 8
model = LNO1d(width, modes, hidden_layer=128).cuda()

# %% [markdown]
# Then you need to define `optimizer` and `scheduler` with any preferable settings

# %%
step_size = 100
gamma = 0.9
learning_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate, weight_decay=1e-4)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=step_size, gamma=gamma)

# %% [markdown]
# To train LNO, you need to use your custom train function that depends on your problem. In our case, we have `train_lno()` from `utils.scripts.py`
#
# Notice that `train_lno()` uses function `compute_loss()`, which is defined in the same file. Basically, this functions tells FNO that we are trying to learn:
# $$\frac{dx}{dt} + x(t) - u(t) = 0$$
# $$x(0) = 1$$
# $$t\in[0,1]$$
#
# Thus, in this problem we have 2 "sources of loss": initial and physics loss. You can define variable `w` to set different weights to either of losses.
#
# After every `10 epoch`, model is saved. Make sure to define a folder where you want to store models. By default, it is `trained_models/lno`

# %%
epochs = 10
trained_model = train_lno(model, compute_loss_ode, dataloader, optimizer, scheduler, epochs, logging=False)
# Out:
# Epoch [1/10], Loss: 0.901283, Time: 45.84896 s
# Epoch [2/10], Loss: 0.178941, Time: 45.538123 s
# Epoch [3/10], Loss: 0.408194, Time: 45.587836 s
# Epoch [4/10], Loss: 0.318540, Time: 45.646628 s
# Epoch [5/10], Loss: 0.141051, Time: 45.550506 s
# Epoch [6/10], Loss: 0.095547, Time: 45.472953 s
# Epoch [7/10], Loss: 0.080240, Time: 45.44222 s
# Epoch [8/10], Loss: 0.252535, Time: 45.299252 s
# Epoch [9/10], Loss: 0.072714, Time: 45.331971 s
# Epoch [10/10], Loss: 0.035377, Time: 45.398242 s

# %% [markdown]
# LNO is taking much longer time than FNO to converge to something substantial

# %% [markdown]
# ## Load pre-trained model

# %% [markdown]
# Or you can just load pre-trained model as usually

# %%
modes = 16
width = 8

trained_model = LNO1d(width, modes)
trained_model.to(device)
trained_model.load_state_dict(torch.load('trained_models/lno/width-[8]-modes[16]/epochs_[50]_model_time_[20250423-174005]_loss_[0.0027].pth'))
trained_model.eval()  #
# Out:
# LNO1d(
#   (fc0): Linear(in_features=2, out_features=8, bias=True)
#   (conv0): PR()
#   (w0): Conv1d(8, 8, kernel_size=(1,), stride=(1,))
#   (fc1): Linear(in_features=8, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=1, bias=True)
# )

# %% [markdown]
# # Solve Control Problem

# %% [markdown]
# Once we succesefully trained Fourier Neural Operator. We can solve next control problem:
# $$\text{min}_u \ \int_{0}^{1} (x^2 + u^2)dt$$
# $$\text{s.t.} \ \frac{dx}{dt} = x - u$$
# $$ x(0) = 1$$
#
# ***Note:*** everything related to implementation of objective function was explained in a notebook related to Deep-O-Net in `playground.ipynb`
#
# Idea is simple, we have a model that maps $u$ to $x$. We can start from some random function $u$, find $x$ that solves ode and initial condition using NN. Calculate objective function:
# $$\text{min}_u \ \int_{0}^{1} (x^2 + u^2)dt$$
# Update $u$ and repeat process again.
#
# The whole process relies on the fact that LNO indeed can provide solution $x$.
#
# `optimize_neural_operator()` solves this problem given pretrained FNO model. Notice that it has as input parameter `objective_function()`

# %%
m = 200 
end_time = 1
epochs = 1500
learning_rate = 0.001

u_opt, x_opt, t = optimize_neural_operator(trained_model, objective_function, m, end_time, epochs, learning_rate)
# Out:
# Epoch [100/1500], Loss: 0.4404, time: 02:00:27.751717
# Epoch [200/1500], Loss: 0.4134, time: 02:00:28.041957
# Epoch [300/1500], Loss: 0.3972, time: 02:00:28.331528
# Epoch [400/1500], Loss: 0.3873, time: 02:00:28.620401
# Epoch [500/1500], Loss: 0.3813, time: 02:00:28.908535
# Epoch [600/1500], Loss: 0.3775, time: 02:00:29.197548
# Epoch [700/1500], Loss: 0.3753, time: 02:00:29.487938
# Epoch [800/1500], Loss: 0.3739, time: 02:00:29.776969
# Epoch [900/1500], Loss: 0.3731, time: 02:00:30.065850
# Epoch [1000/1500], Loss: 0.3727, time: 02:00:30.354102
# Epoch [1100/1500], Loss: 0.3724, time: 02:00:30.644869
# Epoch [1200/1500], Loss: 0.3723, time: 02:00:30.934101
# Epoch [1300/1500], Loss: 0.3722, time: 02:00:31.223467
# Epoch [1400/1500], Loss: 0.3722, time: 02:00:31.516071
# Epoch [1500/1500], Loss: 0.3721, time: 02:00:31.807217

# %% [markdown]
# ## Comparison with analytical solution

# %% [markdown]
# From the paper "Convergence of the forward-backward sweep method in optimal control" by Michael McAsey et al, we know that analytical solution for this problem is:
#
# $$x(t) = \frac{\sqrt{2}\cosh(\sqrt{2}(t-1)) - \sinh(\sqrt{2}(t-1))}{\sqrt{2}\cosh(\sqrt{2})+\sinh{\sqrt{2}}}$$
# $$u(t) = \frac{\sinh(\sqrt{2}(t-1))}{\sqrt{2}\cosh(\sqrt{2})+\sinh{\sqrt{2}}}$$
#
# We can use these functions to confirm that we indeed found an optimal solution.

# %%
def analytical_x(t):
    numerator = np.sqrt(2) * np.cosh(np.sqrt(2) * (t - 1)) - np.sinh(np.sqrt(2) * (t - 1))
    denominator = np.sqrt(2) * np.cosh(np.sqrt(2)) + np.sinh(np.sqrt(2))
    return numerator / denominator

def analytical_u(t):
    numerator = np.sinh(np.sqrt(2) * (t - 1))
    denominator = np.sqrt(2) * np.cosh(np.sqrt(2)) + np.sinh(np.sqrt(2))
    return numerator / denominator

t_plot = np.linspace(0, end_time, m)

analytical_x_vals = analytical_x(t_plot)
analytical_u_vals = analytical_u(t_plot)

x_found = x_opt.cpu().detach().numpy().flatten()
u_found = u_opt.cpu().detach().numpy().flatten()
u_tensor = torch.from_numpy(analytical_u_vals).float().unsqueeze(0).to(device)

# %% [markdown]
# Solution found by LNO is not perfect, but follows the shape of the analytical solution. When try find $x$ for the true analytical $u$, it returns the same function as "optimal" $x$ found by LNO. But it is slightly off (smaller) than true analytical $x$.

# %%
plot_analytical_and_found_solutions(t_plot, analytical_x_vals, x_found, analytical_u_vals, u_found)

# %%
trained_model = LNO1d(modes=16, width=8, hidden_layer=128)
trained_model.to(device)
trained_model.load_state_dict(torch.load('trained_models/lno/epochs_[10]_model_time_[20250504-215407]_loss_[0.0045].pth'))
trained_model.eval()  #
# Out:
# LNO1d(
#   (fc0): Linear(in_features=2, out_features=8, bias=True)
#   (conv0): PR()
#   (w0): Conv1d(8, 8, kernel_size=(1,), stride=(1,))
#   (fc1): Linear(in_features=8, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=1, bias=True)
# )

# %%
m = 200 
end_time = 1
epochs = 12000
learning_rate = 0.001

u_opt, x_opt, t_opt = optimize_neural_operator(trained_model, objective_function_nde, m, end_time, epochs, learning_rate,  w=[1,2, 0], model_name="lno")
# Out:
# /m/home/home8/87/begantm1/data/Documents/Thesis/utils/scripts.py:342: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   t = torch.tensor(torch.linspace(0, 1, m), dtype=torch.float).reshape(1, m, 1).to(device).repeat([u.shape[0], 1, 1]).clone().detach().requires_grad_(True)
# tensor([[-2.4184]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4183]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4184]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4184]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4185]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4185]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4186]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4187]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4187]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4188]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4189]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4189]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4190]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4191]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4192]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4193]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4194]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4195]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4196]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4197]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4198]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4199]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4200]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4202]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4203]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4204]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4206]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4207]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4208]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4210]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4211]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4213]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4215]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4216]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4218]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4220]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4222]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4223]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4225]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4227]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4229]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4231]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4233]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4235]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4237]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4239]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4241]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4243]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4246]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4248]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4250]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4252]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4255]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4257]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4260]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4262]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4265]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4267]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4270]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4272]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4275]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4278]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4281]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4283]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4286]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4289]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4292]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4295]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4298]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4301]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4304]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4307]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4310]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4313]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4316]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4319]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4323]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4326]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4329]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4332]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4336]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4339]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4343]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4346]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4350]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4353]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4357]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4360]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4364]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4368]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [100/12000], Loss: 1.2950, time: 22:05:28.247398
# tensor([[-2.4371]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4375]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4379]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4383]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4386]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4390]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4394]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4398]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4402]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4406]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4410]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4414]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4418]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4422]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4426]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4431]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4435]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4439]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4443]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4447]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4452]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4456]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4460]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4465]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4469]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4474]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4478]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4483]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4487]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4491]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4496]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4501]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4505]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4510]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4515]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4519]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4524]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4529]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4533]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4538]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4543]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4548]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4553]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4558]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4562]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4567]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4572]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4577]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4582]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4587]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4592]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4597]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4602]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4608]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4613]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4618]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4623]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4628]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4633]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4639]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4644]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4649]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4655]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4660]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4665]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4671]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4676]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4681]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4687]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4692]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4698]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4703]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4709]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4714]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4720]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4725]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4731]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4737]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4742]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4748]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4754]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4759]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4765]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4771]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4777]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4782]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4788]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4794]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4800]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4806]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4812]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4818]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4824]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4829]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4835]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4841]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4847]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4853]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4859]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4866]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [200/12000], Loss: -0.8541, time: 22:05:28.578546
# tensor([[-2.4872]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4878]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4884]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4890]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4896]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4902]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4908]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4915]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4921]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4927]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4933]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4940]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4946]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4952]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4958]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4965]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4971]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4977]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4984]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4990]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.4997]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5003]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5009]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5016]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5022]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5029]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5035]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5042]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5048]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5055]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5062]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5068]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5075]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5081]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5088]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5095]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5101]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5108]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5114]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5121]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5128]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5135]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5141]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5148]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5155]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5162]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5168]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5175]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5182]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5189]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5196]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5202]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5209]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5216]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5223]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5230]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5237]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5244]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5251]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5257]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5264]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5271]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5278]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5285]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5292]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5299]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5306]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5313]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5320]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5327]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5334]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5341]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5348]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5356]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5363]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5370]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5377]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5384]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5391]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5398]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5405]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5412]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5420]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5427]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5434]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5441]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5448]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5456]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5463]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5470]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5477]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5484]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5492]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5499]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5506]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5513]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5521]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5528]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5535]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5543]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [300/12000], Loss: -1.8167, time: 22:05:28.913589
# tensor([[-2.5550]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5557]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5565]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5572]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5579]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5587]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5594]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5601]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5609]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5616]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5623]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5631]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5638]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5646]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5653]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5660]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5668]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5675]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5683]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5690]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5698]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5705]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5713]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5720]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5728]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5735]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5742]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5750]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5757]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5765]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5773]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5780]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5788]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5795]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5803]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5810]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5818]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5825]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5833]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5840]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5848]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5856]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5863]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5871]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5878]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5886]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5894]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5901]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5909]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5916]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5924]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5932]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5939]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5947]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5955]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5962]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5970]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5978]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5985]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.5993]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6001]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6008]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6016]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6024]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6031]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6039]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6047]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6055]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6062]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6070]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6078]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6085]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6093]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6101]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6109]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6116]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6124]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6132]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6140]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6147]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6155]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6163]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6171]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6179]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6186]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6194]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6202]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6210]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6218]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6225]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6233]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6241]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6249]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6257]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6264]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6272]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6280]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6288]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6296]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6304]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [400/12000], Loss: -2.2926, time: 22:05:29.243539
# tensor([[-2.6312]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6319]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6327]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6335]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6343]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6351]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6359]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6367]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6374]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6382]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6390]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6398]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6406]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6414]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6422]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6430]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6438]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6445]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6453]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6461]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6469]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6477]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6485]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6493]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6501]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6509]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6517]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6525]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6533]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6541]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6549]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6557]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6565]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6573]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6580]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6588]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6596]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6604]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6612]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6620]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6628]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6636]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6644]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6652]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6660]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6668]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6676]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6684]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6692]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6700]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6708]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6716]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6724]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6733]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6741]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6749]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6757]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6765]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6773]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6781]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6789]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6797]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6805]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6813]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6821]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6829]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6837]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6845]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6853]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6861]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6870]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6878]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6886]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6894]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6902]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6910]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6918]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6926]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6934]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6942]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6951]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6959]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6967]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6975]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6983]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6991]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.6999]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7007]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7016]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7024]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7032]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7040]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7048]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7056]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7065]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7073]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7081]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7089]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7097]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7105]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [500/12000], Loss: -2.5433, time: 22:05:29.573874
# tensor([[-2.7114]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7122]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7130]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7138]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7146]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7155]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7163]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7171]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7179]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7187]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7196]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7204]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7212]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7220]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7229]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7237]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7245]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7253]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7261]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7270]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7278]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7286]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7294]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7303]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7311]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7319]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7328]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7336]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7344]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7352]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7361]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7369]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7377]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7386]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7394]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7402]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7410]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7419]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7427]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7435]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7444]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7452]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7460]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7469]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7477]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7485]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7494]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7502]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7510]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7519]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7527]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7535]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7544]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7552]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7560]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7569]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7577]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7586]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7594]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7602]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7611]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7619]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7627]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7636]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7644]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7653]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7661]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7669]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7678]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7686]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7695]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7703]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7711]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7720]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7728]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7737]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7745]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7754]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7762]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7771]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7779]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7787]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7796]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7804]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7813]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7821]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7830]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7838]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7847]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7855]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7864]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7872]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7881]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7889]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7898]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7906]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7915]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7923]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7932]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7940]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [600/12000], Loss: -2.6937, time: 22:05:29.904337
# tensor([[-2.7949]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7957]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7966]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7974]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7983]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.7991]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8000]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8008]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8017]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8025]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8034]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8042]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8051]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8060]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8068]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8077]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8085]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8094]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8102]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8111]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8120]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8128]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8137]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8145]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8154]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8163]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8171]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8180]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8188]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8197]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8206]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8214]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8223]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8231]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8240]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8249]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8257]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8266]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8275]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8283]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8292]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8301]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8309]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8318]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8327]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8335]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8344]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8353]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8361]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8370]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8379]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8387]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8396]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8405]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8413]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8422]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8431]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8440]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8448]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8457]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8466]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8474]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8483]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8492]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8501]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8509]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8518]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8527]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8536]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8544]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8553]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8562]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8571]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8579]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8588]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8597]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8606]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8614]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8623]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8632]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8641]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8650]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8658]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8667]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8676]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8685]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8694]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8702]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8711]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8720]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8729]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8738]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8747]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8755]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8764]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8773]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8782]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8791]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8800]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8809]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [700/12000], Loss: -2.8039, time: 22:05:30.233955
# tensor([[-2.8817]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8826]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8835]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8844]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8853]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8862]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8871]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8880]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8889]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8897]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8906]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8915]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8924]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8933]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8942]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8951]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8960]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8969]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8978]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8987]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.8996]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9005]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9013]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9022]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9031]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9040]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9049]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9058]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9067]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9076]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9085]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9094]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9103]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9112]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9121]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9130]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-2.9139]], device='cuda:0', grad_fn=<SelectBackward0>)
# ...
# tensor([[-5.7574]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7576]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7578]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7581]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7583]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7585]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7587]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7589]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7591]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7594]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7596]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7598]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7600]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7602]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7604]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7607]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7609]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7611]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7613]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7615]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7618]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7620]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7622]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7624]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7626]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7628]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7631]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7633]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7635]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7637]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7639]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7641]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7644]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7646]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7648]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7650]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7652]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7654]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7656]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7659]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7661]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7663]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7665]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7667]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7669]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7672]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7674]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7676]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7678]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7680]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7682]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7684]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7687]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7689]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7691]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7693]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7695]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7697]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7699]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7702]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7704]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7706]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7708]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7710]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7712]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7714]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7717]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7719]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7721]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7723]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7725]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7727]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7729]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7731]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7734]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7736]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7738]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7740]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7742]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7744]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7746]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7748]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7751]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7753]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7755]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7757]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7759]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7761]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7763]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7765]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7767]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7770]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7772]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [5200/12000], Loss: -5.4496, time: 22:05:45.217469
# tensor([[-5.7774]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7776]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7778]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7780]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7782]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7784]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7786]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7789]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7791]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7793]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7795]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7797]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7799]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7801]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7803]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7805]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7808]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7810]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7812]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7814]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7816]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7818]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7820]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7822]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7824]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7826]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7828]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7831]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7833]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7835]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7837]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7839]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7841]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7843]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7845]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7847]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7849]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7851]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7854]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7856]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7858]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7860]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7862]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7864]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7866]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7868]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7870]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7872]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7874]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7876]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7878]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7881]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7883]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7885]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7887]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7889]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7891]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7893]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7895]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7897]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7899]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7901]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7903]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7905]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7907]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7910]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7912]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7914]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7916]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7918]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7920]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7922]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7924]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7926]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7928]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7930]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7932]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7934]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7936]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7938]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7940]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7942]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7944]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7947]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7949]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7951]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7953]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7955]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7957]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7959]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7961]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7963]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7965]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7967]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7969]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7971]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7973]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7975]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7977]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7979]], device='cuda:0', grad_fn=<SelectBackward0>)
# Epoch [5300/12000], Loss: -5.4703, time: 22:05:45.548281
# tensor([[-5.7981]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7983]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7985]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7987]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7989]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7991]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7993]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7995]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7997]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.7999]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8002]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8003]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8006]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8008]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8010]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8012]], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([[-5.8014]], device='cuda:0', grad_fn=<SelectBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 6
#       3 epochs = 12000
#       4 learning_rate = 0.001
# ----> 6 u_opt, x_opt, t_opt = optimize_neural_operator(trained_model, objective_function_nde, m, end_time, epochs, learning_rate,  w=[1,2, 0], model_name="lno")
#
# File /m/home/home8/87/begantm1/data/Documents/Thesis/utils/scripts.py:366, in optimize_neural_operator(model, objective_function, m, end_time, num_epochs, learning_rate, bounds, w, model_name)
#     363 args = {'u': u_bounded, 'x': x, 't': t, 'w':w}
#     365 loss = objective_function(args)
# --> 366 loss.backward()
#     367 optimizer.step()
#     369 if (epoch+1) % 100 == 0:
#
# File ~/Documents/Thesis/.venv/lib/python3.10/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Documents/Thesis/.venv/lib/python3.10/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Documents/Thesis/.venv/lib/python3.10/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plt.plot(t_opt.cpu().detach().numpy().T, u_opt.cpu().detach().numpy().T, label='u found')

# %%
plt.plot(t_opt.cpu().detach().numpy().T, x_opt.cpu().detach().numpy().T, label='u found')

# %%
t_opt.shape, x_opt.shape
# Out:
# (torch.Size([1, 200]), torch.Size([1, 200]))

# %%
# remove the batch dimension
t_vec = t_opt.squeeze(0)   # shape [200]
x_vec = x_opt.squeeze(0)   # shape [200]
u_vec = u_opt.squeeze(0)   # shape [200]

# now differentiate along dim=0 (the only axis)
dx_dt, = torch.gradient(
    x_vec,
    spacing=(t_vec,),
    dim=0
)

plt.plot((dx_dt - 5/9 * (-x_vec + x_vec*u_vec + u_vec**2)).cpu().detach().numpy().T, label='u found')

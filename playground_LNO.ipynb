# %% [markdown]
# # Notebook \#3 - Operator Learning and Optimal Control
# version: LNO
#
# for some instructions regarding use of special functions from this repo, consider starting from exploring `playground_deeponet.ipynb`

# %%
import torch
from utils.scripts import solve_optimization
from models.lno import LNO1d, LNO1d_extended

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64


model = LNO1d(modes=modes, width=width, activation="silu", hidden_layer = hidden_layer).to(device)

ckpt = torch.load("trained_models/linear/lno/unsupervised/epoch[670]_model_time_[20250718_232320]_loss_[0.0011].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [10, 1, 1, 0, 0]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'linear',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs=5000,
    m=m,
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 0.684169 | rel_err_u: 3.5953, rel_err_x: 0.4820
# Epoch  100 | Loss: 0.604572 | rel_err_u: 3.4798, rel_err_x: 0.4703
# Epoch  150 | Loss: 0.545865 | rel_err_u: 3.3590, rel_err_x: 0.4560
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  200 | Loss: 0.500890 | rel_err_u: 3.2362, rel_err_x: 0.4403
# Epoch  250 | Loss: 0.465107 | rel_err_u: 3.1126, rel_err_x: 0.4235
# Epoch  300 | Loss: 0.435577 | rel_err_u: 2.9890, rel_err_x: 0.4062
# Epoch  350 | Loss: 0.410481 | rel_err_u: 2.8660, rel_err_x: 0.3884
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  400 | Loss: 0.388684 | rel_err_u: 2.7446, rel_err_x: 0.3706
# Epoch  450 | Loss: 0.369450 | rel_err_u: 2.6252, rel_err_x: 0.3529
# Epoch  500 | Loss: 0.352292 | rel_err_u: 2.5085, rel_err_x: 0.3354
# Epoch  550 | Loss: 0.336863 | rel_err_u: 2.3948, rel_err_x: 0.3183
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  600 | Loss: 0.322923 | rel_err_u: 2.2842, rel_err_x: 0.3015
# Epoch  650 | Loss: 0.310287 | rel_err_u: 2.1770, rel_err_x: 0.2852
# Epoch  700 | Loss: 0.298804 | rel_err_u: 2.0733, rel_err_x: 0.2695
# Epoch  750 | Loss: 0.288360 | rel_err_u: 1.9731, rel_err_x: 0.2542
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  800 | Loss: 0.278859 | rel_err_u: 1.8765, rel_err_x: 0.2395
# Epoch  850 | Loss: 0.270215 | rel_err_u: 1.7833, rel_err_x: 0.2254
# Epoch  900 | Loss: 0.262351 | rel_err_u: 1.6937, rel_err_x: 0.2119
# Epoch  950 | Loss: 0.255208 | rel_err_u: 1.6075, rel_err_x: 0.1989
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1000 | Loss: 0.248724 | rel_err_u: 1.5247, rel_err_x: 0.1865
# Epoch 1050 | Loss: 0.242843 | rel_err_u: 1.4452, rel_err_x: 0.1746
# Epoch 1100 | Loss: 0.237519 | rel_err_u: 1.3691, rel_err_x: 0.1633
# Epoch 1150 | Loss: 0.232704 | rel_err_u: 1.2961, rel_err_x: 0.1525
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1200 | Loss: 0.228355 | rel_err_u: 1.2263, rel_err_x: 0.1423
# Epoch 1250 | Loss: 0.224436 | rel_err_u: 1.1596, rel_err_x: 0.1326
# Epoch 1300 | Loss: 0.220909 | rel_err_u: 1.0958, rel_err_x: 0.1234
# Epoch 1350 | Loss: 0.217738 | rel_err_u: 1.0350, rel_err_x: 0.1146
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1400 | Loss: 0.214893 | rel_err_u: 0.9770, rel_err_x: 0.1064
# Epoch 1450 | Loss: 0.212344 | rel_err_u: 0.9217, rel_err_x: 0.0986
# Epoch 1500 | Loss: 0.210065 | rel_err_u: 0.8691, rel_err_x: 0.0913
# Epoch 1550 | Loss: 0.208029 | rel_err_u: 0.8190, rel_err_x: 0.0844
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1600 | Loss: 0.206213 | rel_err_u: 0.7714, rel_err_x: 0.0779
# Epoch 1650 | Loss: 0.204595 | rel_err_u: 0.7262, rel_err_x: 0.0718
# Epoch 1700 | Loss: 0.203159 | rel_err_u: 0.6833, rel_err_x: 0.0661
# Epoch 1750 | Loss: 0.201881 | rel_err_u: 0.6425, rel_err_x: 0.0607
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1800 | Loss: 0.200748 | rel_err_u: 0.6039, rel_err_x: 0.0558
# Epoch 1850 | Loss: 0.199744 | rel_err_u: 0.5672, rel_err_x: 0.0511
# Epoch 1900 | Loss: 0.198856 | rel_err_u: 0.5325, rel_err_x: 0.0468
# Epoch 1950 | Loss: 0.198069 | rel_err_u: 0.4996, rel_err_x: 0.0427
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2000 | Loss: 0.197375 | rel_err_u: 0.4684, rel_err_x: 0.0390
# Epoch 2050 | Loss: 0.196762 | rel_err_u: 0.4389, rel_err_x: 0.0355
# Epoch 2100 | Loss: 0.196222 | rel_err_u: 0.4109, rel_err_x: 0.0323
# Epoch 2150 | Loss: 0.195747 | rel_err_u: 0.3844, rel_err_x: 0.0294
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2200 | Loss: 0.195328 | rel_err_u: 0.3594, rel_err_x: 0.0266
# Epoch 2250 | Loss: 0.194960 | rel_err_u: 0.3357, rel_err_x: 0.0241
# Epoch 2300 | Loss: 0.194637 | rel_err_u: 0.3133, rel_err_x: 0.0218
# Epoch 2350 | Loss: 0.194354 | rel_err_u: 0.2921, rel_err_x: 0.0197
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2400 | Loss: 0.194106 | rel_err_u: 0.2721, rel_err_x: 0.0177
# Epoch 2450 | Loss: 0.193889 | rel_err_u: 0.2531, rel_err_x: 0.0159
# Epoch 2500 | Loss: 0.193699 | rel_err_u: 0.2353, rel_err_x: 0.0143
# Epoch 2550 | Loss: 0.193534 | rel_err_u: 0.2184, rel_err_x: 0.0128
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2600 | Loss: 0.193390 | rel_err_u: 0.2025, rel_err_x: 0.0114
# Epoch 2650 | Loss: 0.193265 | rel_err_u: 0.1875, rel_err_x: 0.0102
# Epoch 2700 | Loss: 0.193156 | rel_err_u: 0.1734, rel_err_x: 0.0091
# Epoch 2750 | Loss: 0.193063 | rel_err_u: 0.1602, rel_err_x: 0.0080
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2800 | Loss: 0.192982 | rel_err_u: 0.1477, rel_err_x: 0.0071
# Epoch 2850 | Loss: 0.192912 | rel_err_u: 0.1361, rel_err_x: 0.0063
# Epoch 2900 | Loss: 0.192852 | rel_err_u: 0.1251, rel_err_x: 0.0055
# Epoch 2950 | Loss: 0.192801 | rel_err_u: 0.1149, rel_err_x: 0.0048
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3000 | Loss: 0.192758 | rel_err_u: 0.1053, rel_err_x: 0.0042
# Epoch 3050 | Loss: 0.192720 | rel_err_u: 0.0964, rel_err_x: 0.0036
# Epoch 3100 | Loss: 0.192689 | rel_err_u: 0.0881, rel_err_x: 0.0031
# Epoch 3150 | Loss: 0.192662 | rel_err_u: 0.0804, rel_err_x: 0.0027
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3200 | Loss: 0.192640 | rel_err_u: 0.0733, rel_err_x: 0.0023
# Epoch 3250 | Loss: 0.192621 | rel_err_u: 0.0667, rel_err_x: 0.0019
# Epoch 3300 | Loss: 0.192605 | rel_err_u: 0.0607, rel_err_x: 0.0016
# Epoch 3350 | Loss: 0.192592 | rel_err_u: 0.0551, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3400 | Loss: 0.192582 | rel_err_u: 0.0500, rel_err_x: 0.0011
# Epoch 3450 | Loss: 0.192573 | rel_err_u: 0.0454, rel_err_x: 0.0009
# Epoch 3500 | Loss: 0.192565 | rel_err_u: 0.0412, rel_err_x: 0.0008
# Epoch 3550 | Loss: 0.192559 | rel_err_u: 0.0374, rel_err_x: 0.0008
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3600 | Loss: 0.192555 | rel_err_u: 0.0340, rel_err_x: 0.0007
# Epoch 3650 | Loss: 0.192551 | rel_err_u: 0.0310, rel_err_x: 0.0007
# Epoch 3700 | Loss: 0.192548 | rel_err_u: 0.0283, rel_err_x: 0.0008
# Epoch 3750 | Loss: 0.192545 | rel_err_u: 0.0259, rel_err_x: 0.0008
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3800 | Loss: 0.192543 | rel_err_u: 0.0239, rel_err_x: 0.0009
# Epoch 3850 | Loss: 0.192542 | rel_err_u: 0.0221, rel_err_x: 0.0009
# Epoch 3900 | Loss: 0.192540 | rel_err_u: 0.0206, rel_err_x: 0.0010
# Epoch 3950 | Loss: 0.192540 | rel_err_u: 0.0193, rel_err_x: 0.0010
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4000 | Loss: 0.192539 | rel_err_u: 0.0183, rel_err_x: 0.0011
# Epoch 4050 | Loss: 0.192538 | rel_err_u: 0.0174, rel_err_x: 0.0011
# Epoch 4100 | Loss: 0.192538 | rel_err_u: 0.0167, rel_err_x: 0.0012
# Epoch 4150 | Loss: 0.192538 | rel_err_u: 0.0161, rel_err_x: 0.0012
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4200 | Loss: 0.192537 | rel_err_u: 0.0157, rel_err_x: 0.0012
# Epoch 4250 | Loss: 0.192537 | rel_err_u: 0.0153, rel_err_x: 0.0013
# Epoch 4300 | Loss: 0.192537 | rel_err_u: 0.0151, rel_err_x: 0.0013
# Epoch 4350 | Loss: 0.192537 | rel_err_u: 0.0148, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4400 | Loss: 0.192537 | rel_err_u: 0.0147, rel_err_x: 0.0013
# Epoch 4450 | Loss: 0.192537 | rel_err_u: 0.0145, rel_err_x: 0.0013
# Epoch 4500 | Loss: 0.192537 | rel_err_u: 0.0145, rel_err_x: 0.0013
# Epoch 4550 | Loss: 0.192537 | rel_err_u: 0.0144, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4600 | Loss: 0.192537 | rel_err_u: 0.0143, rel_err_x: 0.0014
# Epoch 4650 | Loss: 0.192537 | rel_err_u: 0.0143, rel_err_x: 0.0014
# Epoch 4700 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4750 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4800 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4850 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4900 | Loss: 0.192536 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4950 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 5000 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.1925065517425537

# %% [markdown]
# <image src="found_trajectories/linear/lno/plot.png" width=600>

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64

model = LNO1d(modes=modes, width=width, activation="silu", hidden_layer = hidden_layer).to(device)
ckpt = torch.load("trained_models/oscillatory/lno/unsupervised/epoch[1000]_model_time_[20250718_232530]_loss_[0.0017].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [10, 1, 1, 0, 0.1]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'oscillatory',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 10000,
    m=m,
    device=device,
    result=True
)
# Out:
# Epoch   50 | Loss: 0.319972 | rel_err_u: 114.3646, rel_err_x: 4.5346
# Epoch  100 | Loss: 0.257602 | rel_err_u: 109.1187, rel_err_x: 4.3778
# Epoch  150 | Loss: 0.212674 | rel_err_u: 104.0166, rel_err_x: 4.1941
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch  200 | Loss: 0.179017 | rel_err_u: 98.9773, rel_err_x: 3.9906
# Epoch  250 | Loss: 0.152756 | rel_err_u: 93.9913, rel_err_x: 3.7746
# Epoch  300 | Loss: 0.131582 | rel_err_u: 89.0935, rel_err_x: 3.5532
# Epoch  350 | Loss: 0.114083 | rel_err_u: 84.3235, rel_err_x: 3.3317
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch  400 | Loss: 0.099366 | rel_err_u: 79.7111, rel_err_x: 3.1140
# Epoch  450 | Loss: 0.086814 | rel_err_u: 75.2749, rel_err_x: 2.9028
# Epoch  500 | Loss: 0.076010 | rel_err_u: 71.0257, rel_err_x: 2.6997
# Epoch  550 | Loss: 0.066648 | rel_err_u: 66.9660, rel_err_x: 2.5058
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch  600 | Loss: 0.058495 | rel_err_u: 63.0946, rel_err_x: 2.3218
# Epoch  650 | Loss: 0.051366 | rel_err_u: 59.4070, rel_err_x: 2.1478
# Epoch  700 | Loss: 0.045118 | rel_err_u: 55.8981, rel_err_x: 1.9841
# Epoch  750 | Loss: 0.039636 | rel_err_u: 52.5606, rel_err_x: 1.8304
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch  800 | Loss: 0.034820 | rel_err_u: 49.3875, rel_err_x: 1.6865
# Epoch  850 | Loss: 0.030588 | rel_err_u: 46.3727, rel_err_x: 1.5522
# Epoch  900 | Loss: 0.026865 | rel_err_u: 43.5092, rel_err_x: 1.4271
# Epoch  950 | Loss: 0.023603 | rel_err_u: 40.7912, rel_err_x: 1.3109
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 1000 | Loss: 0.020738 | rel_err_u: 38.2127, rel_err_x: 1.2030
# Epoch 1050 | Loss: 0.018223 | rel_err_u: 35.7689, rel_err_x: 1.1031
# Epoch 1100 | Loss: 0.016026 | rel_err_u: 33.4540, rel_err_x: 1.0108
# Epoch 1150 | Loss: 0.014108 | rel_err_u: 31.2631, rel_err_x: 0.9256
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 1200 | Loss: 0.012428 | rel_err_u: 29.1921, rel_err_x: 0.8470
# Epoch 1250 | Loss: 0.010966 | rel_err_u: 27.2360, rel_err_x: 0.7747
# Epoch 1300 | Loss: 0.009696 | rel_err_u: 25.3913, rel_err_x: 0.7083
# Epoch 1350 | Loss: 0.008593 | rel_err_u: 23.6528, rel_err_x: 0.6473
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 1400 | Loss: 0.007634 | rel_err_u: 22.0168, rel_err_x: 0.5914
# Epoch 1450 | Loss: 0.006808 | rel_err_u: 20.4786, rel_err_x: 0.5402
# Epoch 1500 | Loss: 0.006094 | rel_err_u: 19.0344, rel_err_x: 0.4935
# Epoch 1550 | Loss: 0.005476 | rel_err_u: 17.6804, rel_err_x: 0.4507
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 1600 | Loss: 0.004948 | rel_err_u: 16.4117, rel_err_x: 0.4117
# Epoch 1650 | Loss: 0.004492 | rel_err_u: 15.2249, rel_err_x: 0.3762
# Epoch 1700 | Loss: 0.004102 | rel_err_u: 14.1160, rel_err_x: 0.3439
# Epoch 1750 | Loss: 0.003767 | rel_err_u: 13.0805, rel_err_x: 0.3145
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 1800 | Loss: 0.003482 | rel_err_u: 12.1151, rel_err_x: 0.2878
# Epoch 1850 | Loss: 0.003238 | rel_err_u: 11.2152, rel_err_x: 0.2637
# Epoch 1900 | Loss: 0.003030 | rel_err_u: 10.3779, rel_err_x: 0.2418
# Epoch 1950 | Loss: 0.002853 | rel_err_u: 9.5989, rel_err_x: 0.2220
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 2000 | Loss: 0.002702 | rel_err_u: 8.8754, rel_err_x: 0.2041
# Epoch 2050 | Loss: 0.002575 | rel_err_u: 8.2037, rel_err_x: 0.1880
# Epoch 2100 | Loss: 0.002467 | rel_err_u: 7.5802, rel_err_x: 0.1734
# Epoch 2150 | Loss: 0.002375 | rel_err_u: 7.0027, rel_err_x: 0.1604
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 2200 | Loss: 0.002297 | rel_err_u: 6.4682, rel_err_x: 0.1486
# Epoch 2250 | Loss: 0.002232 | rel_err_u: 5.9735, rel_err_x: 0.1381
# Epoch 2300 | Loss: 0.002176 | rel_err_u: 5.5165, rel_err_x: 0.1287
# Epoch 2350 | Loss: 0.002130 | rel_err_u: 5.0952, rel_err_x: 0.1202
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 2400 | Loss: 0.002090 | rel_err_u: 4.7065, rel_err_x: 0.1126
# Epoch 2450 | Loss: 0.002057 | rel_err_u: 4.3488, rel_err_x: 0.1058
# Epoch 2500 | Loss: 0.002030 | rel_err_u: 4.0204, rel_err_x: 0.0998
# Epoch 2550 | Loss: 0.002007 | rel_err_u: 3.7195, rel_err_x: 0.0943
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 2600 | Loss: 0.001988 | rel_err_u: 3.4442, rel_err_x: 0.0895
# Epoch 2650 | Loss: 0.001971 | rel_err_u: 3.1927, rel_err_x: 0.0852
# Epoch 2700 | Loss: 0.001958 | rel_err_u: 2.9639, rel_err_x: 0.0814
# Epoch 2750 | Loss: 0.001947 | rel_err_u: 2.7571, rel_err_x: 0.0780
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 2800 | Loss: 0.001938 | rel_err_u: 2.5699, rel_err_x: 0.0750
# Epoch 2850 | Loss: 0.001930 | rel_err_u: 2.4021, rel_err_x: 0.0724
# Epoch 2900 | Loss: 0.001924 | rel_err_u: 2.2518, rel_err_x: 0.0700
# Epoch 2950 | Loss: 0.001919 | rel_err_u: 2.1181, rel_err_x: 0.0679
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 3000 | Loss: 0.001915 | rel_err_u: 1.9990, rel_err_x: 0.0661
# Epoch 3050 | Loss: 0.001911 | rel_err_u: 1.8948, rel_err_x: 0.0645
# Epoch 3100 | Loss: 0.001908 | rel_err_u: 1.8023, rel_err_x: 0.0630
# Epoch 3150 | Loss: 0.001906 | rel_err_u: 1.7234, rel_err_x: 0.0618
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 3200 | Loss: 0.001904 | rel_err_u: 1.6549, rel_err_x: 0.0607
# Epoch 3250 | Loss: 0.001903 | rel_err_u: 1.5971, rel_err_x: 0.0598
# Epoch 3300 | Loss: 0.001902 | rel_err_u: 1.5464, rel_err_x: 0.0589
# Epoch 3350 | Loss: 0.001901 | rel_err_u: 1.5033, rel_err_x: 0.0581
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 3400 | Loss: 0.001900 | rel_err_u: 1.4681, rel_err_x: 0.0575
# Epoch 3450 | Loss: 0.001900 | rel_err_u: 1.4380, rel_err_x: 0.0569
# Epoch 3500 | Loss: 0.001899 | rel_err_u: 1.4128, rel_err_x: 0.0564
# Epoch 3550 | Loss: 0.001899 | rel_err_u: 1.3931, rel_err_x: 0.0560
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 3600 | Loss: 0.001898 | rel_err_u: 1.3753, rel_err_x: 0.0556
# Epoch 3650 | Loss: 0.001898 | rel_err_u: 1.3601, rel_err_x: 0.0552
# Epoch 3700 | Loss: 0.001898 | rel_err_u: 1.3495, rel_err_x: 0.0550
# Epoch 3750 | Loss: 0.001898 | rel_err_u: 1.3400, rel_err_x: 0.0547
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 3800 | Loss: 0.001898 | rel_err_u: 1.3318, rel_err_x: 0.0545
# Epoch 3850 | Loss: 0.001898 | rel_err_u: 1.3262, rel_err_x: 0.0544
# Epoch 3900 | Loss: 0.001898 | rel_err_u: 1.3200, rel_err_x: 0.0541
# Epoch 3950 | Loss: 0.001898 | rel_err_u: 1.3169, rel_err_x: 0.0541
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 4000 | Loss: 0.001898 | rel_err_u: 1.3136, rel_err_x: 0.0540
# Epoch 4050 | Loss: 0.001898 | rel_err_u: 1.3103, rel_err_x: 0.0538
# Epoch 4100 | Loss: 0.001898 | rel_err_u: 1.3074, rel_err_x: 0.0538
# Epoch 4150 | Loss: 0.001898 | rel_err_u: 1.3066, rel_err_x: 0.0537
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 4200 | Loss: 0.001897 | rel_err_u: 1.3056, rel_err_x: 0.0537
# Epoch 4250 | Loss: 0.001898 | rel_err_u: 1.3038, rel_err_x: 0.0536
# Epoch 4300 | Loss: 0.001898 | rel_err_u: 1.3034, rel_err_x: 0.0536
# Epoch 4350 | Loss: 0.001898 | rel_err_u: 1.3031, rel_err_x: 0.0536
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 4400 | Loss: 0.001898 | rel_err_u: 1.3014, rel_err_x: 0.0535
# Epoch 4450 | Loss: 0.001897 | rel_err_u: 1.3020, rel_err_x: 0.0535
# Epoch 4500 | Loss: 0.001897 | rel_err_u: 1.3012, rel_err_x: 0.0535
# Epoch 4550 | Loss: 0.001897 | rel_err_u: 1.3008, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 4600 | Loss: 0.001898 | rel_err_u: 1.3016, rel_err_x: 0.0535
# Epoch 4650 | Loss: 0.001898 | rel_err_u: 1.3008, rel_err_x: 0.0535
# Epoch 4700 | Loss: 0.001897 | rel_err_u: 1.3002, rel_err_x: 0.0534
# Epoch 4750 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 4800 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Epoch 4850 | Loss: 0.001898 | rel_err_u: 1.2996, rel_err_x: 0.0534
# Epoch 4900 | Loss: 0.001898 | rel_err_u: 1.2994, rel_err_x: 0.0534
# Epoch 4950 | Loss: 0.001898 | rel_err_u: 1.3001, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 5000 | Loss: 0.001897 | rel_err_u: 1.2998, rel_err_x: 0.0534
# Epoch 5050 | Loss: 0.001897 | rel_err_u: 1.3005, rel_err_x: 0.0534
# Epoch 5100 | Loss: 0.001897 | rel_err_u: 1.2999, rel_err_x: 0.0534
# Epoch 5150 | Loss: 0.001897 | rel_err_u: 1.3002, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 5200 | Loss: 0.001898 | rel_err_u: 1.2990, rel_err_x: 0.0534
# Epoch 5250 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Epoch 5300 | Loss: 0.001897 | rel_err_u: 1.2995, rel_err_x: 0.0534
# Epoch 5350 | Loss: 0.001898 | rel_err_u: 1.3002, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 5400 | Loss: 0.001898 | rel_err_u: 1.2995, rel_err_x: 0.0535
# Epoch 5450 | Loss: 0.001897 | rel_err_u: 1.2999, rel_err_x: 0.0534
# Epoch 5500 | Loss: 0.001898 | rel_err_u: 1.3009, rel_err_x: 0.0535
# Epoch 5550 | Loss: 0.001898 | rel_err_u: 1.2997, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 5600 | Loss: 0.001898 | rel_err_u: 1.2998, rel_err_x: 0.0534
# Epoch 5650 | Loss: 0.001897 | rel_err_u: 1.2997, rel_err_x: 0.0534
# Epoch 5700 | Loss: 0.001897 | rel_err_u: 1.3014, rel_err_x: 0.0535
# Epoch 5750 | Loss: 0.001898 | rel_err_u: 1.2997, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 5800 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Epoch 5850 | Loss: 0.001897 | rel_err_u: 1.2990, rel_err_x: 0.0534
# Epoch 5900 | Loss: 0.001898 | rel_err_u: 1.2998, rel_err_x: 0.0534
# Epoch 5950 | Loss: 0.001897 | rel_err_u: 1.3004, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 6000 | Loss: 0.001898 | rel_err_u: 1.2992, rel_err_x: 0.0534
# Epoch 6050 | Loss: 0.001897 | rel_err_u: 1.3001, rel_err_x: 0.0534
# Epoch 6100 | Loss: 0.001897 | rel_err_u: 1.2984, rel_err_x: 0.0534
# Epoch 6150 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 6200 | Loss: 0.001898 | rel_err_u: 1.2988, rel_err_x: 0.0534
# Epoch 6250 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Epoch 6300 | Loss: 0.001898 | rel_err_u: 1.2995, rel_err_x: 0.0534
# Epoch 6350 | Loss: 0.001898 | rel_err_u: 1.3016, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 6400 | Loss: 0.001898 | rel_err_u: 1.3004, rel_err_x: 0.0534
# Epoch 6450 | Loss: 0.001897 | rel_err_u: 1.2994, rel_err_x: 0.0534
# Epoch 6500 | Loss: 0.001898 | rel_err_u: 1.3003, rel_err_x: 0.0534
# Epoch 6550 | Loss: 0.001897 | rel_err_u: 1.3008, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 6600 | Loss: 0.001898 | rel_err_u: 1.2992, rel_err_x: 0.0534
# Epoch 6650 | Loss: 0.001897 | rel_err_u: 1.2979, rel_err_x: 0.0534
# Epoch 6700 | Loss: 0.001897 | rel_err_u: 1.3000, rel_err_x: 0.0535
# Epoch 6750 | Loss: 0.001897 | rel_err_u: 1.2998, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 6800 | Loss: 0.001897 | rel_err_u: 1.2999, rel_err_x: 0.0534
# Epoch 6850 | Loss: 0.001898 | rel_err_u: 1.2988, rel_err_x: 0.0534
# Epoch 6900 | Loss: 0.001897 | rel_err_u: 1.2999, rel_err_x: 0.0534
# Epoch 6950 | Loss: 0.001898 | rel_err_u: 1.2997, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 7000 | Loss: 0.001898 | rel_err_u: 1.3016, rel_err_x: 0.0534
# Epoch 7050 | Loss: 0.001898 | rel_err_u: 1.2990, rel_err_x: 0.0534
# Epoch 7100 | Loss: 0.001898 | rel_err_u: 1.2983, rel_err_x: 0.0534
# Epoch 7150 | Loss: 0.001898 | rel_err_u: 1.3010, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 7200 | Loss: 0.001898 | rel_err_u: 1.3006, rel_err_x: 0.0535
# Epoch 7250 | Loss: 0.001898 | rel_err_u: 1.3003, rel_err_x: 0.0534
# Epoch 7300 | Loss: 0.001898 | rel_err_u: 1.2994, rel_err_x: 0.0534
# Epoch 7350 | Loss: 0.001898 | rel_err_u: 1.2983, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 7400 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Epoch 7450 | Loss: 0.001898 | rel_err_u: 1.2984, rel_err_x: 0.0534
# Epoch 7500 | Loss: 0.001898 | rel_err_u: 1.3008, rel_err_x: 0.0534
# Epoch 7550 | Loss: 0.001898 | rel_err_u: 1.3016, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 7600 | Loss: 0.001897 | rel_err_u: 1.2998, rel_err_x: 0.0535
# Epoch 7650 | Loss: 0.001898 | rel_err_u: 1.2998, rel_err_x: 0.0534
# Epoch 7700 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Epoch 7750 | Loss: 0.001898 | rel_err_u: 1.2992, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 7800 | Loss: 0.001898 | rel_err_u: 1.3011, rel_err_x: 0.0535
# Epoch 7850 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Epoch 7900 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Epoch 7950 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 8000 | Loss: 0.001897 | rel_err_u: 1.2990, rel_err_x: 0.0534
# Epoch 8050 | Loss: 0.001898 | rel_err_u: 1.2985, rel_err_x: 0.0534
# Epoch 8100 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Epoch 8150 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0533
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 8200 | Loss: 0.001897 | rel_err_u: 1.2998, rel_err_x: 0.0535
# Epoch 8250 | Loss: 0.001897 | rel_err_u: 1.3003, rel_err_x: 0.0535
# Epoch 8300 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Epoch 8350 | Loss: 0.001898 | rel_err_u: 1.3018, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 8400 | Loss: 0.001897 | rel_err_u: 1.2999, rel_err_x: 0.0535
# Epoch 8450 | Loss: 0.001898 | rel_err_u: 1.2984, rel_err_x: 0.0534
# Epoch 8500 | Loss: 0.001898 | rel_err_u: 1.2989, rel_err_x: 0.0534
# Epoch 8550 | Loss: 0.001898 | rel_err_u: 1.2990, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 8600 | Loss: 0.001897 | rel_err_u: 1.3002, rel_err_x: 0.0534
# Epoch 8650 | Loss: 0.001898 | rel_err_u: 1.2991, rel_err_x: 0.0534
# Epoch 8700 | Loss: 0.001898 | rel_err_u: 1.2995, rel_err_x: 0.0534
# Epoch 8750 | Loss: 0.001898 | rel_err_u: 1.3016, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 8800 | Loss: 0.001898 | rel_err_u: 1.2983, rel_err_x: 0.0534
# Epoch 8850 | Loss: 0.001898 | rel_err_u: 1.2996, rel_err_x: 0.0534
# Epoch 8900 | Loss: 0.001898 | rel_err_u: 1.3001, rel_err_x: 0.0535
# Epoch 8950 | Loss: 0.001897 | rel_err_u: 1.3007, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 9000 | Loss: 0.001897 | rel_err_u: 1.2988, rel_err_x: 0.0534
# Epoch 9050 | Loss: 0.001898 | rel_err_u: 1.2994, rel_err_x: 0.0534
# Epoch 9100 | Loss: 0.001897 | rel_err_u: 1.3008, rel_err_x: 0.0535
# Epoch 9150 | Loss: 0.001898 | rel_err_u: 1.3004, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 9200 | Loss: 0.001897 | rel_err_u: 1.2996, rel_err_x: 0.0535
# Epoch 9250 | Loss: 0.001897 | rel_err_u: 1.2997, rel_err_x: 0.0534
# Epoch 9300 | Loss: 0.001898 | rel_err_u: 1.2982, rel_err_x: 0.0534
# Epoch 9350 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 9400 | Loss: 0.001898 | rel_err_u: 1.2996, rel_err_x: 0.0535
# Epoch 9450 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Epoch 9500 | Loss: 0.001898 | rel_err_u: 1.3007, rel_err_x: 0.0534
# Epoch 9550 | Loss: 0.001898 | rel_err_u: 1.3014, rel_err_x: 0.0535
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 9600 | Loss: 0.001898 | rel_err_u: 1.2981, rel_err_x: 0.0534
# Epoch 9650 | Loss: 0.001898 | rel_err_u: 1.2993, rel_err_x: 0.0534
# Epoch 9700 | Loss: 0.001898 | rel_err_u: 1.3006, rel_err_x: 0.0535
# Epoch 9750 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 9800 | Loss: 0.001898 | rel_err_u: 1.3000, rel_err_x: 0.0534
# Epoch 9850 | Loss: 0.001898 | rel_err_u: 1.3005, rel_err_x: 0.0534
# Epoch 9900 | Loss: 0.001897 | rel_err_u: 1.2986, rel_err_x: 0.0534
# Epoch 9950 | Loss: 0.001898 | rel_err_u: 1.3003, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch 10000 | Loss: 0.001898 | rel_err_u: 1.2986, rel_err_x: 0.0534

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.0015614270232617855

# %% [markdown]
# <image src="found_trajectories/oscillatory/lno/plot.png" width=600>

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64

model = LNO1d(width, modes, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/polynomial_tracking/lno/unsupervised/epoch[1000]_model_time_[20250718_233449]_loss_[0.0127].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [100, 1, 1, 1, 0]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'polynomial_tracking',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 10000,
    m=m,
    device=device,
    result=True
)
# Out:
# Epoch   50 | Loss: 1.717599 | rel_err_u: 2.1812, rel_err_x: 1.3872
# Epoch  100 | Loss: 1.229454 | rel_err_u: 2.0968, rel_err_x: 1.3794
# Epoch  150 | Loss: 0.910929 | rel_err_u: 2.0268, rel_err_x: 1.3696
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  200 | Loss: 0.702320 | rel_err_u: 1.9670, rel_err_x: 1.3561
# Epoch  250 | Loss: 0.565567 | rel_err_u: 1.9135, rel_err_x: 1.3387
# Epoch  300 | Loss: 0.475413 | rel_err_u: 1.8637, rel_err_x: 1.3175
# Epoch  350 | Loss: 0.415122 | rel_err_u: 1.8159, rel_err_x: 1.2930
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  400 | Loss: 0.373730 | rel_err_u: 1.7691, rel_err_x: 1.2659
# Epoch  450 | Loss: 0.344285 | rel_err_u: 1.7230, rel_err_x: 1.2365
# Epoch  500 | Loss: 0.322442 | rel_err_u: 1.6774, rel_err_x: 1.2055
# Epoch  550 | Loss: 0.305485 | rel_err_u: 1.6323, rel_err_x: 1.1733
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  600 | Loss: 0.291741 | rel_err_u: 1.5877, rel_err_x: 1.1401
# Epoch  650 | Loss: 0.280211 | rel_err_u: 1.5436, rel_err_x: 1.1064
# Epoch  700 | Loss: 0.270272 | rel_err_u: 1.5002, rel_err_x: 1.0722
# Epoch  750 | Loss: 0.261515 | rel_err_u: 1.4574, rel_err_x: 1.0379
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  800 | Loss: 0.253648 | rel_err_u: 1.4153, rel_err_x: 1.0035
# Epoch  850 | Loss: 0.246514 | rel_err_u: 1.3741, rel_err_x: 0.9693
# Epoch  900 | Loss: 0.239978 | rel_err_u: 1.3335, rel_err_x: 0.9353
# Epoch  950 | Loss: 0.233972 | rel_err_u: 1.2938, rel_err_x: 0.9016
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 1000 | Loss: 0.228397 | rel_err_u: 1.2549, rel_err_x: 0.8683
# Epoch 1050 | Loss: 0.223218 | rel_err_u: 1.2168, rel_err_x: 0.8355
# Epoch 1100 | Loss: 0.218397 | rel_err_u: 1.1796, rel_err_x: 0.8033
# Epoch 1150 | Loss: 0.213900 | rel_err_u: 1.1432, rel_err_x: 0.7718
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 1200 | Loss: 0.209700 | rel_err_u: 1.1077, rel_err_x: 0.7409
# Epoch 1250 | Loss: 0.205767 | rel_err_u: 1.0730, rel_err_x: 0.7107
# Epoch 1300 | Loss: 0.202089 | rel_err_u: 1.0391, rel_err_x: 0.6813
# Epoch 1350 | Loss: 0.198648 | rel_err_u: 1.0061, rel_err_x: 0.6526
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 1400 | Loss: 0.195418 | rel_err_u: 0.9739, rel_err_x: 0.6248
# Epoch 1450 | Loss: 0.192391 | rel_err_u: 0.9426, rel_err_x: 0.5978
# Epoch 1500 | Loss: 0.189557 | rel_err_u: 0.9120, rel_err_x: 0.5717
# Epoch 1550 | Loss: 0.186898 | rel_err_u: 0.8822, rel_err_x: 0.5464
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 1600 | Loss: 0.184409 | rel_err_u: 0.8531, rel_err_x: 0.5219
# Epoch 1650 | Loss: 0.182078 | rel_err_u: 0.8249, rel_err_x: 0.4983
# Epoch 1700 | Loss: 0.179891 | rel_err_u: 0.7974, rel_err_x: 0.4756
# Epoch 1750 | Loss: 0.177842 | rel_err_u: 0.7706, rel_err_x: 0.4536
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 1800 | Loss: 0.175929 | rel_err_u: 0.7446, rel_err_x: 0.4325
# Epoch 1850 | Loss: 0.174133 | rel_err_u: 0.7193, rel_err_x: 0.4121
# Epoch 1900 | Loss: 0.172454 | rel_err_u: 0.6946, rel_err_x: 0.3926
# Epoch 1950 | Loss: 0.170886 | rel_err_u: 0.6707, rel_err_x: 0.3738
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 2000 | Loss: 0.169417 | rel_err_u: 0.6475, rel_err_x: 0.3558
# Epoch 2050 | Loss: 0.168047 | rel_err_u: 0.6249, rel_err_x: 0.3385
# Epoch 2100 | Loss: 0.166766 | rel_err_u: 0.6030, rel_err_x: 0.3219
# Epoch 2150 | Loss: 0.165568 | rel_err_u: 0.5817, rel_err_x: 0.3059
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 2200 | Loss: 0.164453 | rel_err_u: 0.5611, rel_err_x: 0.2907
# Epoch 2250 | Loss: 0.163413 | rel_err_u: 0.5410, rel_err_x: 0.2761
# Epoch 2300 | Loss: 0.162441 | rel_err_u: 0.5216, rel_err_x: 0.2621
# Epoch 2350 | Loss: 0.161536 | rel_err_u: 0.5028, rel_err_x: 0.2487
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 2400 | Loss: 0.160693 | rel_err_u: 0.4846, rel_err_x: 0.2359
# Epoch 2450 | Loss: 0.159911 | rel_err_u: 0.4669, rel_err_x: 0.2236
# Epoch 2500 | Loss: 0.159181 | rel_err_u: 0.4499, rel_err_x: 0.2119
# Epoch 2550 | Loss: 0.158501 | rel_err_u: 0.4333, rel_err_x: 0.2007
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 2600 | Loss: 0.157868 | rel_err_u: 0.4173, rel_err_x: 0.1900
# Epoch 2650 | Loss: 0.157282 | rel_err_u: 0.4018, rel_err_x: 0.1799
# Epoch 2700 | Loss: 0.156735 | rel_err_u: 0.3868, rel_err_x: 0.1701
# Epoch 2750 | Loss: 0.156228 | rel_err_u: 0.3723, rel_err_x: 0.1609
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 2800 | Loss: 0.155757 | rel_err_u: 0.3582, rel_err_x: 0.1520
# Epoch 2850 | Loss: 0.155317 | rel_err_u: 0.3446, rel_err_x: 0.1436
# Epoch 2900 | Loss: 0.154911 | rel_err_u: 0.3315, rel_err_x: 0.1356
# Epoch 2950 | Loss: 0.154533 | rel_err_u: 0.3188, rel_err_x: 0.1280
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 3000 | Loss: 0.154182 | rel_err_u: 0.3065, rel_err_x: 0.1207
# Epoch 3050 | Loss: 0.153855 | rel_err_u: 0.2946, rel_err_x: 0.1138
# Epoch 3100 | Loss: 0.153553 | rel_err_u: 0.2831, rel_err_x: 0.1072
# Epoch 3150 | Loss: 0.153272 | rel_err_u: 0.2720, rel_err_x: 0.1010
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 3200 | Loss: 0.153012 | rel_err_u: 0.2613, rel_err_x: 0.0950
# Epoch 3250 | Loss: 0.152769 | rel_err_u: 0.2509, rel_err_x: 0.0894
# Epoch 3300 | Loss: 0.152545 | rel_err_u: 0.2408, rel_err_x: 0.0840
# Epoch 3350 | Loss: 0.152337 | rel_err_u: 0.2310, rel_err_x: 0.0790
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 3400 | Loss: 0.152144 | rel_err_u: 0.2216, rel_err_x: 0.0741
# Epoch 3450 | Loss: 0.151966 | rel_err_u: 0.2125, rel_err_x: 0.0696
# Epoch 3500 | Loss: 0.151799 | rel_err_u: 0.2037, rel_err_x: 0.0652
# Epoch 3550 | Loss: 0.151645 | rel_err_u: 0.1952, rel_err_x: 0.0611
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 3600 | Loss: 0.151503 | rel_err_u: 0.1869, rel_err_x: 0.0572
# Epoch 3650 | Loss: 0.151372 | rel_err_u: 0.1789, rel_err_x: 0.0535
# Epoch 3700 | Loss: 0.151250 | rel_err_u: 0.1712, rel_err_x: 0.0501
# Epoch 3750 | Loss: 0.151138 | rel_err_u: 0.1637, rel_err_x: 0.0468
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 3800 | Loss: 0.151034 | rel_err_u: 0.1565, rel_err_x: 0.0436
# Epoch 3850 | Loss: 0.150937 | rel_err_u: 0.1495, rel_err_x: 0.0407
# Epoch 3900 | Loss: 0.150850 | rel_err_u: 0.1428, rel_err_x: 0.0379
# Epoch 3950 | Loss: 0.150768 | rel_err_u: 0.1363, rel_err_x: 0.0352
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 4000 | Loss: 0.150694 | rel_err_u: 0.1300, rel_err_x: 0.0327
# Epoch 4050 | Loss: 0.150624 | rel_err_u: 0.1240, rel_err_x: 0.0304
# Epoch 4100 | Loss: 0.150560 | rel_err_u: 0.1182, rel_err_x: 0.0282
# Epoch 4150 | Loss: 0.150503 | rel_err_u: 0.1126, rel_err_x: 0.0261
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 4200 | Loss: 0.150451 | rel_err_u: 0.1072, rel_err_x: 0.0241
# Epoch 4250 | Loss: 0.150402 | rel_err_u: 0.1020, rel_err_x: 0.0222
# Epoch 4300 | Loss: 0.150357 | rel_err_u: 0.0971, rel_err_x: 0.0204
# Epoch 4350 | Loss: 0.150317 | rel_err_u: 0.0924, rel_err_x: 0.0188
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 4400 | Loss: 0.150280 | rel_err_u: 0.0878, rel_err_x: 0.0173
# Epoch 4450 | Loss: 0.150248 | rel_err_u: 0.0835, rel_err_x: 0.0158
# Epoch 4500 | Loss: 0.150218 | rel_err_u: 0.0794, rel_err_x: 0.0144
# Epoch 4550 | Loss: 0.150190 | rel_err_u: 0.0755, rel_err_x: 0.0132
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 4600 | Loss: 0.150167 | rel_err_u: 0.0717, rel_err_x: 0.0120
# Epoch 4650 | Loss: 0.150144 | rel_err_u: 0.0682, rel_err_x: 0.0109
# Epoch 4700 | Loss: 0.150123 | rel_err_u: 0.0649, rel_err_x: 0.0099
# Epoch 4750 | Loss: 0.150105 | rel_err_u: 0.0618, rel_err_x: 0.0090
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch 4800 | Loss: 0.150091 | rel_err_u: 0.0589, rel_err_x: 0.0081
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 14
#      11 w = [100, 1, 1, 1, 0]
#      12 initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)
# ---> 14 analytics, x, u, x_optimal, u_optimal = solve_optimization(
#      15     model, 'polynomial_tracking',
#      16     initial_guess,
#      17     lr=0.001,
#      18     architecture="lno",
#      19     w=w,
#      20     num_epochs = 10000,
#      21     m=m,
#      22     device=device,
#      23     result=True
#      24 )
#
# File ~/Thesis-2/utils/scripts.py:114, in solve_optimization(model, problem, initial_guess, lr, architecture, w, bounds, num_epochs, m, device, plot_interval, result, early_stopping, patience, min_delta, plots)
#     111 analytics['obj'].append(obj.item())
#     112 analytics['total_loss'].append(loss.item())
# --> 114 loss.backward()
#     115 optimizer.step()
#     117 if early_stopping:
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.14918164908885956

# %% [markdown]
# <image src="found_trajectories/polynomial_tracking/lno/plot.png" width=600>

# %%
m = 200

modes = [8, 8]
width = 4
hidden_layer = 64
model = LNO1d_extended(modes=modes, width=width, activation="tanh", depth=2, active_last=True, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/nonlinear/lno/unsupervised/epoch[360]_model_time_[20250719_151537]_loss_[0.0597].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [100, 1, 1, 1, 0]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'nonlinear',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 30000,
    m=m,
    bounds = [-1.5, 1.5],
    device=device,
    result=True,
    early_stopping=True,
)
# Out:
# Epoch   50 | Loss: 10.389113 | rel_err_u: 1.7321, rel_err_x: 0.3173
# Epoch  100 | Loss: 7.086969 | rel_err_u: 1.6767, rel_err_x: 0.2947
# Epoch  150 | Loss: 5.018788 | rel_err_u: 1.6399, rel_err_x: 0.2807
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  200 | Loss: 3.691982 | rel_err_u: 1.6170, rel_err_x: 0.2721
# Epoch  250 | Loss: 2.832678 | rel_err_u: 1.6026, rel_err_x: 0.2667
# Epoch  300 | Loss: 2.273173 | rel_err_u: 1.5931, rel_err_x: 0.2630
# Epoch  350 | Loss: 1.904635 | rel_err_u: 1.5866, rel_err_x: 0.2604
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  400 | Loss: 1.658357 | rel_err_u: 1.5814, rel_err_x: 0.2583
# Epoch  450 | Loss: 1.491769 | rel_err_u: 1.5767, rel_err_x: 0.2564
# Epoch  500 | Loss: 1.377275 | rel_err_u: 1.5718, rel_err_x: 0.2544
# Epoch  550 | Loss: 1.296346 | rel_err_u: 1.5668, rel_err_x: 0.2525
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  600 | Loss: 1.237515 | rel_err_u: 1.5618, rel_err_x: 0.2507
# Epoch  650 | Loss: 1.192442 | rel_err_u: 1.5570, rel_err_x: 0.2489
# Epoch  700 | Loss: 1.156041 | rel_err_u: 1.5526, rel_err_x: 0.2472
# Epoch  750 | Loss: 1.125441 | rel_err_u: 1.5485, rel_err_x: 0.2455
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  800 | Loss: 1.098656 | rel_err_u: 1.5454, rel_err_x: 0.2442
# Epoch  850 | Loss: 1.075731 | rel_err_u: 1.5422, rel_err_x: 0.2428
# Epoch  900 | Loss: 1.055550 | rel_err_u: 1.5389, rel_err_x: 0.2414
# Epoch  950 | Loss: 1.037608 | rel_err_u: 1.5355, rel_err_x: 0.2400
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1000 | Loss: 1.021472 | rel_err_u: 1.5319, rel_err_x: 0.2384
# Epoch 1050 | Loss: 1.006749 | rel_err_u: 1.5279, rel_err_x: 0.2367
# Epoch 1100 | Loss: 0.993269 | rel_err_u: 1.5234, rel_err_x: 0.2349
# Epoch 1150 | Loss: 0.980733 | rel_err_u: 1.5191, rel_err_x: 0.2331
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1200 | Loss: 0.968873 | rel_err_u: 1.5137, rel_err_x: 0.2310
# Epoch 1250 | Loss: 0.957591 | rel_err_u: 1.5077, rel_err_x: 0.2287
# Epoch 1300 | Loss: 0.946412 | rel_err_u: 1.5015, rel_err_x: 0.2264
# Epoch 1350 | Loss: 0.935001 | rel_err_u: 1.4956, rel_err_x: 0.2241
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1400 | Loss: 0.924364 | rel_err_u: 1.4900, rel_err_x: 0.2220
# Epoch 1450 | Loss: 0.914194 | rel_err_u: 1.4840, rel_err_x: 0.2197
# Epoch 1500 | Loss: 0.904148 | rel_err_u: 1.4780, rel_err_x: 0.2174
# Epoch 1550 | Loss: 0.892522 | rel_err_u: 1.4739, rel_err_x: 0.2155
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1600 | Loss: 0.880879 | rel_err_u: 1.4731, rel_err_x: 0.2148
# Epoch 1650 | Loss: 0.871631 | rel_err_u: 1.4671, rel_err_x: 0.2126
# Epoch 1700 | Loss: 0.862759 | rel_err_u: 1.4616, rel_err_x: 0.2105
# Epoch 1750 | Loss: 0.853925 | rel_err_u: 1.4562, rel_err_x: 0.2084
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1800 | Loss: 0.845088 | rel_err_u: 1.4508, rel_err_x: 0.2063
# Epoch 1850 | Loss: 0.836297 | rel_err_u: 1.4458, rel_err_x: 0.2042
# Epoch 1900 | Loss: 0.827179 | rel_err_u: 1.4413, rel_err_x: 0.2023
# Epoch 1950 | Loss: 0.818434 | rel_err_u: 1.4374, rel_err_x: 0.2006
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2000 | Loss: 0.810047 | rel_err_u: 1.4336, rel_err_x: 0.1989
# Epoch 2050 | Loss: 0.802060 | rel_err_u: 1.4297, rel_err_x: 0.1971
# Epoch 2100 | Loss: 0.793846 | rel_err_u: 1.4260, rel_err_x: 0.1954
# Epoch 2150 | Loss: 0.785448 | rel_err_u: 1.4228, rel_err_x: 0.1937
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2200 | Loss: 0.776503 | rel_err_u: 1.4205, rel_err_x: 0.1923
# Epoch 2250 | Loss: 0.766926 | rel_err_u: 1.4193, rel_err_x: 0.1911
# Epoch 2300 | Loss: 0.756529 | rel_err_u: 1.4193, rel_err_x: 0.1902
# Epoch 2350 | Loss: 0.745332 | rel_err_u: 1.4207, rel_err_x: 0.1896
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2400 | Loss: 0.733135 | rel_err_u: 1.4233, rel_err_x: 0.1893
# Epoch 2450 | Loss: 0.719337 | rel_err_u: 1.4273, rel_err_x: 0.1895
# Epoch 2500 | Loss: 0.702839 | rel_err_u: 1.4333, rel_err_x: 0.1901
# Epoch 2550 | Loss: 0.683741 | rel_err_u: 1.4424, rel_err_x: 0.1917
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2600 | Loss: 0.662770 | rel_err_u: 1.4550, rel_err_x: 0.1943
# Epoch 2650 | Loss: 0.639955 | rel_err_u: 1.4706, rel_err_x: 0.1978
# Epoch 2700 | Loss: 0.614198 | rel_err_u: 1.4892, rel_err_x: 0.2025
# Epoch 2750 | Loss: 0.585725 | rel_err_u: 1.5107, rel_err_x: 0.2084
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2800 | Loss: 0.555822 | rel_err_u: 1.5336, rel_err_x: 0.2151
# Epoch 2850 | Loss: 0.527092 | rel_err_u: 1.5558, rel_err_x: 0.2219
# Epoch 2900 | Loss: 0.502379 | rel_err_u: 1.5744, rel_err_x: 0.2278
# Epoch 2950 | Loss: 0.483856 | rel_err_u: 1.5849, rel_err_x: 0.2314
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3000 | Loss: 0.462618 | rel_err_u: 1.5874, rel_err_x: 0.2328
# Epoch 3050 | Loss: 0.439089 | rel_err_u: 1.5895, rel_err_x: 0.2344
# Epoch 3100 | Loss: 0.423283 | rel_err_u: 1.5905, rel_err_x: 0.2354
# Epoch 3150 | Loss: 0.412294 | rel_err_u: 1.5882, rel_err_x: 0.2351
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3200 | Loss: 0.401045 | rel_err_u: 1.5855, rel_err_x: 0.2347
# Epoch 3250 | Loss: 0.387672 | rel_err_u: 1.5849, rel_err_x: 0.2348
# Epoch 3300 | Loss: 0.372665 | rel_err_u: 1.5872, rel_err_x: 0.2357
# Epoch 3350 | Loss: 0.357983 | rel_err_u: 1.5925, rel_err_x: 0.2377
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3400 | Loss: 0.346018 | rel_err_u: 1.5993, rel_err_x: 0.2401
# Epoch 3450 | Loss: 0.336374 | rel_err_u: 1.6054, rel_err_x: 0.2423
# Epoch 3500 | Loss: 0.328361 | rel_err_u: 1.6106, rel_err_x: 0.2442
# Epoch 3550 | Loss: 0.321730 | rel_err_u: 1.6152, rel_err_x: 0.2459
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3600 | Loss: 0.316199 | rel_err_u: 1.6192, rel_err_x: 0.2474
# Epoch 3650 | Loss: 0.311481 | rel_err_u: 1.6225, rel_err_x: 0.2488
# Epoch 3700 | Loss: 0.307427 | rel_err_u: 1.6252, rel_err_x: 0.2499
# Epoch 3750 | Loss: 0.303867 | rel_err_u: 1.6274, rel_err_x: 0.2509
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3800 | Loss: 0.300741 | rel_err_u: 1.6283, rel_err_x: 0.2514
# Epoch 3850 | Loss: 0.298003 | rel_err_u: 1.6281, rel_err_x: 0.2517
# Epoch 3900 | Loss: 0.295627 | rel_err_u: 1.6272, rel_err_x: 0.2516
# Epoch 3950 | Loss: 0.293405 | rel_err_u: 1.6260, rel_err_x: 0.2515
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4000 | Loss: 0.291323 | rel_err_u: 1.6246, rel_err_x: 0.2513
# Epoch 4050 | Loss: 0.289383 | rel_err_u: 1.6231, rel_err_x: 0.2511
# Epoch 4100 | Loss: 0.287442 | rel_err_u: 1.6216, rel_err_x: 0.2509
# Epoch 4150 | Loss: 0.285546 | rel_err_u: 1.6202, rel_err_x: 0.2507
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4200 | Loss: 0.283717 | rel_err_u: 1.6189, rel_err_x: 0.2505
# Epoch 4250 | Loss: 0.281828 | rel_err_u: 1.6177, rel_err_x: 0.2504
# Epoch 4300 | Loss: 0.280093 | rel_err_u: 1.6167, rel_err_x: 0.2504
# Epoch 4350 | Loss: 0.278576 | rel_err_u: 1.6158, rel_err_x: 0.2504
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4400 | Loss: 0.277202 | rel_err_u: 1.6150, rel_err_x: 0.2505
# Epoch 4450 | Loss: 0.275914 | rel_err_u: 1.6142, rel_err_x: 0.2505
# Epoch 4500 | Loss: 0.274685 | rel_err_u: 1.6134, rel_err_x: 0.2506
# Epoch 4550 | Loss: 0.273523 | rel_err_u: 1.6127, rel_err_x: 0.2506
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4600 | Loss: 0.272343 | rel_err_u: 1.6121, rel_err_x: 0.2508
# Epoch 4650 | Loss: 0.271114 | rel_err_u: 1.6116, rel_err_x: 0.2509
# Epoch 4700 | Loss: 0.269940 | rel_err_u: 1.6111, rel_err_x: 0.2510
# Epoch 4750 | Loss: 0.268715 | rel_err_u: 1.6107, rel_err_x: 0.2512
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4800 | Loss: 0.267437 | rel_err_u: 1.6105, rel_err_x: 0.2515
# Epoch 4850 | Loss: 0.266111 | rel_err_u: 1.6106, rel_err_x: 0.2518
# Epoch 4900 | Loss: 0.264690 | rel_err_u: 1.6109, rel_err_x: 0.2523
# Epoch 4950 | Loss: 0.263185 | rel_err_u: 1.6116, rel_err_x: 0.2528
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5000 | Loss: 0.261551 | rel_err_u: 1.6129, rel_err_x: 0.2535
# Epoch 5050 | Loss: 0.259701 | rel_err_u: 1.6148, rel_err_x: 0.2544
# Epoch 5100 | Loss: 0.257652 | rel_err_u: 1.6176, rel_err_x: 0.2556
# Epoch 5150 | Loss: 0.255296 | rel_err_u: 1.6217, rel_err_x: 0.2572
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5200 | Loss: 0.252476 | rel_err_u: 1.6275, rel_err_x: 0.2593
# Epoch 5250 | Loss: 0.248927 | rel_err_u: 1.6358, rel_err_x: 0.2621
# Epoch 5300 | Loss: 0.244291 | rel_err_u: 1.6471, rel_err_x: 0.2658
# Epoch 5350 | Loss: 0.237825 | rel_err_u: 1.6637, rel_err_x: 0.2710
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5400 | Loss: 0.228108 | rel_err_u: 1.6887, rel_err_x: 0.2786
# Epoch 5450 | Loss: 0.213424 | rel_err_u: 1.7253, rel_err_x: 0.2896
# Epoch 5500 | Loss: 0.193710 | rel_err_u: 1.7724, rel_err_x: 0.3041
# Epoch 5550 | Loss: 0.172883 | rel_err_u: 1.8225, rel_err_x: 0.3197
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5600 | Loss: 0.154368 | rel_err_u: 1.8697, rel_err_x: 0.3347
# Epoch 5650 | Loss: 0.139443 | rel_err_u: 1.9120, rel_err_x: 0.3483
# Epoch 5700 | Loss: 0.128822 | rel_err_u: 1.9459, rel_err_x: 0.3596
# Epoch 5750 | Loss: 0.121420 | rel_err_u: 1.9703, rel_err_x: 0.3681
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5800 | Loss: 0.115721 | rel_err_u: 1.9875, rel_err_x: 0.3742
# Epoch 5850 | Loss: 0.110821 | rel_err_u: 1.9999, rel_err_x: 0.3788
# Epoch 5900 | Loss: 0.106463 | rel_err_u: 2.0094, rel_err_x: 0.3823
# Epoch 5950 | Loss: 0.102519 | rel_err_u: 2.0168, rel_err_x: 0.3850
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6000 | Loss: 0.098858 | rel_err_u: 2.0228, rel_err_x: 0.3872
# Epoch 6050 | Loss: 0.095437 | rel_err_u: 2.0278, rel_err_x: 0.3889
# Epoch 6100 | Loss: 0.092127 | rel_err_u: 2.0317, rel_err_x: 0.3902
# Epoch 6150 | Loss: 0.088996 | rel_err_u: 2.0347, rel_err_x: 0.3911
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6200 | Loss: 0.085962 | rel_err_u: 2.0368, rel_err_x: 0.3916
# Epoch 6250 | Loss: 0.083009 | rel_err_u: 2.0379, rel_err_x: 0.3917
# Epoch 6300 | Loss: 0.080077 | rel_err_u: 2.0381, rel_err_x: 0.3915
# Epoch 6350 | Loss: 0.077222 | rel_err_u: 2.0373, rel_err_x: 0.3907
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6400 | Loss: 0.074321 | rel_err_u: 2.0354, rel_err_x: 0.3896
# Epoch 6450 | Loss: 0.071464 | rel_err_u: 2.0327, rel_err_x: 0.3881
# Epoch 6500 | Loss: 0.068573 | rel_err_u: 2.0292, rel_err_x: 0.3862
# Epoch 6550 | Loss: 0.065688 | rel_err_u: 2.0250, rel_err_x: 0.3840
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6600 | Loss: 0.062851 | rel_err_u: 2.0203, rel_err_x: 0.3816
# Epoch 6650 | Loss: 0.059957 | rel_err_u: 2.0153, rel_err_x: 0.3790
# Epoch 6700 | Loss: 0.057162 | rel_err_u: 2.0101, rel_err_x: 0.3763
# Epoch 6750 | Loss: 0.054419 | rel_err_u: 2.0049, rel_err_x: 0.3735
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6800 | Loss: 0.051712 | rel_err_u: 1.9996, rel_err_x: 0.3706
# Epoch 6850 | Loss: 0.049101 | rel_err_u: 1.9942, rel_err_x: 0.3677
# Epoch 6900 | Loss: 0.046519 | rel_err_u: 1.9884, rel_err_x: 0.3646
# Epoch 6950 | Loss: 0.043857 | rel_err_u: 1.9815, rel_err_x: 0.3611
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7000 | Loss: 0.040956 | rel_err_u: 1.9732, rel_err_x: 0.3571
# Epoch 7050 | Loss: 0.037840 | rel_err_u: 1.9631, rel_err_x: 0.3525
# Epoch 7100 | Loss: 0.034859 | rel_err_u: 1.9528, rel_err_x: 0.3479
# Epoch 7150 | Loss: 0.032121 | rel_err_u: 1.9429, rel_err_x: 0.3435
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7200 | Loss: 0.029565 | rel_err_u: 1.9332, rel_err_x: 0.3393
# Epoch 7250 | Loss: 0.027125 | rel_err_u: 1.9235, rel_err_x: 0.3350
# Epoch 7300 | Loss: 0.024801 | rel_err_u: 1.9138, rel_err_x: 0.3308
# Epoch 7350 | Loss: 0.022468 | rel_err_u: 1.9041, rel_err_x: 0.3266
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7400 | Loss: 0.020135 | rel_err_u: 1.8944, rel_err_x: 0.3223
# Epoch 7450 | Loss: 0.017862 | rel_err_u: 1.8847, rel_err_x: 0.3181
# Epoch 7500 | Loss: 0.015588 | rel_err_u: 1.8750, rel_err_x: 0.3139
# Epoch 7550 | Loss: 0.013346 | rel_err_u: 1.8654, rel_err_x: 0.3098
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7600 | Loss: 0.011089 | rel_err_u: 1.8559, rel_err_x: 0.3057
# Epoch 7650 | Loss: 0.008854 | rel_err_u: 1.8466, rel_err_x: 0.3017
# Epoch 7700 | Loss: 0.006622 | rel_err_u: 1.8375, rel_err_x: 0.2979
# Epoch 7750 | Loss: 0.004246 | rel_err_u: 1.8284, rel_err_x: 0.2941
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7800 | Loss: 0.001550 | rel_err_u: 1.8193, rel_err_x: 0.2903
# Epoch 7850 | Loss: -0.001584 | rel_err_u: 1.8104, rel_err_x: 0.2867
# Epoch 7900 | Loss: -0.004275 | rel_err_u: 1.8031, rel_err_x: 0.2838
# Epoch 7950 | Loss: -0.006301 | rel_err_u: 1.7975, rel_err_x: 0.2816
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8000 | Loss: -0.008064 | rel_err_u: 1.7929, rel_err_x: 0.2799
# Epoch 8050 | Loss: -0.009814 | rel_err_u: 1.7889, rel_err_x: 0.2784
# Epoch 8100 | Loss: -0.011624 | rel_err_u: 1.7851, rel_err_x: 0.2771
# Epoch 8150 | Loss: -0.013403 | rel_err_u: 1.7818, rel_err_x: 0.2759
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8200 | Loss: -0.015257 | rel_err_u: 1.7789, rel_err_x: 0.2749
# Epoch 8250 | Loss: -0.017301 | rel_err_u: 1.7762, rel_err_x: 0.2740
# Epoch 8300 | Loss: -0.019418 | rel_err_u: 1.7739, rel_err_x: 0.2732
# Epoch 8350 | Loss: -0.021515 | rel_err_u: 1.7722, rel_err_x: 0.2725
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8400 | Loss: -0.023410 | rel_err_u: 1.7707, rel_err_x: 0.2719
# Epoch 8450 | Loss: -0.024858 | rel_err_u: 1.7695, rel_err_x: 0.2713
# Epoch 8500 | Loss: -0.025942 | rel_err_u: 1.7685, rel_err_x: 0.2708
# Epoch 8550 | Loss: -0.026635 | rel_err_u: 1.7675, rel_err_x: 0.2703
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8600 | Loss: -0.027150 | rel_err_u: 1.7668, rel_err_x: 0.2699
# Epoch 8650 | Loss: -0.027480 | rel_err_u: 1.7664, rel_err_x: 0.2696
# Epoch 8700 | Loss: -0.027695 | rel_err_u: 1.7661, rel_err_x: 0.2694
# Epoch 8750 | Loss: -0.027847 | rel_err_u: 1.7660, rel_err_x: 0.2692
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8800 | Loss: -0.027963 | rel_err_u: 1.7659, rel_err_x: 0.2690
# Epoch 8850 | Loss: -0.028011 | rel_err_u: 1.7660, rel_err_x: 0.2689
# Epoch 8900 | Loss: -0.028066 | rel_err_u: 1.7660, rel_err_x: 0.2689
# Epoch 8950 | Loss: -0.028092 | rel_err_u: 1.7662, rel_err_x: 0.2689
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9000 | Loss: -0.028123 | rel_err_u: 1.7663, rel_err_x: 0.2688
# Epoch 9050 | Loss: -0.028131 | rel_err_u: 1.7664, rel_err_x: 0.2688
# Epoch 9100 | Loss: -0.028137 | rel_err_u: 1.7666, rel_err_x: 0.2688
# Epoch 9150 | Loss: -0.028158 | rel_err_u: 1.7667, rel_err_x: 0.2688
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9200 | Loss: -0.028156 | rel_err_u: 1.7668, rel_err_x: 0.2688
# Epoch 9250 | Loss: -0.028155 | rel_err_u: 1.7669, rel_err_x: 0.2688
# Epoch 9300 | Loss: -0.028158 | rel_err_u: 1.7670, rel_err_x: 0.2688
# Epoch 9350 | Loss: -0.028156 | rel_err_u: 1.7671, rel_err_x: 0.2688
# [Early stop] Epoch 9362 | Best loss: -2.8163e-02

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: -0.03414168953895569

# %% [markdown]
# <image src="found_trajectories/nonlinear/lno/plot.png" width=600>

# %%
m = 200

modes = 32
width = 16
hidden_layer = 128

model = LNO1d(width, modes, activation = "silu",batch_norm=True, active_last=True, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/singular_arc/lno/attempt_started20250720_215514/epoch[1000]_model_time_[20250720_215514]_loss_[0.0148].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [50, 1, 1, 0, 10]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)-3 

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'singular_arc',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 100000,
    early_stopping=True,
    m=m,
    bounds = [-3.5, 0],
    device=device,
    result=True,
    plots=False,
)
# Out:
# Epoch   50 | Loss: 10.844107 | rel_err_u: 1.0218, rel_err_x: 1.2115
# Epoch  100 | Loss: 10.369057 | rel_err_u: 0.9943, rel_err_x: 1.1598
# Epoch  150 | Loss: 9.939803 | rel_err_u: 0.9668, rel_err_x: 1.1077
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  200 | Loss: 9.548416 | rel_err_u: 0.9397, rel_err_x: 1.0556
# Epoch  250 | Loss: 9.189808 | rel_err_u: 0.9132, rel_err_x: 1.0041
# Epoch  300 | Loss: 8.859728 | rel_err_u: 0.8873, rel_err_x: 0.9536
# Epoch  350 | Loss: 8.555278 | rel_err_u: 0.8620, rel_err_x: 0.9046
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  400 | Loss: 8.274195 | rel_err_u: 0.8374, rel_err_x: 0.8572
# Epoch  450 | Loss: 8.015017 | rel_err_u: 0.8135, rel_err_x: 0.8120
# Epoch  500 | Loss: 7.776542 | rel_err_u: 0.7902, rel_err_x: 0.7690
# Epoch  550 | Loss: 7.557256 | rel_err_u: 0.7676, rel_err_x: 0.7285
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  600 | Loss: 7.355408 | rel_err_u: 0.7455, rel_err_x: 0.6906
# Epoch  650 | Loss: 7.169471 | rel_err_u: 0.7240, rel_err_x: 0.6552
# Epoch  700 | Loss: 6.997785 | rel_err_u: 0.7030, rel_err_x: 0.6225
# Epoch  750 | Loss: 6.838548 | rel_err_u: 0.6824, rel_err_x: 0.5922
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  800 | Loss: 6.690548 | rel_err_u: 0.6622, rel_err_x: 0.5640
# Epoch  850 | Loss: 6.551816 | rel_err_u: 0.6425, rel_err_x: 0.5378
# Epoch  900 | Loss: 6.421354 | rel_err_u: 0.6231, rel_err_x: 0.5133
# Epoch  950 | Loss: 6.297554 | rel_err_u: 0.6041, rel_err_x: 0.4902
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1000 | Loss: 6.180299 | rel_err_u: 0.5855, rel_err_x: 0.4683
# Epoch 1050 | Loss: 6.068179 | rel_err_u: 0.5671, rel_err_x: 0.4475
# Epoch 1100 | Loss: 5.961030 | rel_err_u: 0.5492, rel_err_x: 0.4275
# Epoch 1150 | Loss: 5.859135 | rel_err_u: 0.5316, rel_err_x: 0.4083
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1200 | Loss: 5.762360 | rel_err_u: 0.5144, rel_err_x: 0.3897
# Epoch 1250 | Loss: 5.670156 | rel_err_u: 0.4975, rel_err_x: 0.3716
# Epoch 1300 | Loss: 5.582724 | rel_err_u: 0.4811, rel_err_x: 0.3540
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 15
#      12 w = [50, 1, 1, 0, 10]
#      13 initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)-3
# ---> 15 analytics, x, u, x_optimal, u_optimal = solve_optimization(
#      16     model, 'singular_arc',
#      17     initial_guess,
#      18     lr=0.001,
#      19     architecture="lno",
#      20     w=w,
#      21     num_epochs = 100000,
#      22     early_stopping=True,
#      23     m=m,
#      24     bounds = [-3.5, 0],
#      25     device=device,
#      26     result=True
#      27 )
#
# File ~/Thesis-2/utils/scripts.py:114, in solve_optimization(model, problem, initial_guess, lr, architecture, w, bounds, num_epochs, m, device, plot_interval, result, early_stopping, patience, min_delta, plots)
#     111 analytics['obj'].append(obj.item())
#     112 analytics['total_loss'].append(loss.item())
# --> 114 loss.backward()
#     115 optimizer.step()
#     117 if early_stopping:
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)    624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~/Thesis-2/.venv/lib/python3.11/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 2.183225393295288

# %% [markdown]
# <image src="found_trajectories/singular_arc/lno/plot.png" width=600>

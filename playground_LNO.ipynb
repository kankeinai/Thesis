# %% [markdown]
# # Notebook \#3 - Operator Learning and Optimal Control
# version: LNO
#
# for some instructions regarding use of special functions from this repo, consider starting from exploring `playground_deeponet.ipynb`

# %%
import torch
from utils.scripts import solve_optimization
from models.lno import LNO1d, LNO1d_extended

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64


model = LNO1d(modes=modes, width=width, activation="silu", hidden_layer = hidden_layer).to(device)

ckpt = torch.load("trained_models/linear/lno/unsupervised/epoch[670]_model_time_[20250718_232320]_loss_[0.0011].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [10, 1, 1, 0, 0]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'linear',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs=5000,
    m=m,
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 0.684169 | rel_err_u: 3.5953, rel_err_x: 0.4820
# Epoch  100 | Loss: 0.604572 | rel_err_u: 3.4798, rel_err_x: 0.4703
# Epoch  150 | Loss: 0.545865 | rel_err_u: 3.3590, rel_err_x: 0.4560
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  200 | Loss: 0.500890 | rel_err_u: 3.2362, rel_err_x: 0.4403
# Epoch  250 | Loss: 0.465107 | rel_err_u: 3.1126, rel_err_x: 0.4235
# Epoch  300 | Loss: 0.435577 | rel_err_u: 2.9890, rel_err_x: 0.4062
# Epoch  350 | Loss: 0.410481 | rel_err_u: 2.8660, rel_err_x: 0.3884
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  400 | Loss: 0.388684 | rel_err_u: 2.7446, rel_err_x: 0.3706
# Epoch  450 | Loss: 0.369450 | rel_err_u: 2.6252, rel_err_x: 0.3529
# Epoch  500 | Loss: 0.352292 | rel_err_u: 2.5085, rel_err_x: 0.3354
# Epoch  550 | Loss: 0.336863 | rel_err_u: 2.3948, rel_err_x: 0.3183
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  600 | Loss: 0.322923 | rel_err_u: 2.2842, rel_err_x: 0.3015
# Epoch  650 | Loss: 0.310287 | rel_err_u: 2.1770, rel_err_x: 0.2852
# Epoch  700 | Loss: 0.298804 | rel_err_u: 2.0733, rel_err_x: 0.2695
# Epoch  750 | Loss: 0.288360 | rel_err_u: 1.9731, rel_err_x: 0.2542
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch  800 | Loss: 0.278859 | rel_err_u: 1.8765, rel_err_x: 0.2395
# Epoch  850 | Loss: 0.270215 | rel_err_u: 1.7833, rel_err_x: 0.2254
# Epoch  900 | Loss: 0.262351 | rel_err_u: 1.6937, rel_err_x: 0.2119
# Epoch  950 | Loss: 0.255208 | rel_err_u: 1.6075, rel_err_x: 0.1989
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1000 | Loss: 0.248724 | rel_err_u: 1.5247, rel_err_x: 0.1865
# Epoch 1050 | Loss: 0.242843 | rel_err_u: 1.4452, rel_err_x: 0.1746
# Epoch 1100 | Loss: 0.237519 | rel_err_u: 1.3691, rel_err_x: 0.1633
# Epoch 1150 | Loss: 0.232704 | rel_err_u: 1.2961, rel_err_x: 0.1525
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1200 | Loss: 0.228355 | rel_err_u: 1.2263, rel_err_x: 0.1423
# Epoch 1250 | Loss: 0.224436 | rel_err_u: 1.1596, rel_err_x: 0.1326
# Epoch 1300 | Loss: 0.220909 | rel_err_u: 1.0958, rel_err_x: 0.1234
# Epoch 1350 | Loss: 0.217738 | rel_err_u: 1.0350, rel_err_x: 0.1146
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1400 | Loss: 0.214893 | rel_err_u: 0.9770, rel_err_x: 0.1064
# Epoch 1450 | Loss: 0.212344 | rel_err_u: 0.9217, rel_err_x: 0.0986
# Epoch 1500 | Loss: 0.210065 | rel_err_u: 0.8691, rel_err_x: 0.0913
# Epoch 1550 | Loss: 0.208029 | rel_err_u: 0.8190, rel_err_x: 0.0844
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1600 | Loss: 0.206213 | rel_err_u: 0.7714, rel_err_x: 0.0779
# Epoch 1650 | Loss: 0.204595 | rel_err_u: 0.7262, rel_err_x: 0.0718
# Epoch 1700 | Loss: 0.203159 | rel_err_u: 0.6833, rel_err_x: 0.0661
# Epoch 1750 | Loss: 0.201881 | rel_err_u: 0.6425, rel_err_x: 0.0607
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 1800 | Loss: 0.200748 | rel_err_u: 0.6039, rel_err_x: 0.0558
# Epoch 1850 | Loss: 0.199744 | rel_err_u: 0.5672, rel_err_x: 0.0511
# Epoch 1900 | Loss: 0.198856 | rel_err_u: 0.5325, rel_err_x: 0.0468
# Epoch 1950 | Loss: 0.198069 | rel_err_u: 0.4996, rel_err_x: 0.0427
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2000 | Loss: 0.197375 | rel_err_u: 0.4684, rel_err_x: 0.0390
# Epoch 2050 | Loss: 0.196762 | rel_err_u: 0.4389, rel_err_x: 0.0355
# Epoch 2100 | Loss: 0.196222 | rel_err_u: 0.4109, rel_err_x: 0.0323
# Epoch 2150 | Loss: 0.195747 | rel_err_u: 0.3844, rel_err_x: 0.0294
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2200 | Loss: 0.195328 | rel_err_u: 0.3594, rel_err_x: 0.0266
# Epoch 2250 | Loss: 0.194960 | rel_err_u: 0.3357, rel_err_x: 0.0241
# Epoch 2300 | Loss: 0.194637 | rel_err_u: 0.3133, rel_err_x: 0.0218
# Epoch 2350 | Loss: 0.194354 | rel_err_u: 0.2921, rel_err_x: 0.0197
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2400 | Loss: 0.194106 | rel_err_u: 0.2721, rel_err_x: 0.0177
# Epoch 2450 | Loss: 0.193889 | rel_err_u: 0.2531, rel_err_x: 0.0159
# Epoch 2500 | Loss: 0.193699 | rel_err_u: 0.2353, rel_err_x: 0.0143
# Epoch 2550 | Loss: 0.193534 | rel_err_u: 0.2184, rel_err_x: 0.0128
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2600 | Loss: 0.193390 | rel_err_u: 0.2025, rel_err_x: 0.0114
# Epoch 2650 | Loss: 0.193265 | rel_err_u: 0.1875, rel_err_x: 0.0102
# Epoch 2700 | Loss: 0.193156 | rel_err_u: 0.1734, rel_err_x: 0.0091
# Epoch 2750 | Loss: 0.193063 | rel_err_u: 0.1602, rel_err_x: 0.0080
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 2800 | Loss: 0.192982 | rel_err_u: 0.1477, rel_err_x: 0.0071
# Epoch 2850 | Loss: 0.192912 | rel_err_u: 0.1361, rel_err_x: 0.0063
# Epoch 2900 | Loss: 0.192852 | rel_err_u: 0.1251, rel_err_x: 0.0055
# Epoch 2950 | Loss: 0.192801 | rel_err_u: 0.1149, rel_err_x: 0.0048
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3000 | Loss: 0.192758 | rel_err_u: 0.1053, rel_err_x: 0.0042
# Epoch 3050 | Loss: 0.192720 | rel_err_u: 0.0964, rel_err_x: 0.0036
# Epoch 3100 | Loss: 0.192689 | rel_err_u: 0.0881, rel_err_x: 0.0031
# Epoch 3150 | Loss: 0.192662 | rel_err_u: 0.0804, rel_err_x: 0.0027
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3200 | Loss: 0.192640 | rel_err_u: 0.0733, rel_err_x: 0.0023
# Epoch 3250 | Loss: 0.192621 | rel_err_u: 0.0667, rel_err_x: 0.0019
# Epoch 3300 | Loss: 0.192605 | rel_err_u: 0.0607, rel_err_x: 0.0016
# Epoch 3350 | Loss: 0.192592 | rel_err_u: 0.0551, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3400 | Loss: 0.192582 | rel_err_u: 0.0500, rel_err_x: 0.0011
# Epoch 3450 | Loss: 0.192573 | rel_err_u: 0.0454, rel_err_x: 0.0009
# Epoch 3500 | Loss: 0.192565 | rel_err_u: 0.0412, rel_err_x: 0.0008
# Epoch 3550 | Loss: 0.192559 | rel_err_u: 0.0374, rel_err_x: 0.0008
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3600 | Loss: 0.192555 | rel_err_u: 0.0340, rel_err_x: 0.0007
# Epoch 3650 | Loss: 0.192551 | rel_err_u: 0.0310, rel_err_x: 0.0007
# Epoch 3700 | Loss: 0.192548 | rel_err_u: 0.0283, rel_err_x: 0.0008
# Epoch 3750 | Loss: 0.192545 | rel_err_u: 0.0259, rel_err_x: 0.0008
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 3800 | Loss: 0.192543 | rel_err_u: 0.0239, rel_err_x: 0.0009
# Epoch 3850 | Loss: 0.192542 | rel_err_u: 0.0221, rel_err_x: 0.0009
# Epoch 3900 | Loss: 0.192540 | rel_err_u: 0.0206, rel_err_x: 0.0010
# Epoch 3950 | Loss: 0.192540 | rel_err_u: 0.0193, rel_err_x: 0.0010
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4000 | Loss: 0.192539 | rel_err_u: 0.0183, rel_err_x: 0.0011
# Epoch 4050 | Loss: 0.192538 | rel_err_u: 0.0174, rel_err_x: 0.0011
# Epoch 4100 | Loss: 0.192538 | rel_err_u: 0.0167, rel_err_x: 0.0012
# Epoch 4150 | Loss: 0.192538 | rel_err_u: 0.0161, rel_err_x: 0.0012
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4200 | Loss: 0.192537 | rel_err_u: 0.0157, rel_err_x: 0.0012
# Epoch 4250 | Loss: 0.192537 | rel_err_u: 0.0153, rel_err_x: 0.0013
# Epoch 4300 | Loss: 0.192537 | rel_err_u: 0.0151, rel_err_x: 0.0013
# Epoch 4350 | Loss: 0.192537 | rel_err_u: 0.0148, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4400 | Loss: 0.192537 | rel_err_u: 0.0147, rel_err_x: 0.0013
# Epoch 4450 | Loss: 0.192537 | rel_err_u: 0.0145, rel_err_x: 0.0013
# Epoch 4500 | Loss: 0.192537 | rel_err_u: 0.0145, rel_err_x: 0.0013
# Epoch 4550 | Loss: 0.192537 | rel_err_u: 0.0144, rel_err_x: 0.0013
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4600 | Loss: 0.192537 | rel_err_u: 0.0143, rel_err_x: 0.0014
# Epoch 4650 | Loss: 0.192537 | rel_err_u: 0.0143, rel_err_x: 0.0014
# Epoch 4700 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4750 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 4800 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4850 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4900 | Loss: 0.192536 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Epoch 4950 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014
# Plot saved to found_trajectories/linear/lno/plot.png
# Epoch 5000 | Loss: 0.192537 | rel_err_u: 0.0142, rel_err_x: 0.0014

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.1925065517425537

# %% [markdown]
# <image src="found_trajectories/linear/lno/plot.png" width=600>

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64

model = LNO1d(modes=modes, width=width, activation="silu", hidden_layer = hidden_layer).to(device)
ckpt = torch.load("trained_models/oscillatory/lno/unsupervised/epoch[1000]_model_time_[20250718_232530]_loss_[0.0017].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [10, 1, 1, 0, 0.1]
initial_guess = torch.zeros((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'oscillatory',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 200,
    m=m,
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 0.001898 | rel_err_u: 1.2697, rel_err_x: 0.0524
# Epoch  100 | Loss: 0.001898 | rel_err_u: 1.3020, rel_err_x: 0.0535
# Epoch  150 | Loss: 0.001898 | rel_err_u: 1.3005, rel_err_x: 0.0534
# Plot saved to found_trajectories/oscillatory/lno/plot.png
# Epoch  200 | Loss: 0.001898 | rel_err_u: 1.3008, rel_err_x: 0.0535

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.0015614270232617855

# %% [markdown]
# <image src="found_trajectories/oscillatory/lno/plot.png" width=600>

# %%
m = 200
modes = 8
width = 4
hidden_layer = 64

model = LNO1d(width, modes, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/polynomial_tracking/lno/unsupervised/epoch[1000]_model_time_[20250718_233449]_loss_[0.0127].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [100, 1, 1, 1, 0]
initial_guess = torch.zeros((1, m), dtype=torch.float32, device=device, requires_grad=True)

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'polynomial_tracking',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 700,
    m=m,
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 0.180666 | rel_err_u: 0.7667, rel_err_x: 0.7807
# Epoch  100 | Loss: 0.166927 | rel_err_u: 0.5691, rel_err_x: 0.5817
# Epoch  150 | Loss: 0.158748 | rel_err_u: 0.4093, rel_err_x: 0.4189
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  200 | Loss: 0.154209 | rel_err_u: 0.2848, rel_err_x: 0.2912
# Epoch  250 | Loss: 0.151876 | rel_err_u: 0.1918, rel_err_x: 0.1955
# Epoch  300 | Loss: 0.150771 | rel_err_u: 0.1257, rel_err_x: 0.1270
# Epoch  350 | Loss: 0.150287 | rel_err_u: 0.0815, rel_err_x: 0.0802
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  400 | Loss: 0.150091 | rel_err_u: 0.0547, rel_err_x: 0.0498
# Epoch  450 | Loss: 0.150019 | rel_err_u: 0.0406, rel_err_x: 0.0309
# Epoch  500 | Loss: 0.149994 | rel_err_u: 0.0348, rel_err_x: 0.0197
# Epoch  550 | Loss: 0.149985 | rel_err_u: 0.0330, rel_err_x: 0.0133
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  600 | Loss: 0.149983 | rel_err_u: 0.0326, rel_err_x: 0.0099
# Epoch  650 | Loss: 0.149983 | rel_err_u: 0.0326, rel_err_x: 0.0080
# Plot saved to found_trajectories/polynomial_tracking/lno/plot.png
# Epoch  700 | Loss: 0.149982 | rel_err_u: 0.0327, rel_err_x: 0.0071

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 0.14918164908885956

# %% [markdown]
# <image src="found_trajectories/polynomial_tracking/lno/plot.png" width=600>

# %%
m = 200

modes = [8, 8]
width = 4
hidden_layer = 64
model = LNO1d_extended(modes=modes, width=width, activation="tanh", depth=2, active_last=True, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/nonlinear/lno/unsupervised/epoch[360]_model_time_[20250719_151537]_loss_[0.0597].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [100, 1, 1, 1, 0]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True)*1.5

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'nonlinear',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 10000,
    m=m,
    bounds = [-1.5, 1.5],
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 53.959167 | rel_err_u: 2.8163, rel_err_x: 0.9797
# Epoch  100 | Loss: 39.567245 | rel_err_u: 2.7453, rel_err_x: 0.9209
# Epoch  150 | Loss: 29.728518 | rel_err_u: 2.6896, rel_err_x: 0.8770
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  200 | Loss: 22.792616 | rel_err_u: 2.6464, rel_err_x: 0.8448
# Epoch  250 | Loss: 17.753542 | rel_err_u: 2.6124, rel_err_x: 0.8209
# Epoch  300 | Loss: 14.004498 | rel_err_u: 2.5853, rel_err_x: 0.8031
# Epoch  350 | Loss: 11.178853 | rel_err_u: 2.5633, rel_err_x: 0.7897
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  400 | Loss: 9.033087 | rel_err_u: 2.5450, rel_err_x: 0.7795
# Epoch  450 | Loss: 7.406290 | rel_err_u: 2.5291, rel_err_x: 0.7714
# Epoch  500 | Loss: 6.174303 | rel_err_u: 2.5148, rel_err_x: 0.7643
# Epoch  550 | Loss: 5.241703 | rel_err_u: 2.5014, rel_err_x: 0.7577
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  600 | Loss: 4.536452 | rel_err_u: 2.4884, rel_err_x: 0.7514
# Epoch  650 | Loss: 3.999624 | rel_err_u: 2.4757, rel_err_x: 0.7450
# Epoch  700 | Loss: 3.590427 | rel_err_u: 2.4633, rel_err_x: 0.7388
# Epoch  750 | Loss: 3.272870 | rel_err_u: 2.4515, rel_err_x: 0.7327
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch  800 | Loss: 3.026353 | rel_err_u: 2.4401, rel_err_x: 0.7269
# Epoch  850 | Loss: 2.831101 | rel_err_u: 2.4293, rel_err_x: 0.7214
# Epoch  900 | Loss: 2.675693 | rel_err_u: 2.4187, rel_err_x: 0.7159
# Epoch  950 | Loss: 2.550248 | rel_err_u: 2.4082, rel_err_x: 0.7104
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1000 | Loss: 2.445663 | rel_err_u: 2.3979, rel_err_x: 0.7050
# Epoch 1050 | Loss: 2.358304 | rel_err_u: 2.3879, rel_err_x: 0.6997
# Epoch 1100 | Loss: 2.283582 | rel_err_u: 2.3782, rel_err_x: 0.6945
# Epoch 1150 | Loss: 2.218111 | rel_err_u: 2.3687, rel_err_x: 0.6895
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1200 | Loss: 2.160579 | rel_err_u: 2.3597, rel_err_x: 0.6847
# Epoch 1250 | Loss: 2.108999 | rel_err_u: 2.3509, rel_err_x: 0.6800
# Epoch 1300 | Loss: 2.063237 | rel_err_u: 2.3425, rel_err_x: 0.6755
# Epoch 1350 | Loss: 2.021610 | rel_err_u: 2.3343, rel_err_x: 0.6712
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1400 | Loss: 1.984082 | rel_err_u: 2.3263, rel_err_x: 0.6669
# Epoch 1450 | Loss: 1.949601 | rel_err_u: 2.3184, rel_err_x: 0.6627
# Epoch 1500 | Loss: 1.918117 | rel_err_u: 2.3105, rel_err_x: 0.6584
# Epoch 1550 | Loss: 1.889095 | rel_err_u: 2.3027, rel_err_x: 0.6541
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1600 | Loss: 1.861825 | rel_err_u: 2.2948, rel_err_x: 0.6498
# Epoch 1650 | Loss: 1.836674 | rel_err_u: 2.2868, rel_err_x: 0.6453
# Epoch 1700 | Loss: 1.813008 | rel_err_u: 2.2789, rel_err_x: 0.6408
# Epoch 1750 | Loss: 1.790438 | rel_err_u: 2.2709, rel_err_x: 0.6363
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 1800 | Loss: 1.768446 | rel_err_u: 2.2635, rel_err_x: 0.6320
# Epoch 1850 | Loss: 1.747702 | rel_err_u: 2.2564, rel_err_x: 0.6281
# Epoch 1900 | Loss: 1.728204 | rel_err_u: 2.2489, rel_err_x: 0.6238
# Epoch 1950 | Loss: 1.710396 | rel_err_u: 2.2406, rel_err_x: 0.6190
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2000 | Loss: 1.693194 | rel_err_u: 2.2321, rel_err_x: 0.6139
# Epoch 2050 | Loss: 1.676718 | rel_err_u: 2.2234, rel_err_x: 0.6087
# Epoch 2100 | Loss: 1.660942 | rel_err_u: 2.2146, rel_err_x: 0.6035
# Epoch 2150 | Loss: 1.645465 | rel_err_u: 2.2058, rel_err_x: 0.5982
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2200 | Loss: 1.630486 | rel_err_u: 2.1969, rel_err_x: 0.5929
# Epoch 2250 | Loss: 1.615864 | rel_err_u: 2.1879, rel_err_x: 0.5875
# Epoch 2300 | Loss: 1.601691 | rel_err_u: 2.1790, rel_err_x: 0.5821
# Epoch 2350 | Loss: 1.588104 | rel_err_u: 2.1700, rel_err_x: 0.5767
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2400 | Loss: 1.574899 | rel_err_u: 2.1608, rel_err_x: 0.5712
# Epoch 2450 | Loss: 1.562248 | rel_err_u: 2.1516, rel_err_x: 0.5656
# Epoch 2500 | Loss: 1.549617 | rel_err_u: 2.1422, rel_err_x: 0.5600
# Epoch 2550 | Loss: 1.537351 | rel_err_u: 2.1327, rel_err_x: 0.5543
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2600 | Loss: 1.525368 | rel_err_u: 2.1231, rel_err_x: 0.5485
# Epoch 2650 | Loss: 1.513434 | rel_err_u: 2.1134, rel_err_x: 0.5428
# Epoch 2700 | Loss: 1.501667 | rel_err_u: 2.1037, rel_err_x: 0.5370
# Epoch 2750 | Loss: 1.489835 | rel_err_u: 2.0939, rel_err_x: 0.5312
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 2800 | Loss: 1.478250 | rel_err_u: 2.0841, rel_err_x: 0.5254
# Epoch 2850 | Loss: 1.466569 | rel_err_u: 2.0743, rel_err_x: 0.5196
# Epoch 2900 | Loss: 1.454923 | rel_err_u: 2.0644, rel_err_x: 0.5138
# Epoch 2950 | Loss: 1.443161 | rel_err_u: 2.0545, rel_err_x: 0.5080
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3000 | Loss: 1.430941 | rel_err_u: 2.0446, rel_err_x: 0.5022
# Epoch 3050 | Loss: 1.418151 | rel_err_u: 2.0348, rel_err_x: 0.4966
# Epoch 3100 | Loss: 1.404825 | rel_err_u: 2.0253, rel_err_x: 0.4911
# Epoch 3150 | Loss: 1.390768 | rel_err_u: 2.0160, rel_err_x: 0.4858
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3200 | Loss: 1.376446 | rel_err_u: 2.0071, rel_err_x: 0.4807
# Epoch 3250 | Loss: 1.361234 | rel_err_u: 1.9992, rel_err_x: 0.4762
# Epoch 3300 | Loss: 1.348281 | rel_err_u: 1.9926, rel_err_x: 0.4723
# Epoch 3350 | Loss: 1.338185 | rel_err_u: 1.9827, rel_err_x: 0.4670
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3400 | Loss: 1.328351 | rel_err_u: 1.9721, rel_err_x: 0.4613
# Epoch 3450 | Loss: 1.318334 | rel_err_u: 1.9615, rel_err_x: 0.4557
# Epoch 3500 | Loss: 1.308372 | rel_err_u: 1.9510, rel_err_x: 0.4500
# Epoch 3550 | Loss: 1.297547 | rel_err_u: 1.9408, rel_err_x: 0.4446
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3600 | Loss: 1.285326 | rel_err_u: 1.9313, rel_err_x: 0.4395
# Epoch 3650 | Loss: 1.273519 | rel_err_u: 1.9226, rel_err_x: 0.4348
# Epoch 3700 | Loss: 1.262125 | rel_err_u: 1.9142, rel_err_x: 0.4305
# Epoch 3750 | Loss: 1.250969 | rel_err_u: 1.9061, rel_err_x: 0.4263
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 3800 | Loss: 1.240246 | rel_err_u: 1.8980, rel_err_x: 0.4221
# Epoch 3850 | Loss: 1.229785 | rel_err_u: 1.8896, rel_err_x: 0.4178
# Epoch 3900 | Loss: 1.219506 | rel_err_u: 1.8810, rel_err_x: 0.4133
# Epoch 3950 | Loss: 1.209208 | rel_err_u: 1.8720, rel_err_x: 0.4087
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4000 | Loss: 1.199154 | rel_err_u: 1.8628, rel_err_x: 0.4041
# Epoch 4050 | Loss: 1.189262 | rel_err_u: 1.8533, rel_err_x: 0.3993
# Epoch 4100 | Loss: 1.179638 | rel_err_u: 1.8434, rel_err_x: 0.3944
# Epoch 4150 | Loss: 1.170232 | rel_err_u: 1.8330, rel_err_x: 0.3893
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4200 | Loss: 1.160619 | rel_err_u: 1.8221, rel_err_x: 0.3842
# Epoch 4250 | Loss: 1.150973 | rel_err_u: 1.8111, rel_err_x: 0.3789
# Epoch 4300 | Loss: 1.141145 | rel_err_u: 1.7999, rel_err_x: 0.3737
# Epoch 4350 | Loss: 1.130803 | rel_err_u: 1.7888, rel_err_x: 0.3686
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4400 | Loss: 1.120287 | rel_err_u: 1.7778, rel_err_x: 0.3635
# Epoch 4450 | Loss: 1.109130 | rel_err_u: 1.7670, rel_err_x: 0.3586
# Epoch 4500 | Loss: 1.097710 | rel_err_u: 1.7563, rel_err_x: 0.3538
# Epoch 4550 | Loss: 1.085674 | rel_err_u: 1.7460, rel_err_x: 0.3491
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4600 | Loss: 1.073381 | rel_err_u: 1.7359, rel_err_x: 0.3446
# Epoch 4650 | Loss: 1.060425 | rel_err_u: 1.7261, rel_err_x: 0.3402
# Epoch 4700 | Loss: 1.047056 | rel_err_u: 1.7167, rel_err_x: 0.3360
# Epoch 4750 | Loss: 1.031935 | rel_err_u: 1.7081, rel_err_x: 0.3321
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 4800 | Loss: 1.016075 | rel_err_u: 1.7024, rel_err_x: 0.3296
# Epoch 4850 | Loss: 1.002490 | rel_err_u: 1.6949, rel_err_x: 0.3265
# Epoch 4900 | Loss: 0.989015 | rel_err_u: 1.6870, rel_err_x: 0.3232
# Epoch 4950 | Loss: 0.975414 | rel_err_u: 1.6793, rel_err_x: 0.3200
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5000 | Loss: 0.961342 | rel_err_u: 1.6719, rel_err_x: 0.3170
# Epoch 5050 | Loss: 0.946007 | rel_err_u: 1.6657, rel_err_x: 0.3144
# Epoch 5100 | Loss: 0.929722 | rel_err_u: 1.6610, rel_err_x: 0.3126
# Epoch 5150 | Loss: 0.913730 | rel_err_u: 1.6572, rel_err_x: 0.3112
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5200 | Loss: 0.898162 | rel_err_u: 1.6533, rel_err_x: 0.3098
# Epoch 5250 | Loss: 0.883259 | rel_err_u: 1.6491, rel_err_x: 0.3083
# Epoch 5300 | Loss: 0.868917 | rel_err_u: 1.6449, rel_err_x: 0.3069
# Epoch 5350 | Loss: 0.855709 | rel_err_u: 1.6403, rel_err_x: 0.3054
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5400 | Loss: 0.843296 | rel_err_u: 1.6350, rel_err_x: 0.3036
# Epoch 5450 | Loss: 0.831220 | rel_err_u: 1.6288, rel_err_x: 0.3016
# Epoch 5500 | Loss: 0.819511 | rel_err_u: 1.6222, rel_err_x: 0.2993
# Epoch 5550 | Loss: 0.807304 | rel_err_u: 1.6156, rel_err_x: 0.2969
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5600 | Loss: 0.794805 | rel_err_u: 1.6094, rel_err_x: 0.2945
# Epoch 5650 | Loss: 0.781654 | rel_err_u: 1.6042, rel_err_x: 0.2923
# Epoch 5700 | Loss: 0.767519 | rel_err_u: 1.6009, rel_err_x: 0.2906
# Epoch 5750 | Loss: 0.752499 | rel_err_u: 1.6003, rel_err_x: 0.2898
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 5800 | Loss: 0.738212 | rel_err_u: 1.5996, rel_err_x: 0.2890
# Epoch 5850 | Loss: 0.724573 | rel_err_u: 1.5973, rel_err_x: 0.2878
# Epoch 5900 | Loss: 0.710648 | rel_err_u: 1.5951, rel_err_x: 0.2867
# Epoch 5950 | Loss: 0.696090 | rel_err_u: 1.5941, rel_err_x: 0.2860
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6000 | Loss: 0.680729 | rel_err_u: 1.5944, rel_err_x: 0.2859
# Epoch 6050 | Loss: 0.664241 | rel_err_u: 1.5962, rel_err_x: 0.2864
# Epoch 6100 | Loss: 0.646455 | rel_err_u: 1.5995, rel_err_x: 0.2874
# Epoch 6150 | Loss: 0.627355 | rel_err_u: 1.6044, rel_err_x: 0.2891
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6200 | Loss: 0.607416 | rel_err_u: 1.6106, rel_err_x: 0.2912
# Epoch 6250 | Loss: 0.587147 | rel_err_u: 1.6180, rel_err_x: 0.2939
# Epoch 6300 | Loss: 0.566963 | rel_err_u: 1.6260, rel_err_x: 0.2968
# Epoch 6350 | Loss: 0.547773 | rel_err_u: 1.6344, rel_err_x: 0.2998
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6400 | Loss: 0.529420 | rel_err_u: 1.6427, rel_err_x: 0.3028
# Epoch 6450 | Loss: 0.512103 | rel_err_u: 1.6506, rel_err_x: 0.3055
# Epoch 6500 | Loss: 0.495657 | rel_err_u: 1.6580, rel_err_x: 0.3081
# Epoch 6550 | Loss: 0.480134 | rel_err_u: 1.6648, rel_err_x: 0.3104
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6600 | Loss: 0.465625 | rel_err_u: 1.6709, rel_err_x: 0.3124
# Epoch 6650 | Loss: 0.451994 | rel_err_u: 1.6763, rel_err_x: 0.3140
# Epoch 6700 | Loss: 0.439261 | rel_err_u: 1.6810, rel_err_x: 0.3154
# Epoch 6750 | Loss: 0.427315 | rel_err_u: 1.6849, rel_err_x: 0.3164
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 6800 | Loss: 0.415811 | rel_err_u: 1.6882, rel_err_x: 0.3172
# Epoch 6850 | Loss: 0.404825 | rel_err_u: 1.6911, rel_err_x: 0.3178
# Epoch 6900 | Loss: 0.393985 | rel_err_u: 1.6937, rel_err_x: 0.3184
# Epoch 6950 | Loss: 0.382882 | rel_err_u: 1.6964, rel_err_x: 0.3189
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7000 | Loss: 0.371160 | rel_err_u: 1.6994, rel_err_x: 0.3196
# Epoch 7050 | Loss: 0.358254 | rel_err_u: 1.7031, rel_err_x: 0.3207
# Epoch 7100 | Loss: 0.343535 | rel_err_u: 1.7079, rel_err_x: 0.3223
# Epoch 7150 | Loss: 0.327903 | rel_err_u: 1.7145, rel_err_x: 0.3247
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7200 | Loss: 0.312792 | rel_err_u: 1.7215, rel_err_x: 0.3271
# Epoch 7250 | Loss: 0.297126 | rel_err_u: 1.7282, rel_err_x: 0.3293
# Epoch 7300 | Loss: 0.280737 | rel_err_u: 1.7337, rel_err_x: 0.3312
# Epoch 7350 | Loss: 0.264173 | rel_err_u: 1.7381, rel_err_x: 0.3329
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7400 | Loss: 0.249824 | rel_err_u: 1.7391, rel_err_x: 0.3334
# Epoch 7450 | Loss: 0.239221 | rel_err_u: 1.7360, rel_err_x: 0.3323
# Epoch 7500 | Loss: 0.231307 | rel_err_u: 1.7309, rel_err_x: 0.3303
# Epoch 7550 | Loss: 0.224796 | rel_err_u: 1.7259, rel_err_x: 0.3281
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7600 | Loss: 0.219137 | rel_err_u: 1.7216, rel_err_x: 0.3261
# Epoch 7650 | Loss: 0.214071 | rel_err_u: 1.7179, rel_err_x: 0.3244
# Epoch 7700 | Loss: 0.209338 | rel_err_u: 1.7146, rel_err_x: 0.3227
# Epoch 7750 | Loss: 0.204934 | rel_err_u: 1.7115, rel_err_x: 0.3212
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 7800 | Loss: 0.200810 | rel_err_u: 1.7085, rel_err_x: 0.3197
# Epoch 7850 | Loss: 0.196885 | rel_err_u: 1.7054, rel_err_x: 0.3183
# Epoch 7900 | Loss: 0.193126 | rel_err_u: 1.7024, rel_err_x: 0.3169
# Epoch 7950 | Loss: 0.189555 | rel_err_u: 1.6992, rel_err_x: 0.3154
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8000 | Loss: 0.186011 | rel_err_u: 1.6962, rel_err_x: 0.3140
# Epoch 8050 | Loss: 0.182529 | rel_err_u: 1.6931, rel_err_x: 0.3126
# Epoch 8100 | Loss: 0.179100 | rel_err_u: 1.6902, rel_err_x: 0.3113
# Epoch 8150 | Loss: 0.175610 | rel_err_u: 1.6874, rel_err_x: 0.3100
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8200 | Loss: 0.172034 | rel_err_u: 1.6849, rel_err_x: 0.3088
# Epoch 8250 | Loss: 0.168258 | rel_err_u: 1.6828, rel_err_x: 0.3078
# Epoch 8300 | Loss: 0.164348 | rel_err_u: 1.6813, rel_err_x: 0.3070
# Epoch 8350 | Loss: 0.160263 | rel_err_u: 1.6807, rel_err_x: 0.3065
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8400 | Loss: 0.156051 | rel_err_u: 1.6811, rel_err_x: 0.3064
# Epoch 8450 | Loss: 0.151861 | rel_err_u: 1.6823, rel_err_x: 0.3066
# Epoch 8500 | Loss: 0.147980 | rel_err_u: 1.6842, rel_err_x: 0.3069
# Epoch 8550 | Loss: 0.144420 | rel_err_u: 1.6863, rel_err_x: 0.3074
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8600 | Loss: 0.141163 | rel_err_u: 1.6881, rel_err_x: 0.3078
# Epoch 8650 | Loss: 0.138117 | rel_err_u: 1.6899, rel_err_x: 0.3081
# Epoch 8700 | Loss: 0.135109 | rel_err_u: 1.6914, rel_err_x: 0.3083
# Epoch 8750 | Loss: 0.132187 | rel_err_u: 1.6931, rel_err_x: 0.3085
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 8800 | Loss: 0.129250 | rel_err_u: 1.6950, rel_err_x: 0.3087
# Epoch 8850 | Loss: 0.126274 | rel_err_u: 1.6971, rel_err_x: 0.3089
# Epoch 8900 | Loss: 0.123319 | rel_err_u: 1.6997, rel_err_x: 0.3093
# Epoch 8950 | Loss: 0.120219 | rel_err_u: 1.7027, rel_err_x: 0.3097
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9000 | Loss: 0.117052 | rel_err_u: 1.7061, rel_err_x: 0.3102
# Epoch 9050 | Loss: 0.113824 | rel_err_u: 1.7102, rel_err_x: 0.3108
# Epoch 9100 | Loss: 0.110566 | rel_err_u: 1.7146, rel_err_x: 0.3115
# Epoch 9150 | Loss: 0.107182 | rel_err_u: 1.7197, rel_err_x: 0.3122
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9200 | Loss: 0.103729 | rel_err_u: 1.7250, rel_err_x: 0.3130
# Epoch 9250 | Loss: 0.100214 | rel_err_u: 1.7306, rel_err_x: 0.3138
# Epoch 9300 | Loss: 0.096656 | rel_err_u: 1.7365, rel_err_x: 0.3146
# Epoch 9350 | Loss: 0.092998 | rel_err_u: 1.7426, rel_err_x: 0.3154
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9400 | Loss: 0.089382 | rel_err_u: 1.7488, rel_err_x: 0.3161
# Epoch 9450 | Loss: 0.085940 | rel_err_u: 1.7553, rel_err_x: 0.3169
# Epoch 9500 | Loss: 0.082730 | rel_err_u: 1.7618, rel_err_x: 0.3176
# Epoch 9550 | Loss: 0.079663 | rel_err_u: 1.7681, rel_err_x: 0.3182
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9600 | Loss: 0.076701 | rel_err_u: 1.7740, rel_err_x: 0.3186
# Epoch 9650 | Loss: 0.073856 | rel_err_u: 1.7793, rel_err_x: 0.3187
# Epoch 9700 | Loss: 0.070977 | rel_err_u: 1.7842, rel_err_x: 0.3185
# Epoch 9750 | Loss: 0.067934 | rel_err_u: 1.7886, rel_err_x: 0.3180
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 9800 | Loss: 0.064465 | rel_err_u: 1.7930, rel_err_x: 0.3171
# Epoch 9850 | Loss: 0.060907 | rel_err_u: 1.7975, rel_err_x: 0.3159
# Epoch 9900 | Loss: 0.057225 | rel_err_u: 1.8002, rel_err_x: 0.3140
# Epoch 9950 | Loss: 0.053186 | rel_err_u: 1.8024, rel_err_x: 0.3120
# Plot saved to found_trajectories/nonlinear/lno/plot.png
# Epoch 10000 | Loss: 0.048645 | rel_err_u: 1.8055, rel_err_x: 0.3103

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: -0.016128093004226685

# %%
m = 200

modes = 32
width = 16
hidden_layer = 128

model = LNO1d(width, modes, activation = "silu",batch_norm=True, active_last=True, hidden_layer=hidden_layer).to(device)

ckpt = torch.load("trained_models/singular_arc/lno/attempt_started20250720_215514/epoch[1000]_model_time_[20250720_215514]_loss_[0.0148].pth", map_location=device)
model.load_state_dict(ckpt["model_state_dict"])

w = [50, 1, 1, 0, 10]
initial_guess = torch.rand((1, m), dtype=torch.float32, device=device, requires_grad=True) - 3

analytics, x, u, x_optimal, u_optimal = solve_optimization(
    model, 'singular_arc',
    initial_guess,
    lr=0.001,
    architecture="lno", 
    w=w,
    num_epochs = 5000,
    m=m,
    bounds = [-3.5, 0],
    device=device,
    logging=True
)
# Out:
# Epoch   50 | Loss: 10.437212 | rel_err_u: 1.0124, rel_err_x: 1.1253
# Epoch  100 | Loss: 10.010415 | rel_err_u: 0.9862, rel_err_x: 1.0730
# Epoch  150 | Loss: 9.623985 | rel_err_u: 0.9594, rel_err_x: 1.0201
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  200 | Loss: 9.269459 | rel_err_u: 0.9329, rel_err_x: 0.9680
# Epoch  250 | Loss: 8.942824 | rel_err_u: 0.9068, rel_err_x: 0.9173
# Epoch  300 | Loss: 8.641844 | rel_err_u: 0.8813, rel_err_x: 0.8685
# Epoch  350 | Loss: 8.364189 | rel_err_u: 0.8564, rel_err_x: 0.8220
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  400 | Loss: 8.108514 | rel_err_u: 0.8322, rel_err_x: 0.7781
# Epoch  450 | Loss: 7.872994 | rel_err_u: 0.8085, rel_err_x: 0.7369
# Epoch  500 | Loss: 7.655867 | rel_err_u: 0.7854, rel_err_x: 0.6988
# Epoch  550 | Loss: 7.455352 | rel_err_u: 0.7627, rel_err_x: 0.6635
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  600 | Loss: 7.269360 | rel_err_u: 0.7404, rel_err_x: 0.6311
# Epoch  650 | Loss: 7.096163 | rel_err_u: 0.7183, rel_err_x: 0.6013
# Epoch  700 | Loss: 6.934237 | rel_err_u: 0.6967, rel_err_x: 0.5738
# Epoch  750 | Loss: 6.782468 | rel_err_u: 0.6753, rel_err_x: 0.5481
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch  800 | Loss: 6.639828 | rel_err_u: 0.6545, rel_err_x: 0.5240
# Epoch  850 | Loss: 6.505654 | rel_err_u: 0.6340, rel_err_x: 0.5013
# Epoch  900 | Loss: 6.379127 | rel_err_u: 0.6140, rel_err_x: 0.4797
# Epoch  950 | Loss: 6.259533 | rel_err_u: 0.5943, rel_err_x: 0.4592
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1000 | Loss: 6.146250 | rel_err_u: 0.5750, rel_err_x: 0.4397
# Epoch 1050 | Loss: 6.038263 | rel_err_u: 0.5560, rel_err_x: 0.4210
# Epoch 1100 | Loss: 5.935150 | rel_err_u: 0.5374, rel_err_x: 0.4031
# Epoch 1150 | Loss: 5.836113 | rel_err_u: 0.5190, rel_err_x: 0.3858
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1200 | Loss: 5.740752 | rel_err_u: 0.5010, rel_err_x: 0.3691
# Epoch 1250 | Loss: 5.648618 | rel_err_u: 0.4832, rel_err_x: 0.3529
# Epoch 1300 | Loss: 5.559667 | rel_err_u: 0.4658, rel_err_x: 0.3372
# Epoch 1350 | Loss: 5.473882 | rel_err_u: 0.4488, rel_err_x: 0.3220
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1400 | Loss: 5.391363 | rel_err_u: 0.4322, rel_err_x: 0.3072
# Epoch 1450 | Loss: 5.312045 | rel_err_u: 0.4159, rel_err_x: 0.2929
# Epoch 1500 | Loss: 5.235902 | rel_err_u: 0.4001, rel_err_x: 0.2791
# Epoch 1550 | Loss: 5.162602 | rel_err_u: 0.3847, rel_err_x: 0.2659
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1600 | Loss: 5.092293 | rel_err_u: 0.3697, rel_err_x: 0.2533
# Epoch 1650 | Loss: 5.024571 | rel_err_u: 0.3551, rel_err_x: 0.2413
# Epoch 1700 | Loss: 4.959040 | rel_err_u: 0.3409, rel_err_x: 0.2301
# Epoch 1750 | Loss: 4.895736 | rel_err_u: 0.3271, rel_err_x: 0.2197
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 1800 | Loss: 4.834356 | rel_err_u: 0.3136, rel_err_x: 0.2102
# Epoch 1850 | Loss: 4.774760 | rel_err_u: 0.3006, rel_err_x: 0.2016
# Epoch 1900 | Loss: 4.716532 | rel_err_u: 0.2880, rel_err_x: 0.1940
# Epoch 1950 | Loss: 4.659863 | rel_err_u: 0.2758, rel_err_x: 0.1873
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 2000 | Loss: 4.604487 | rel_err_u: 0.2643, rel_err_x: 0.1817
# Epoch 2050 | Loss: 4.550687 | rel_err_u: 0.2534, rel_err_x: 0.1769
# Epoch 2100 | Loss: 4.498513 | rel_err_u: 0.2433, rel_err_x: 0.1731
# Epoch 2150 | Loss: 4.449517 | rel_err_u: 0.2336, rel_err_x: 0.1685
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 2200 | Loss: 4.403890 | rel_err_u: 0.2247, rel_err_x: 0.1645
# Epoch 2250 | Loss: 4.361354 | rel_err_u: 0.2166, rel_err_x: 0.1610
# Epoch 2300 | Loss: 4.321673 | rel_err_u: 0.2094, rel_err_x: 0.1582
# Epoch 2350 | Loss: 4.284866 | rel_err_u: 0.2030, rel_err_x: 0.1559
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 2400 | Loss: 4.250764 | rel_err_u: 0.1975, rel_err_x: 0.1542
# Epoch 2450 | Loss: 4.219209 | rel_err_u: 0.1928, rel_err_x: 0.1528
# Epoch 2500 | Loss: 4.190107 | rel_err_u: 0.1891, rel_err_x: 0.1519
# Epoch 2550 | Loss: 4.163254 | rel_err_u: 0.1861, rel_err_x: 0.1514
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 2600 | Loss: 4.138532 | rel_err_u: 0.1839, rel_err_x: 0.1512
# Epoch 2650 | Loss: 4.115688 | rel_err_u: 0.1825, rel_err_x: 0.1514
# Epoch 2700 | Loss: 4.094732 | rel_err_u: 0.1817, rel_err_x: 0.1518
# Epoch 2750 | Loss: 4.075427 | rel_err_u: 0.1816, rel_err_x: 0.1524
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 2800 | Loss: 4.057666 | rel_err_u: 0.1820, rel_err_x: 0.1532
# Epoch 2850 | Loss: 4.041434 | rel_err_u: 0.1827, rel_err_x: 0.1540
# Epoch 2900 | Loss: 4.026529 | rel_err_u: 0.1838, rel_err_x: 0.1548
# Epoch 2950 | Loss: 4.012835 | rel_err_u: 0.1852, rel_err_x: 0.1557
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 3000 | Loss: 4.000379 | rel_err_u: 0.1870, rel_err_x: 0.1568
# Epoch 3050 | Loss: 3.988948 | rel_err_u: 0.1890, rel_err_x: 0.1580
# Epoch 3100 | Loss: 3.978559 | rel_err_u: 0.1911, rel_err_x: 0.1592
# Epoch 3150 | Loss: 3.969041 | rel_err_u: 0.1935, rel_err_x: 0.1605
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 3200 | Loss: 3.960385 | rel_err_u: 0.1960, rel_err_x: 0.1618
# Epoch 3250 | Loss: 3.952547 | rel_err_u: 0.1986, rel_err_x: 0.1632
# Epoch 3300 | Loss: 3.945427 | rel_err_u: 0.2013, rel_err_x: 0.1645
# Epoch 3350 | Loss: 3.938993 | rel_err_u: 0.2040, rel_err_x: 0.1659
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 3400 | Loss: 3.933167 | rel_err_u: 0.2068, rel_err_x: 0.1673
# Epoch 3450 | Loss: 3.927948 | rel_err_u: 0.2095, rel_err_x: 0.1686
# Epoch 3500 | Loss: 3.923221 | rel_err_u: 0.2123, rel_err_x: 0.1699
# Epoch 3550 | Loss: 3.918982 | rel_err_u: 0.2149, rel_err_x: 0.1712
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 3600 | Loss: 3.915195 | rel_err_u: 0.2175, rel_err_x: 0.1724
# Epoch 3650 | Loss: 3.911820 | rel_err_u: 0.2201, rel_err_x: 0.1735
# Epoch 3700 | Loss: 3.908790 | rel_err_u: 0.2225, rel_err_x: 0.1746
# Epoch 3750 | Loss: 3.906091 | rel_err_u: 0.2249, rel_err_x: 0.1756
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 3800 | Loss: 3.903746 | rel_err_u: 0.2272, rel_err_x: 0.1766
# Epoch 3850 | Loss: 3.901598 | rel_err_u: 0.2294, rel_err_x: 0.1775
# Epoch 3900 | Loss: 3.899753 | rel_err_u: 0.2314, rel_err_x: 0.1784
# Epoch 3950 | Loss: 3.898108 | rel_err_u: 0.2334, rel_err_x: 0.1792
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 4000 | Loss: 3.896653 | rel_err_u: 0.2353, rel_err_x: 0.1799
# Epoch 4050 | Loss: 3.895339 | rel_err_u: 0.2370, rel_err_x: 0.1806
# Epoch 4100 | Loss: 3.894242 | rel_err_u: 0.2387, rel_err_x: 0.1812
# Epoch 4150 | Loss: 3.893270 | rel_err_u: 0.2403, rel_err_x: 0.1818
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 4200 | Loss: 3.892414 | rel_err_u: 0.2417, rel_err_x: 0.1824
# Epoch 4250 | Loss: 3.891642 | rel_err_u: 0.2431, rel_err_x: 0.1829
# Epoch 4300 | Loss: 3.890998 | rel_err_u: 0.2444, rel_err_x: 0.1833
# Epoch 4350 | Loss: 3.890439 | rel_err_u: 0.2456, rel_err_x: 0.1837
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 4400 | Loss: 3.889938 | rel_err_u: 0.2467, rel_err_x: 0.1841
# Epoch 4450 | Loss: 3.889515 | rel_err_u: 0.2477, rel_err_x: 0.1844
# Epoch 4500 | Loss: 3.889148 | rel_err_u: 0.2487, rel_err_x: 0.1847
# Epoch 4550 | Loss: 3.888813 | rel_err_u: 0.2496, rel_err_x: 0.1850
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 4600 | Loss: 3.888548 | rel_err_u: 0.2504, rel_err_x: 0.1852
# Epoch 4650 | Loss: 3.888294 | rel_err_u: 0.2512, rel_err_x: 0.1855
# Epoch 4700 | Loss: 3.888106 | rel_err_u: 0.2519, rel_err_x: 0.1856
# Epoch 4750 | Loss: 3.887922 | rel_err_u: 0.2525, rel_err_x: 0.1858
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 4800 | Loss: 3.887770 | rel_err_u: 0.2531, rel_err_x: 0.1860
# Epoch 4850 | Loss: 3.887630 | rel_err_u: 0.2537, rel_err_x: 0.1861
# Epoch 4900 | Loss: 3.887536 | rel_err_u: 0.2542, rel_err_x: 0.1862
# Epoch 4950 | Loss: 3.887425 | rel_err_u: 0.2546, rel_err_x: 0.1863
# Plot saved to found_trajectories/singular_arc/lno/plot.png
# Epoch 5000 | Loss: 3.887366 | rel_err_u: 0.2550, rel_err_x: 0.1863

# %%
print(f"Final objective loss: {analytics['obj'][-1]}")
# Out:
# Final objective loss: 2.183225393295288

# %% [markdown]
# <image src="found_trajectories/singular_arc/lno/plot.png" width=600>
